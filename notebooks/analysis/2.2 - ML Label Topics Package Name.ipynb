# %%
from hydra import initialize, compose

with initialize(version_base=None, config_path="../../src/conf/"):
    cfg = compose(config_name='main.yaml', overrides=["local=default"])
    print(cfg)
# Out:
# {'num_workers': 1, 'num_splits': 10, 'split': 1, 'seed': 42, 'project_path': '${base_path}/data/raw/dataset_with_graphs.csv', 'extraction': {'_target_': 'src.feature.extract.NameFeatureExtraction', 'graph_path': '${arcan_graphs}', 'out_path': '${out_path}/processed/', 'stopwords': 'None'}, 'embedding': {'_target_': 'src.feature.embedding.FastTextEmbedding', 'model': 'fastText', 'path': '${base_path}/data/models/wiki.en.bin'}, 'base_path': '/home/sasce/PycharmProjects/CodeGraphClassification', 'out_path': '${base_path}/data/', 'arcan_out': '${base_path}/data/interim/', 'arcan_graphs': '${arcan_out}/arcanOutput', 'raw_data': '${out_path}/raw/', 'dataset': '${base_path}/data/raw/classification_dataset_lang.csv', 'language': 'JAVA', 'repositories_path': '${base_path}/data/raw/repositories/', 'arcan_script': '${base_path}/scripts/bash/run-arcan.sh', 'arcan_path': '${base_path}/tools/arcan', 'repository_path': '${base_path}/data/raw/repositories', 'logs_path': '${base_path}/logs/', 'model': {'_target_': 'src.model.gcn.GraphConvNetwork', 'hidden_channels': 256}, 'datamodule': {'_target_': 'src.data.datamodule.GitRankingDataModule', 'graph_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/interim/arcanOutput', 'feature_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/embedding/name/fastText', 'out_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/torch', 'embedding_size': 300, 'batch_size': 32, 'num_splits': '${num_splits}', 'split': '${split}', 'has_val': True, 'has_test': True}}

# %%
from data.graph import ArcanGraphLoader
from os.path import join
from feature.content import NameContentExtraction
from utils import git_clone, get_versions, git_checkout, filter_by_label
from loguru import logger
import pandas as pd

LABEL = "machine learning"
projects = pd.read_csv("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/dataset_with_graphs.csv")
content_extractor = NameContentExtraction(graph_path=cfg.arcan_graphs)

# %%
projects.head()
# Out:
#                             name                             label   level  \
# 0  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 1  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 2  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 3  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 4  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
#
#    version                                       sha  nodes  edges
# 0      133  292a42769f7f6f1beaf4b178c3f7170fddfee282     68    212
# 1       63  c01cf7bf4093aa21fafc1fba93ba50ca0343c619     36    110
# 2       72  785b7928896b302fd84d81f9437ec47af5d7b330     36    110
# 3       21  b08c040bfe57cb1f3220ca487d33b0240a6564fa     39    155
# 4      115  30cb73f240f83e7a3a363d4a5a5d27c04e313907     68    212

# %%
projects = filter_by_label(projects.copy(deep=True), [LABEL])
# Out:
# 2022-10-26 11:54:44.261 | INFO     | utils:filter_by_label:105 - Labels ['machine learning']
# /home/sasce/PycharmProjects/CodeGraphClassification/src/utils.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].apply(tuple)

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2012 entries, 907 to 59634
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2012 non-null   object
#  1   label    2012 non-null   object
#  2   level    2012 non-null   object
#  3   version  2012 non-null   int64
#  4   sha      2012 non-null   object
#  5   nodes    2012 non-null   int64
#  6   edges    2012 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 125.8+ KB

# %%
projects = list(set(projects['name'].tolist()))
len(projects)
# Out:
# 100

# %%
from tqdm import tqdm

graph_loader = ArcanGraphLoader()
logger.info(f"Extracting features for {len(projects)} projects")
identifiers = []
content = {}
for project_name in tqdm(projects):
    project = project_name.replace('|', '/')

    project_url = f'https://github.com/{project}'
    if content_extractor.clone:
        git_clone(project_url, project_name, cfg.repositories_path)


    versions = [get_versions(project_name, cfg.arcan_graphs)[-1]]

    logger.info(f"Found {len(versions)} versions for project {project}")
    for num, sha in tqdm(versions):
        try:
            if content_extractor.clone:
                git_checkout(join(cfg.repositories_path, project_name), sha)
            project_graph = graph_loader.load(join(cfg.arcan_graphs, project_name, f'dependency-graph-{num}_{sha}.graphml'))
            res = content_extractor.extract(project_name, sha, num)
            identifiers.append(res)
        except:
            continue

    text = [" ".join(x).replace(".", " ") for x in identifiers]
    content[project_name] = text

    #repo_path = join(cfg.repository_path, project_name)
    #shutil.rmtree(repo_path, ignore_errors=True)
# Out:
# 2022-10-26 11:54:44.835 | INFO     | __main__:<module>:4 - Extracting features for 100 projects
#   0%|          | 0/100 [00:00<?, ?it/s]2022-10-26 11:54:44.838 | INFO     | __main__:<module>:17 - Found 1 versions for project gidim/Babler
#
# 100%|██████████| 1/1 [00:00<00:00, 110.98it/s]
# 2022-10-26 11:54:44.853 | INFO     | __main__:<module>:17 - Found 1 versions for project lsds/Crossbow
#
# 100%|██████████| 1/1 [00:00<00:00, 54.60it/s]
# 2022-10-26 11:54:44.882 | INFO     | __main__:<module>:17 - Found 1 versions for project elki-project/elki
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.55it/s]
#   3%|▎         | 3/100 [00:00<00:15,  6.22it/s]2022-10-26 11:54:45.321 | INFO     | __main__:<module>:17 - Found 1 versions for project lizhangqu/TensorflowLite
#
# 100%|██████████| 1/1 [00:00<00:00, 108.80it/s]
# 2022-10-26 11:54:45.334 | INFO     | __main__:<module>:17 - Found 1 versions for project viadee/javaAnchorExplainer
#
# 100%|██████████| 1/1 [00:00<00:00, 173.17it/s]
# 2022-10-26 11:54:45.345 | INFO     | __main__:<module>:17 - Found 1 versions for project tgsmith61591/clust4j
#
# 100%|██████████| 1/1 [00:00<00:00, 71.98it/s]
# 2022-10-26 11:54:45.366 | INFO     | __main__:<module>:17 - Found 1 versions for project vinhkhuc/lbfgs4j
#
# 100%|██████████| 1/1 [00:00<00:00, 359.66it/s]
# 2022-10-26 11:54:45.373 | INFO     | __main__:<module>:17 - Found 1 versions for project sbl-sdsc/mmtf-spark
#
# 100%|██████████| 1/1 [00:00<00:00, 106.55it/s]
# 2022-10-26 11:54:45.392 | INFO     | __main__:<module>:17 - Found 1 versions for project CeON/CERMINE
#
# 100%|██████████| 1/1 [00:00<00:00, 18.52it/s]
#   9%|▉         | 9/100 [00:00<00:05, 16.72it/s]2022-10-26 11:54:45.469 | INFO     | __main__:<module>:17 - Found 1 versions for project lejon/PartiallyCollapsedLDA
#
# 100%|██████████| 1/1 [00:00<00:00, 59.40it/s]
# 2022-10-26 11:54:45.494 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/CatAndDogRecognizer
#
# 100%|██████████| 1/1 [00:00<00:00, 357.91it/s]
# 2022-10-26 11:54:45.501 | INFO     | __main__:<module>:17 - Found 1 versions for project grouplens/samantha
#
# 100%|██████████| 1/1 [00:00<00:00, 23.36it/s]
# 2022-10-26 11:54:45.560 | INFO     | __main__:<module>:17 - Found 1 versions for project o19s/RankyMcRankFace
#
# 100%|██████████| 1/1 [00:00<00:00, 118.56it/s]
#  13%|█▎        | 13/100 [00:00<00:04, 21.69it/s]2022-10-26 11:54:45.575 | INFO     | __main__:<module>:17 - Found 1 versions for project tahaemara/arabic-characters-recognition
#
# 100%|██████████| 1/1 [00:00<00:00, 384.20it/s]
# 2022-10-26 11:54:45.582 | INFO     | __main__:<module>:17 - Found 1 versions for project amidst/toolbox
#
# 100%|██████████| 1/1 [00:00<00:00, 18.42it/s]
# 2022-10-26 11:54:45.649 | INFO     | __main__:<module>:17 - Found 1 versions for project viadee/camunda-kafka-polling-client
#
# 100%|██████████| 1/1 [00:00<00:00, 154.85it/s]
# 2022-10-26 11:54:45.662 | INFO     | __main__:<module>:17 - Found 1 versions for project tony-framework/TonY
#
# 100%|██████████| 1/1 [00:00<00:00, 87.56it/s]
#  17%|█▋        | 17/100 [00:00<00:03, 25.81it/s]2022-10-26 11:54:45.680 | INFO     | __main__:<module>:17 - Found 1 versions for project cheng-li/pyramid
#
# 100%|██████████| 1/1 [00:00<00:00, 24.76it/s]
# 2022-10-26 11:54:45.736 | INFO     | __main__:<module>:17 - Found 1 versions for project Jasonnor/Backpropagation
#
# 100%|██████████| 1/1 [00:00<00:00, 444.74it/s]
# 2022-10-26 11:54:45.742 | INFO     | __main__:<module>:17 - Found 1 versions for project xRahul/GroupingMessages
#
# 100%|██████████| 1/1 [00:00<00:00, 434.78it/s]
# 2022-10-26 11:54:45.749 | INFO     | __main__:<module>:17 - Found 1 versions for project starling-lab/BoostSRL
#
# 100%|██████████| 1/1 [00:00<00:00, 17.30it/s]
#  21%|██        | 21/100 [00:00<00:02, 26.49it/s]2022-10-26 11:54:45.823 | INFO     | __main__:<module>:17 - Found 1 versions for project yuantiku/ytk-learn
#
# 100%|██████████| 1/1 [00:00<00:00, 63.98it/s]
# 2022-10-26 11:54:45.847 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/KMeansImageColorReduction
#
# 100%|██████████| 1/1 [00:00<00:00, 491.94it/s]
# 2022-10-26 11:54:45.854 | INFO     | __main__:<module>:17 - Found 1 versions for project snuspl/cruise
#
# 100%|██████████| 1/1 [00:00<00:00, 26.97it/s]
# 2022-10-26 11:54:45.911 | INFO     | __main__:<module>:17 - Found 1 versions for project evllabs/JGAAP
#
# 100%|██████████| 1/1 [00:00<00:00, 37.38it/s]
#  25%|██▌       | 25/100 [00:01<00:02, 28.06it/s]2022-10-26 11:54:45.950 | INFO     | __main__:<module>:17 - Found 1 versions for project Hortensie/AI_Trader
#
# 100%|██████████| 1/1 [00:00<00:00, 53.52it/s]
# 2022-10-26 11:54:45.980 | INFO     | __main__:<module>:17 - Found 1 versions for project CalebFenton/apkfile
#
# 100%|██████████| 1/1 [00:00<00:00, 95.43it/s]
# 2022-10-26 11:54:45.998 | INFO     | __main__:<module>:17 - Found 1 versions for project fracpete/collective-classification-weka-package
#
# 100%|██████████| 1/1 [00:00<00:00, 128.89it/s]
# 2022-10-26 11:54:46.014 | INFO     | __main__:<module>:17 - Found 1 versions for project robrua/easy-bert
#
# 100%|██████████| 1/1 [00:00<00:00, 411.85it/s]
# 2022-10-26 11:54:46.022 | INFO     | __main__:<module>:17 - Found 1 versions for project universal-automata/liblevenshtein-java
#
# 100%|██████████| 1/1 [00:00<00:00, 171.08it/s]
# 2022-10-26 11:54:46.036 | INFO     | __main__:<module>:17 - Found 1 versions for project kaiwaehner/ksql-udf-deep-learning-mqtt-iot
#
# 100%|██████████| 1/1 [00:00<00:00, 251.86it/s]
# 2022-10-26 11:54:46.047 | INFO     | __main__:<module>:17 - Found 1 versions for project rahul-raj/Java-Deep-Learning-Cookbook
#
# 100%|██████████| 1/1 [00:00<00:00, 285.13it/s]
#  32%|███▏      | 32/100 [00:01<00:01, 37.76it/s]2022-10-26 11:54:46.058 | INFO     | __main__:<module>:17 - Found 1 versions for project padreati/rapaio
#
# 100%|██████████| 1/1 [00:00<00:00, 10.61it/s]
# 2022-10-26 11:54:46.169 | INFO     | __main__:<module>:17 - Found 1 versions for project mccorby/ML-LetterPredictor-Android
#
# 100%|██████████| 1/1 [00:00<00:00, 89.20it/s]
# 2022-10-26 11:54:46.187 | INFO     | __main__:<module>:17 - Found 1 versions for project claczny/VizBin
#
# 100%|██████████| 1/1 [00:00<00:00, 210.11it/s]
# 2022-10-26 11:54:46.198 | INFO     | __main__:<module>:17 - Found 1 versions for project sanity/quickml
#
# 100%|██████████| 1/1 [00:00<00:00, 27.89it/s]
# 2022-10-26 11:54:46.248 | INFO     | __main__:<module>:17 - Found 1 versions for project pushkar/ABAGAIL
#
# 100%|██████████| 1/1 [00:00<00:00, 31.78it/s]
#  37%|███▋      | 37/100 [00:01<00:02, 30.57it/s]2022-10-26 11:54:46.288 | INFO     | __main__:<module>:17 - Found 1 versions for project lil-lab/spf
#
# 100%|██████████| 1/1 [00:00<00:00, 16.69it/s]
# 2022-10-26 11:54:46.370 | INFO     | __main__:<module>:17 - Found 1 versions for project nikolamilosevic86/owasp-seraphimdroid
#
# 100%|██████████| 1/1 [00:00<00:00, 60.19it/s]
# 2022-10-26 11:54:46.397 | INFO     | __main__:<module>:17 - Found 1 versions for project punit-naik/MLHadoop
#
# 100%|██████████| 1/1 [00:00<00:00, 260.61it/s]
# 2022-10-26 11:54:46.405 | INFO     | __main__:<module>:17 - Found 1 versions for project hanuor/onyx
#
# 100%|██████████| 1/1 [00:00<00:00, 111.48it/s]
#  41%|████      | 41/100 [00:01<00:01, 30.41it/s]2022-10-26 11:54:46.421 | INFO     | __main__:<module>:17 - Found 1 versions for project tekrei/DSAlgorithms
#
# 100%|██████████| 1/1 [00:00<00:00, 297.07it/s]
# 2022-10-26 11:54:46.429 | INFO     | __main__:<module>:17 - Found 1 versions for project ShifuML/shifu
#
# 100%|██████████| 1/1 [00:00<00:00, 18.86it/s]
# 2022-10-26 11:54:46.499 | INFO     | __main__:<module>:17 - Found 1 versions for project ewimberley/jGeneticNeuralNet
#
# 100%|██████████| 1/1 [00:00<00:00, 211.75it/s]
# 2022-10-26 11:54:46.509 | INFO     | __main__:<module>:17 - Found 1 versions for project tugraz-isds/systemds
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.80it/s]
#  45%|████▌     | 45/100 [00:01<00:02, 22.89it/s]2022-10-26 11:54:46.710 | INFO     | __main__:<module>:17 - Found 1 versions for project dividiti/crowdsource-video-experiments-on-android
#
# 100%|██████████| 1/1 [00:00<00:00, 190.13it/s]
# 2022-10-26 11:54:46.721 | INFO     | __main__:<module>:17 - Found 1 versions for project trishullab/bayou
#
# 100%|██████████| 1/1 [00:00<00:00, 70.75it/s]
# 2022-10-26 11:54:46.746 | INFO     | __main__:<module>:17 - Found 1 versions for project Cerenaut/agi
#
# 100%|██████████| 1/1 [00:00<00:00, 24.68it/s]
# 2022-10-26 11:54:46.801 | INFO     | __main__:<module>:17 - Found 1 versions for project USCDataScience/AgePredictor
#
# 100%|██████████| 1/1 [00:00<00:00, 172.17it/s]
#  49%|████▉     | 49/100 [00:01<00:01, 25.90it/s]2022-10-26 11:54:46.813 | INFO     | __main__:<module>:17 - Found 1 versions for project LiuLabUB/HMMRATAC
#
# 100%|██████████| 1/1 [00:00<00:00, 113.34it/s]
# 2022-10-26 11:54:46.826 | INFO     | __main__:<module>:17 - Found 1 versions for project CogComp/lbjava
#
# 100%|██████████| 1/1 [00:00<00:00, 41.96it/s]
# 2022-10-26 11:54:46.862 | INFO     | __main__:<module>:17 - Found 1 versions for project vinhkhuc/jcrfsuite
#
# 100%|██████████| 1/1 [00:00<00:00, 267.96it/s]
# 2022-10-26 11:54:46.871 | INFO     | __main__:<module>:17 - Found 1 versions for project Waikato/weka-3.8
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
#  53%|█████▎    | 53/100 [00:02<00:02, 18.13it/s]2022-10-26 11:54:47.197 | INFO     | __main__:<module>:17 - Found 1 versions for project Cerenaut/Preprocess-NIST-SD19
#
# 100%|██████████| 1/1 [00:00<00:00, 202.63it/s]
# 2022-10-26 11:54:47.206 | INFO     | __main__:<module>:17 - Found 1 versions for project EdwardRaff/JSAT
#
# 100%|██████████| 1/1 [00:00<00:00, 14.85it/s]
# 2022-10-26 11:54:47.286 | INFO     | __main__:<module>:17 - Found 1 versions for project wcmc-its/ReCiter
#
# 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
#  56%|█████▌    | 56/100 [00:02<00:02, 19.62it/s]2022-10-26 11:54:47.310 | INFO     | __main__:<module>:17 - Found 1 versions for project Pradyuman7/LookAtMe
#
# 100%|██████████| 1/1 [00:00<00:00, 348.10it/s]
# 2022-10-26 11:54:47.317 | INFO     | __main__:<module>:17 - Found 1 versions for project intuit/foremast
#
# 100%|██████████| 1/1 [00:00<00:00, 207.33it/s]
# 2022-10-26 11:54:47.328 | INFO     | __main__:<module>:17 - Found 1 versions for project kaiwaehner/tensorflow-serving-java-grpc-kafka-streams
#
# 100%|██████████| 1/1 [00:00<00:00, 388.87it/s]
# 2022-10-26 11:54:47.335 | INFO     | __main__:<module>:17 - Found 1 versions for project indix/mlflow-gocd
#
# 100%|██████████| 1/1 [00:00<00:00, 279.97it/s]
# 2022-10-26 11:54:47.343 | INFO     | __main__:<module>:17 - Found 1 versions for project EdwardRaff/jLZJD
#
# 100%|██████████| 1/1 [00:00<00:00, 383.32it/s]
# 2022-10-26 11:54:47.350 | INFO     | __main__:<module>:17 - Found 1 versions for project graphaware/neo4j-nlp
#
# 100%|██████████| 1/1 [00:00<00:00, 55.70it/s]
# 2022-10-26 11:54:47.377 | INFO     | __main__:<module>:17 - Found 1 versions for project indeedeng/vowpal-wabbit-java
#
# 100%|██████████| 1/1 [00:00<00:00, 222.60it/s]
# 2022-10-26 11:54:47.387 | INFO     | __main__:<module>:17 - Found 1 versions for project openturing/turing
#
# 100%|██████████| 1/1 [00:00<00:00, 25.21it/s]
#  64%|██████▍   | 64/100 [00:02<00:01, 28.50it/s]2022-10-26 11:54:47.450 | INFO     | __main__:<module>:17 - Found 1 versions for project ptnplanet/Java-Naive-Bayes-Classifier
#
# 100%|██████████| 1/1 [00:00<00:00, 265.01it/s]
# 2022-10-26 11:54:47.458 | INFO     | __main__:<module>:17 - Found 1 versions for project Remper/sociallink
#
# 100%|██████████| 1/1 [00:00<00:00, 60.42it/s]
# 2022-10-26 11:54:47.486 | INFO     | __main__:<module>:17 - Found 1 versions for project amitshekhariitbhu/Android-TensorFlow-Lite-Example
#
# 100%|██████████| 1/1 [00:00<00:00, 375.56it/s]
# 2022-10-26 11:54:47.493 | INFO     | __main__:<module>:17 - Found 1 versions for project jasur-2902/CarRecognition
#
# 100%|██████████| 1/1 [00:00<00:00, 404.27it/s]
# 2022-10-26 11:54:47.503 | INFO     | __main__:<module>:17 - Found 1 versions for project rabidgremlin/Mutters
#
# 100%|██████████| 1/1 [00:00<00:00, 158.47it/s]
# 2022-10-26 11:54:47.515 | INFO     | __main__:<module>:17 - Found 1 versions for project Angel-ML/serving
#
# 100%|██████████| 1/1 [00:00<00:00, 194.88it/s]
# 2022-10-26 11:54:47.526 | INFO     | __main__:<module>:17 - Found 1 versions for project cTJakt/glaucus
#
# 100%|██████████| 1/1 [00:00<00:00, 157.31it/s]
# 2022-10-26 11:54:47.538 | INFO     | __main__:<module>:17 - Found 1 versions for project aws/sagemaker-sparkml-serving-container
#
# 100%|██████████| 1/1 [00:00<00:00, 376.10it/s]
# 2022-10-26 11:54:47.544 | INFO     | __main__:<module>:17 - Found 1 versions for project julesbond007/movie-recommendation-api
#
# 100%|██████████| 1/1 [00:00<00:00, 333.57it/s]
#  73%|███████▎  | 73/100 [00:02<00:00, 40.15it/s]2022-10-26 11:54:47.553 | INFO     | __main__:<module>:17 - Found 1 versions for project SAG-KeLP/kelp-input-generator
#
# 100%|██████████| 1/1 [00:00<00:00, 326.43it/s]
# 2022-10-26 11:54:47.560 | INFO     | __main__:<module>:17 - Found 1 versions for project raulh82vlc/Image-Detection-Samples
#
# 100%|██████████| 1/1 [00:00<00:00, 75.35it/s]
# 2022-10-26 11:54:47.580 | INFO     | __main__:<module>:17 - Found 1 versions for project igorrendulic/food_recognition_with_calorie_mama
#
# 100%|██████████| 1/1 [00:00<00:00, 333.12it/s]
# 2022-10-26 11:54:47.588 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/frauddetection
#
# 100%|██████████| 1/1 [00:00<00:00, 374.12it/s]
# 2022-10-26 11:54:47.596 | INFO     | __main__:<module>:17 - Found 1 versions for project qupath/qupath
#
# 100%|██████████| 1/1 [00:00<00:00, 10.33it/s]
# 2022-10-26 11:54:47.710 | INFO     | __main__:<module>:17 - Found 1 versions for project jblas-project/jblas
#
# 100%|██████████| 1/1 [00:00<00:00, 141.61it/s]
#  79%|███████▉  | 79/100 [00:02<00:00, 38.61it/s]2022-10-26 11:54:47.722 | INFO     | __main__:<module>:17 - Found 1 versions for project modernmt/modernmt
#
# 100%|██████████| 1/1 [00:00<00:00, 21.43it/s]
# 2022-10-26 11:54:47.784 | INFO     | __main__:<module>:17 - Found 1 versions for project rosette-api/rosette-elasticsearch-plugin
#
# 100%|██████████| 1/1 [00:00<00:00, 354.49it/s]
# 2022-10-26 11:54:47.791 | INFO     | __main__:<module>:17 - Found 1 versions for project MindorksOpenSource/AndroidTensorFlowMNISTExample
#
# 100%|██████████| 1/1 [00:00<00:00, 548.49it/s]
# 2022-10-26 11:54:47.796 | INFO     | __main__:<module>:17 - Found 1 versions for project christopher-beckham/weka-pyscript
#
# 100%|██████████| 1/1 [00:00<00:00, 412.30it/s]
# 2022-10-26 11:54:47.803 | INFO     | __main__:<module>:17 - Found 1 versions for project mast-group/tassal
#
# 100%|██████████| 1/1 [00:00<00:00, 100.52it/s]
# 2022-10-26 11:54:47.819 | INFO     | __main__:<module>:17 - Found 1 versions for project SabraTech/Raven-Messenger
#
# 100%|██████████| 1/1 [00:00<00:00, 212.56it/s]
#  85%|████████▌ | 85/100 [00:02<00:00, 42.44it/s]2022-10-26 11:54:47.830 | INFO     | __main__:<module>:17 - Found 1 versions for project monkeylearn/monkeylearn-java
#
# 100%|██████████| 1/1 [00:00<00:00, 348.97it/s]
# 2022-10-26 11:54:47.837 | INFO     | __main__:<module>:17 - Found 1 versions for project Waikato/moa
#
# 100%|██████████| 1/1 [00:00<00:00, 10.18it/s]
# 2022-10-26 11:54:47.954 | INFO     | __main__:<module>:17 - Found 1 versions for project MinhasKamal/GenderRecognizer
#
# 100%|██████████| 1/1 [00:00<00:00, 282.62it/s]
# 2022-10-26 11:54:47.963 | INFO     | __main__:<module>:17 - Found 1 versions for project vinhkhuc/JFastText
#
# 100%|██████████| 1/1 [00:00<00:00, 395.13it/s]
# 2022-10-26 11:54:47.971 | INFO     | __main__:<module>:17 - Found 1 versions for project men-in-stack/The-Third-Eye
#
# 100%|██████████| 1/1 [00:00<00:00, 291.27it/s]
#  90%|█████████ | 90/100 [00:03<00:00, 39.60it/s]2022-10-26 11:54:47.981 | INFO     | __main__:<module>:17 - Found 1 versions for project lil-lab/amr
#
# 100%|██████████| 1/1 [00:00<00:00, 60.35it/s]
# 2022-10-26 11:54:48.008 | INFO     | __main__:<module>:17 - Found 1 versions for project LearnLib/alex
#
# 100%|██████████| 1/1 [00:00<00:00, 108.46it/s]
# 2022-10-26 11:54:48.025 | INFO     | __main__:<module>:17 - Found 1 versions for project komiya-atsushi/xgboost-predictor-java
#
# 100%|██████████| 1/1 [00:00<00:00, 229.18it/s]
# 2022-10-26 11:54:48.035 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/DigitRecognizer
#
# 100%|██████████| 1/1 [00:00<00:00, 309.89it/s]
# 2022-10-26 11:54:48.043 | INFO     | __main__:<module>:17 - Found 1 versions for project vishnugh/evo-NEAT
#
# 100%|██████████| 1/1 [00:00<00:00, 325.22it/s]
# 2022-10-26 11:54:48.051 | INFO     | __main__:<module>:17 - Found 1 versions for project viadee/bpmn.ai
#
# 100%|██████████| 1/1 [00:00<00:00, 110.75it/s]
# 2022-10-26 11:54:48.067 | INFO     | __main__:<module>:17 - Found 1 versions for project girishpai/NumTrans
#
# 100%|██████████| 1/1 [00:00<00:00, 87.83it/s]
#  97%|█████████▋| 97/100 [00:03<00:00, 45.90it/s]2022-10-26 11:54:48.087 | INFO     | __main__:<module>:17 - Found 1 versions for project rahul-raj/Deeplearning4J
#
# 100%|██████████| 1/1 [00:00<00:00, 285.91it/s]
# 2022-10-26 11:54:48.096 | INFO     | __main__:<module>:17 - Found 1 versions for project cookiengineer/lycheejs
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# 2022-10-26 11:54:48.746 | INFO     | __main__:<module>:17 - Found 1 versions for project alipay/jpmml-sparkml-lightgbm
#
# 100%|██████████| 1/1 [00:00<00:00, 144.43it/s]
# 100%|██████████| 100/100 [00:03<00:00, 25.52it/s]

# %%
content
# Out:
# {'gidim|Babler': ['main bing main language id textcat text categorizer main language id com detect language errors main db export to text main bing azure search query main language id com detect language responses main language id cld cld2 main you tube you tube captions scraper main bing php bb scraper main bing php bb scraper bb broker main bing blogspot scraper main language id lingpipe ling pipe main collection babel broker main article extraction main http client main language id com main article extraction language with post count main bing php bb scraper bb job manager main language id lingpipe main article extraction diffbot article main mt http client main url main language id cld main article extraction post extractor main bing php bb scraper bb fetcher and saver main file opener main language id textcat main language data manager main language id textcat my properties main collection babel scraper edu columbia main file saver main language id textcat n gram entry comparator main log db entry main screen logging view manager main main db models blog post main twitter main bing php bb scraper bb search producer main language id textcat finger print main db dao main twitter twitter code switch s job manager main db models forum post main configuration babel config main twitter twitter code switch scraper main you tube main collection babel consumer main google google cse main collection rss scraper main twitter twitter job manager main db main language id language detector main collection babel job main collection main twitter twitter sentiment job manager main language id lingpipe munge main log db main bing php bb scraper bb post main google main twitter twitter sentiment scraper main language id result main bing php bb scraper bb job main screen logging edu main configuration main twitter twitter job manager user main language id cld cld languae detector py wrapper main configuration config from file main twitter twitter users scraper main language id cld language main bing php bb scraper bb thread main configuration twitter keys configuration main language id cld encoding main collection babel producer main twitter twitter key main db mongo db main language id cld result main twitter twitter scraper main language id cld cld hints main language id com detect language main normalization main language id com detect language detect language main normalization twitter normalizer main language id com detect language responses detect response main language id cld cld2 library main language id com detect language responses response main db models main language id com detect language responses batch detections data main db models tweet main db models db entry main language id com detect language errors api error main bing blogspot scraper bs fetcher and saver main language id com detect language responses detections data main bing blogspot scraper bs search producer main language id com detect language client main db models log entry main twitter topsy tweet main bing blogspot scraper bs broker main language id com detect language responses status response main language id main babel main main language id com detect language responses batch detect response main screen logging task logger main language id language classifier main language id language code main ted scraper main language id com detect language responses error data main bing blogspot scraper bs job main language id com detect language responses error response main utils main bing blogspot scraper bs job manager'],
#  'lsds|Crossbow': ['',
#   'imperial lsds crossbow device random imperial lsds crossbow model model iterator imperial lsds crossbow utils slotted object pool pad imperial lsds crossbow cli imperial lsds crossbow processor task processor pool imperial lsds crossbow data padded atomic long imperial lsds crossbow device random random generator imperial lsds crossbow model imperial lsds crossbow kernel dropout imperial lsds crossbow types data type imperial lsds crossbow types momentum method imperial lsds crossbow performance monitor imperial lsds crossbow kernel concat gradient imperial lsds crossbow task abstract task imperial lsds crossbow data mapped data buffer cleaner imperial lsds crossbow task imperial lsds crossbow utils mcs lock imperial lsds crossbow system conf imperial lsds crossbow model model imperial lsds crossbow types update model imperial lsds crossbow dispatcher imperial lsds crossbow utils bits imperial lsds crossbow data i data buffer imperial lsds crossbow device object ref imperial lsds crossbow types imperial lsds crossbow device the cpu imperial lsds crossbow kernel accuracy imperial lsds crossbow cli options imperial lsds crossbow types regularisation imperial lsds crossbow kernel noop imperial lsds crossbow utils queued imperial lsds crossbow imperial lsds crossbow data imperial lsds crossbow device blas imperial lsds crossbow model model manager imperial lsds crossbow kernel conf solver conf imperial lsds crossbow cli command line imperial lsds crossbow dataflow imperial lsds crossbow device imperial lsds crossbow device dataset imperial lsds crossbow kernel conf noop conf uk ac imperial lsds crossbow device blas blas imperial lsds crossbow kernel conf accuracy conf imperial lsds crossbow types dataset type imperial imperial lsds crossbow cli option imperial lsds crossbow dispatcher shuffled task imperial lsds imperial lsds crossbow execution context imperial lsds crossbow batch imperial lsds crossbow types learning rate decay policy imperial lsds crossbow result result handler imperial lsds crossbow kernel concat imperial lsds crossbow model model gradient imperial lsds crossbow dispatcher res net50 task dispatcher imperial lsds crossbow kernel pool gradient imperial lsds crossbow model model lock imperial lsds crossbow result measurement queue imperial lsds crossbow kernel conf concat conf imperial lsds crossbow types phase imperial lsds crossbow kernel inner product imperial lsds crossbow utils crossbow linked list imperial lsds crossbow kernel conf pool conf imperial lsds crossbow kernel re lu gradient imperial lsds crossbow model variable iterator imperial lsds crossbow notes imperial lsds crossbow result result collector imperial lsds crossbow model variable imperial lsds crossbow task task imperial lsds crossbow kernel conf re lu conf imperial lsds crossbow record dataset imperial lsds crossbow model initialiser imperial lsds crossbow kernel element wise op imperial lsds crossbow dispatcher i task dispatcher imperial lsds crossbow data i data buffer iterator imperial lsds crossbow core mapper imperial lsds crossbow types model access imperial lsds crossbow kernel conf element wise op conf imperial lsds crossbow kernel element wise op gradient imperial lsds crossbow model conf imperial lsds crossbow i dataset imperial lsds crossbow kernel kernel imperial lsds crossbow kernel dummy imperial lsds crossbow sub graph imperial lsds crossbow dispatcher transient task dispatcher imperial lsds crossbow kernel pool imperial lsds crossbow types handler type imperial lsds crossbow operator imperial lsds crossbow utils crossbow array list imperial lsds crossbow model local variable imperial lsds crossbow kernel soft max imperial lsds crossbow kernel noop stateless imperial lsds crossbow result test result handler imperial lsds crossbow dataset metadata imperial lsds crossbow kernel lrn gradient imperial lsds crossbow kernel conf soft max conf imperial lsds crossbow task i task imperial lsds crossbow dispatcher task dispatcher imper ...
#  'elki-project|elki': ['',
#   '',
#   'tree metrical mtreevariants mtree ids array static dbi ds colorhistogram statistics distribution weibull distribution meta external double outlier score tree metrical mtreevariants mtree m tree index projection lat lng to ecef projection tree metrical mtreevariants mktrees mkcop mk co p directory entry colorhistogram hsb histogram quadratic distance statistics duration statistics distribution estimator generalized extreme value lmm estimator spatial spatial comparable clustering cblof matrix weighted quadratic distance projected projected index clustering pairsegments cluster pair segment analysis range index statistics distribution estimator rayleigh mad estimator relation materialized relation statistics distribution poisson distribution optionhandling constraints list size constraint ids dbi ds tree metrical mtreevariants mktrees mkcop mk cop tree factory optionhandling parameters object list parameter projected pinn tree metrical mtreevariants query m tree knn by dbid statistics distribution estimator gumbel lmm estimator colorhistogram histogram intersection distance tree metrical mtreevariants mktrees mkcop mk co p tree index relation dbid view projection random projection tree metrical mtreevariants m tree entry spatial primitive distance abstract database statistics distribution estimator log normal levenberg marquardt kde estimator message formatter query range range searcher file based database connection ids set dbi ds statistics intrinsicdimensionality abid estimator output stream logger query knn knn searcher colorhistogram rgb histogram quadratic distance projected projected index$ factory statistics intrinsicdimensionality rabid estimator tree metrical mtreevariants query m tree range by object statistics distribution estimator inverse gaussian mom estimator subspace di sh error formatter statistics distribution inverse gaussian distribution tree metrical mtreevariants m tree leaf entry datastore data store listener automatic evaluation relation relation database util outlier outlier ranking evaluation statistics distribution estimator generalized pareto lmm estimator ids dbid relation convert to string view scaling linear scaling statistics distribution generalized pareto distribution relation projected view lof parallel tree metrical mtreevariants query m tree knn by object statistics intrinsicdimensionality tight lid estimator result util lof parallel lrd processor projection projection query distance distance query statistics distribution estimator inverse gaussian ml estimator proxy database trivial reference clustering ids dbid iter projected lng lat as ecef index outlier outlier roc curve statistics distribution estimator gamma choi wette estimator meta external clustering dynamic index lof parallel parallel lof datastructures heap outlier outlier precision recall gain curve ids dbid ref linearalgebra projected centroid datastructures heap heap util statistics distribution estimator cauchy mad estimator lof parallel lof processor database event manager evaluator exceptions not implemented exception statistics distribution cauchy distribution statistics intrinsicdimensionality lpca estimator projection lng lat to ecef projection outlier outlier precision at k curve tree metrical mtreevariants m tree settings datastore data store event visualizers scatterplot outlier bubble visualization trivial by label or all in one clustering tree metrical mtreevariants query m tree range by dbid anglebased statistics distribution generalized extreme value distribution ids hash set modifiable dbi ds anglebased lbabod trivial by label clustering tree index tree pearson correlation result listener statistics distribution estimator gamma lmm estimator outlier compute outlier histogram knn index lof parallel simplified lrd processor elki launcher updatable database tree metrical mtreevariants abstract m tree outlier outlier precision recall curve tree metrical mtreevariants mktrees mkmax statistics distribution estimator  ...
#  'lizhangqu|TensorflowLite': ['',
#   '',
#   '',
#   'lizhangqu lizhangqu sample main activity lizhangqu sample io io github'],
#  'viadee|javaAnchorExplainer': ['',
#   '',
#   '',
#   '',
#   'xai anchor algorithm execution xai anchor algorithm global threaded batch explainer xai anchor algorithm coverage coverage identification xai anchor algorithm coverage disabled coverage identification xai anchor algorithm execution executor service function xai anchor algorithm anchor construction xai anchor algorithm execution parallel sampling service xai anchor algorithm execution linear sampling service xai anchor algorithm exploration kl lucb de xai anchor algorithm global submodular pick utils xai anchor algorithm anchor candidate xai anchor algorithm execution abstract sampling service xai anchor algorithm exploration best anchor identification xai anchor algorithm no candidate found exception xai anchor algorithm execution sampling xai anchor algorithm exploration batch racing xai anchor algorithm execution sampling session xai anchor algorithm exploration abstract br algorithm xai anchor algorithm global reconfigurable perturbation function xai anchor algorithm execution sampling service xai anchor algorithm util kl bernoulli utils xai anchor algorithm perturbation function xai anchor algorithm coverage perturbation based coverage identification xai anchor algorithm global coverage pick xai anchor algorithm execution sampling sampling function xai anchor algorithm exploration median elimination xai anchor algorithm global abstract global explainer xai anchor algorithm data instance xai anchor algorithm global xai anchor algorithm exploration batch sar xai anchor algorithm global global explainer xai anchor algorithm execution executor service supplier xai anchor algorithm util xai anchor algorithm anchor result xai anchor algorithm classification function xai anchor algorithm coverage xai anchor algorithm global modified submodular pick xai anchor algorithm exploration xai anchor algorithm execution sampling default sampling function de viadee xai anchor algorithm anchor construction builder xai anchor xai xai anchor algorithm global batch explainer xai anchor algorithm xai anchor algorithm util math utils xai anchor algorithm util parameter validation xai anchor algorithm global submodular pick xai anchor algorithm execution balanced parallel sampling service'],
#  'tgsmith61591|clust4j': ['',
#   '',
#   '',
#   '',
#   '',
#   'com data iris loader kernel spline kernel algo base neighbors model$ base neighbors planner com clust4j optimize bracket metrics pairwise boolean similarity utils parallel map matrix map task data example data sets except optimize brent downhill optimizer except na n exception metrics pairwise similarity algo hdbscan algo abstract autonomous clusterer data wine loader optimize base downhill optimizer except illegal cluster state exception metrics scoring unsupervised metric algo preprocess except matrix parse exception algo preprocess box cox transformer algo base clusterer parameters algo metric validator metrics pairwise pairwise sample algo dbscan except model not fit exception algo parallel chunking task sample sampler algo abstract dbscan algo dbscan parameters algo pipeline kernel cauchy kernel algo convergeable planner except non uniform matrix exception named entity algo pipeline pipeline algo preprocess transformer kernel radial basis kernel algo hdbscan parameters algo nearest centroid parameters utils algo base classifier parameters sample bootstrapper algo preprocess yeo johnson transformer utils entry pair kernel exponential kernel algo nearest centroid algo boruvka algorithm clust4j kernel laplacian kernel utils array formatter algo preprocess min max scaler algo noisey label encoder algo preprocess impute algo affinity propagation utils table formatter algo preprocess impute matrix imputation algo pipeline supervised pipeline kernel multiquadric kernel algo kd tree metrics scoring algo preprocess median centerer algo model summary algo safe label encoder utils synchronicity lock algo preprocess pre processor kernel constant kernel metrics scoring supervised metric algo noisey clusterer utils mat utils algo abstract clusterer kernel min kernel algo convergeable algo supervised classifier parameters utils parallel map distributed matrix multiplication metrics scoring evaluation metric algo base model algo radius neighbors kernel kernel algo supervised classifier algo centroid learner utils series algo preprocess impute central tendency method algo preprocess robust scaler kernel gaussian kernel utils vec utils algo affinity propagation parameters algo radius neighbors parameters algo pipeline unsupervised pipeline algo preprocess impute median imputation kernel log kernel algo unsupervised classifier utils matrix formatter algo preprocess pca kernel power kernel algo preprocess impute nearest neighbor imputation algo unsupervised classifier parameters algo base neighbors model global state algo preprocess mean centerer algo neighborhood algo label encoder metrics pairwise geometrically separable algo pipeline neighbors pipeline kernel generalized min kernel utils quad tup algo preprocess weight transformer algo nearest neighbor heap search algo nearest neighbors parameters algo neighbors classifier parameters algo abstract partitional clusterer utils simple heap kernel inverse multiquadric kernel algo abstract density clusterer algo preprocess standard scaler algo ball tree utils deep cloneable metrics pairwise distance kernel spherical kernel utils parallel algo nearest neighbors kernel circular kernel algo base classifier log data log loggable algo preprocess impute bootstrap imputation kernel log log timer algo k medoids parameters algo data buffered matrix reader kernel rational quadratic kernel algo k medoids log log properties metrics algo preprocess impute mean imputation algo abstract dbscan$ abstract dbscan parameters log timer kernel hyperbolic tangent kernel algo mean shift parameters data data set algo k means parameters log log time formatter metrics pairwise utils parallel matrix mr task algo mean shift kernel anova kernel algo centroid clusterer parameters metrics pairwise similarity metric data breast cancer loader utils parallel map algo abstract centroid clusterer log log kernel linear kernel data train test split metrics pairwise minkowski distance utils parallel map dual matrix map task algo ...
#  'vinhkhuc|lbfgs4j': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com lbfgs4j liblbfgs arithmetic lbfgs4j liblbfgs function lbfgs4j liblbfgs lbfgs com github lbfgs4j lbfgs minimizer lbfgs4j liblbfgs mutable double lbfgs4j liblbfgs lbfgs constant lbfgs4j liblbfgs lbfgs4j'],
#  'sbl-sdsc|mmtf-spark': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'mmtf spark ml demos edu mmtf spark mappers structure to bioassembly2 mmtf spark interactions demos polymer interaction fingerprint demo mmtf spark ml demos secondary structure property encoder mmtf spark filters experimental methods mmtf spark webfilters chemical structure query mmtf spark filters demos filter by r free mmtf spark ml protein sequence encoder mmtf spark filters contains d protein chain mmtf spark webfilters demos keyword search mmtf spark interactions demos analyze water interactions4 mmtf spark webfilters pdbj mine search mmtf spark mappers structure to polymer chains mmtf spark filters demos filter exclusively by l proteins mmtf spark datasets pdbj mine dataset mmtf spark utils mmtf spark filters contains group mmtf spark webfilters demos sequence similarity demo mmtf spark applications mmtf spark io mmtf reader mmtf spark utils structure to all interactions mmtf spark filters demos filter protein dna complexes mmtf spark filters deposition date mmtf spark datasets secondary structure segment extractor mmtf spark webfilters wild type mmtf spark webfilters demos wild type query mmtf spark utils coordination geometry mmtf spark alignments demos demo all vs all mmtf spark filters contains d saccharide chain mmtf spark webfilters pisces mmtf spark filters demos filter by deposition date mmtf spark webfilters demos mmtf spark utils interaction center mmtf spark webfilters demos kinase search mmtf spark filters contains l protein chain mmtf spark alignments demos demo query vs all mmtf spark utils columnar structure mmtf spark interactions mmtf spark ml demos secondary structure word2 vec encoder mmtf spark filters demos filter by sequence regex mmtf spark webfilters demos author search demo mmtf spark interactions polymer interaction fingerprint mmtf spark filters secondary structure mmtf spark utils columnar structure x mmtf spark filters demos filter by polymer chain type mmtf spark datasets demos uni prot demo mmtf spark ml demos secondary structure word2 vec model encoder mmtf spark filters contains alternative locations mmtf spark webfilters demos create representative set mmtf spark interactions excluded ligand sets mmtf spark utils dssp secondary structure mmtf spark filters rfree mmtf spark datasets demos pdb to uni prot mapping demo mmtf spark filters demos not filter example mmtf spark utils biojava aligner mmtf spark mappers mmtf spark ml demos secondary structure one hot encoder mmtf spark interactions ligand interaction fingerprint mmtf spark filters demos mmtf spark datasets demos mutation to structure demo mmtf spark utils outlier detector mmtf spark filters demos filter by groups mmtf spark alignments mmtf spark ml demos secondary structure blosum62 encoder mmtf spark utils atom interaction mmtf spark datasets demos drug bank demo mmtf spark alignments structure aligner mmtf spark filters demos filter by release date mmtf spark ml mmtf spark mappers structural alignment mapper mmtf spark mappers structure to interacting residues mmtf spark datasets demos dssp demo mmtf spark utils exhaustive aligner mmtf spark ml demos secondary structure shifted word2 vec encoder mmtf spark ml sequence ngrammer mmtf spark filters demos filter by experimental methods mmtf spark utils structure to atom interactions mmtf spark alignments demos mmtf spark datasets demos secondary structure segment demo mmtf spark ml spark regressor mmtf spark ml demos secondary structure elements word2 vec encoder mmtf spark filters demos filter by resolution mmtf spark datasets mmtf spark io demos pdb to mmtf full mmtf spark ml java rdd to dataset mmtf spark datasets advanced search dataset mmtf spark datasets demos atp interaction analysis mmtf spark datasets secondary structure element extractor mmtf spark mappers demos mmtf spark io mmtf spark io demos read mmtf reduced mmtf spark ml dataset classifier mmtf spark mappers demos map to bio java mmtf spark io repartition hadoop sequence file mmtf spark ml spark multi class classif ...
#  'CeON|CERMINE': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'icm cermine libsvm training icm cermine libsvm parameters metadata classifier parameter finder icm cermine evaluation segmentation evaluator icm cermine tools classification clustering feature vectors normalizer icm cermine parsing tools nlm parsable string extractor icm cermine libsvm training svm initial builder icm cermine metadata zoneclassification features word count feature icm cermine structure model bx document icm cermine parsing tools token classifier icm cermine tools classification clustering single linkage clusterizer icm cermine tools classification svm svm classifier icm cermine structure tools unsegmented pages flattener icm cermine tools classification general feature vector builder icm cermine metadata zoneclassification features dot count feature icm cermine libsvm parameters initial classifier parameter finder icm cermine tools bx doc utils icm cermine bibref model bib entry field icm cermine evaluation transformers icm cermine structure tools icm cermine metadata zoneclassification features line width mean feature icm cermine exception analysis exception icm cermine metadata icm cermine bibref model bib entry type icm cermine metadata enhancer metadata extractor icm cermine structure tools document processor icm cermine structure svm initial zone classifier icm cermine evaluation systems icm cermine metadata extraction enhancers editor enhancer icm cermine metadata zoneclassification features starts with header feature icm cermine tools classification general bx docs to training samples converter icm cermine parsing icm cermine metadata zoneclassification tools zone classification utils icm cermine bibref parsing features icm cermine evaluation transformers grobid to metadata converter icm cermine metadata extraction enhancers journal enhancer icm cermine structure tools unclassified zones preprocessor icm cermine tools classification general penalty calculator icm cermine parsing tools icm cermine bibref parsing model icm cermine metadata extraction enhancers urn enhancer icm cermine tools classification svm svm zone classifier icm cermine metadata zoneclassification features at relative count feature icm cermine parsing features icm cermine parsing features is rare feature icm cermine evaluation transformers element to bib entry converter icm cermine structure tools bx zone tree icm cermine metadata extraction enhancers enhancer icm cermine structure model bx page icm cermine metadata extraction icm cermine structure tools bx zone order tuple icm cermine parsing features binary token feature calculator icm cermine metadata extraction enhancers accepted date enhancer icm cermine metadata extraction enhancers icm cermine tools classification general training sample icm cermine metadata zoneclassification features word length median feature icm cermine evaluation transformers bwmeta to metadata converter icm cermine structure tools classification transfer icm cermine metadata extraction enhancers journal year volume enhancer icm cermine parsing features is upper case feature icm cermine structure model bx zone icm cermine tools classification general icm cermine metadata zoneclassification features y position feature icm cermine metadata extraction enhancers author affiliation splitter enhancer icm cermine structure model bx zone label icm cermine evaluation transformers grobid to content converter icm cermine tools classification svm icm cermine parsing features is non alphanum feature icm cermine metadata extraction enhancers journal volume pages enhancer icm cermine libsvm training svm metadata builder icm cermine metadata zoneclassification features is last page feature icm cermine tools classification sampleselection icm cermine metadata extraction enhancers revised form date enhancer icm cermine evaluation transformers grobid to document reader icm cermine parsing features is all lower case feature icm cermine structure model bx zone label category icm cermine metadata model icm cermine structure  ...
#  'lejon|PartiallyCollapsedLDA': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'configuration similarity lda likelihood distance topics tui bm25 search util index sampler configuration lda train test configuration topics sparse hdp sampler similarity bm25 distance util lda thread factory configuration lda configuration similarity jaccard distance similarity corpus statistics topics adlda similarity distance configuration lda command line parser util sparsity tools configuration parsed lda train test configuration similarity multi instance distance wrapper topics my worker runnable util xor shift random similarity instance distance wrapper configuration configuration topics randomscan document even split batch builder topics type topic parallel table builder util lda dataset string loading utils similarity vectorizer configuration parsed lda configuration topics randomscan document document batch builder util string class array iterator similarity trained distance topics randomscan document fixed split batch builder configuration model factory util eclipse detector topics tui iteration listener similarity kl distance util re mapped alias table topics randomscan document percentage batch builder topics lda gibbs sampler topics lda sampler with callback util int array sort utils topics randomscan document adaptive batch builder similarity t distance topics lda sampler continuable configuration sub config util logging utils similarity stat obj configuration lda train test command line parser types topics uncollapsed lda doc sampling context similarity bhattacharyya distance types polya urn dirichlet fixed coeff poisson configuration parsed remote lda configuration similarity statistical distance pipe keep connector punctuation tokenizer large types sparse dirichlet configuration lda remote configuration topics lda doc sampling result dense topics polya urn spalias lda types poisson fixed coeff sampler similarity instance distance topics marginal prob estimator plain types vs result configuration simple lda configuration pipe numeric also tokenizer util lda logging utils types polya urn dirichlet pipe keep connector punctuation numeric also tokenizer topics collapsed light lda util lda null logger types default sparse dirichlet sampler builder util parallel randoms types standard args dirichlet builder similarity token occurence vectorizer configuration config factory util index sorter topics table builder factory types sparse dirichlet sampler builder util without replacement sampler topics randomscan topic topic batch builder factory similarity symmetric kl distance topics light pcld atype topic proposal util perplexity dataset builder topics randomscan topic topic index builder factory types conditional dirichlet similarity manhattan distance types parallel dirichlet topics randomscan document batch builder factory util gentle alias method similarity hellinger distance pipe types variable selection dirichlet similarity jensen shannon distance topics light pclda types variable selection result topics randomscan topics randomscan document topics tui topics efficient uncollapsed parallel lda topics randomscan topic similarity kolmogorov smirnov distance topics tui document similarity classify types polya urn dirichlet sampler builder similarity continous jaccard distance similarity cosine distance classify kl divergence classifier types marsaglia sparse dirichlet topics spalias uncollapsed parallel lda similarity document distancer similarity canberra distance util lda utils similarity token index vectorizer classify evaluate enhanced confusion matrix similarity likelihood distance types binomial sampler similarity lda distancer similarity token frequency vectorizer topics serial collapsed lda topics lda sampler with phi types polya urn fixed coeff poisson dirichlet sampler builder topics tui lda similarity classify kl divergence classifier multi corpus similarity tf idf vectorizer topics poisson polya urn hdplda infinite topics types vs dirichlet classify evaluate similarity chebychev distance cc types sim ...
#  'klevis|CatAndDogRecognizer': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ramo klevis run ramo'],
#  'grouplens|samantha': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'samantha server indexer samantha server expander generic filter expander samantha server indexer redis based indexer samantha server ranker ranker samantha server tensorflow tensor flow predictor config samantha server dao entity dao config samantha modeler metric recall samantha server io request context samantha server ranker ranked result samantha server expander sql based join expander samantha server config config key samantha server common utilities samantha server dao request item id list dao config samantha server recommender recommender samantha server predictor svd feature predictor config samantha modeler metric mae samantha server indexer abstract indexer samantha modeler tensorflow tensor flow model producer samantha server recommender standard recommender config samantha server expander array item id2 info expander samantha server common json helpers samantha server common item id2 info model manager samantha server recommender recommender config samantha server ranker samantha server common data operation samantha server ranker field blending ranker samantha server dao request entity dao samantha server common redis service samantha server expander redis based join expander samantha server tensorflow tensor flow batch indexer config samantha server config samantha config service samantha server dao indexer based dao config samantha server ranker abstract ranker samantha modeler model space model samantha server ranker ranker utilities samantha server expander english term frequency expander samantha server indexer null indexer config samantha server predictor linear ucb predictor config samantha server dao csv file dao config samantha server tensorflow tensor flow based retriever config samantha server indexer indexer config samantha server ranker predictor based ranker samantha server indexer indexer controllers samantha server dao json file dao config samantha server expander display2 action expander controllers EngineHandlers samantha server indexer null indexer samantha server evaluator metric ndcg config samantha server ranker percentile blending ranker config samantha server predictor predictor samantha server predictor field blending predictor config samantha server dao csv dir dao config samantha server expander negative sampling expander samantha server ranker percentile blending ranker samantha server indexer grouped indexer samantha server predictor prediction samantha server evaluator metric recall config samantha server predictor field blending predictor samantha server retriever retriever utilities samantha server evaluator evaluation samantha server ranker ranker config samantha server dao json file list dao config samantha samantha server evaluator metric rmse config samantha server predictor sync featurized learning data samantha modeler dao entity dao samantha server evaluator evaluator samantha server samantha server indexer indexer utilities samantha server ranker entity field ranker samantha server xgboost samantha server evaluator metric map config samantha server dao cat dao config samantha server io response packer samantha modeler dao csv file dao samantha server xgboost xg boost classifier retriever samantha server io request parser samantha server exception bad request exception samantha server ranker field blending ranker config samantha server dao csv file list dao config samantha server evaluator metric mae config samantha server retriever abstract retriever controllers AdminHandlers samantha modeler featurizer feature extractor utilities samantha server predictor regression tree predictor config samantha server xgboost xg boost classifier retriever config samantha server evaluator metric auc config samantha server dao es based dao config samantha server dao entity dao utilities samantha modeler featurizer constant one extractor samantha server common abstract component config samantha server io io utilities samantha server evaluator metric precision config samantha server ranker ...
#  'o19s|RankyMcRankFace': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ciir edu learning tree mart edu learning boosting weak ranker edu learning ranker trainer edu features feature manager ciir umass edu learning tree regression tree edu learning combiner edu learning coor ascent edu features normalizer edu eval edu features edu eval analyzer edu learning tree ensemble edu learning data point edu learning edu stats random permutation test edu utilities merge sorter edu learning sampler edu learning neuralnet layer edu learning dense data point edu parsing edu utilities rank lib error edu learning neuralnet prop parameter edu learning linear reg rank edu parsing model line producer edu learning boosting edu utilities simple math edu learning neuralnet list neuron edu features linear normalizer edu edu learning neuralnet edu utilities sorter edu utilities file utils edu learning ranker type edu metric edu learning tree edu learning sparse data point edu eval evaluator edu metric metric scorer factory edu utilities edu metric best at k scorer edu metric metric scorer edu learning neuralnet synapse edu learning tree rf ranker edu utilities key value pair edu stats edu utilities worker thread edu learning neuralnet neuron edu metric dcg scorer edu learning neuralnet logi function edu learning neuralnet rank net edu utilities my thread pool edu utilities tmp file edu learning neuralnet transfer function edu stats basic stats edu metric err scorer edu metric reciprocal rank scorer edu features sum normalizor edu utilities expression evaluator edu stats significance test edu learning ranker factory edu metric metric edu metric precision scorer edu features z score normalizor edu metric ap scorer edu learning boosting rank boost edu learning neuralnet lambda rank edu learning tree lambda mart edu learning tree feature histogram edu learning boosting rb weak ranker edu learning neuralnet hyper tangent function edu metric ndcg scorer edu learning tree split edu learning neuralnet list net edu learning rank list edu learning boosting ada rank edu learning ranker'],
#  'tahaemara|arabic-characters-recognition': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com arabic char recogntion model generator com emaraic arabic char recogntion test model arabic char recogntion'],
#  'amidst|toolbox': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'core variables state space types core learning parametric ecml2016 dynamic map inference experiments1 core variables state space types finite state space core potential core inference map inference core learning parametric learning engine ida2015 learning vmp tests core variables state space type enum core utils bayesian network sampler core variables core learning parametric parallel maximum likelihood ecml2016 dynamic map inference experiments2 core variables state space type core datastream core distribution core inference point estimator core variables state space types real state space core learning ecml2016 hidden layer dynamic model core conceptdrift dynamic variables dynamic inference dynamic variables dynamic variables dynamic inference dynamic vmp core variables variable core inference mpe inference dynamic learning dynamic dynamic naive bayes classifier ecml2016 comparison to hugin experiments core datastream attributes core learning parametric bayesian core datastream batches spliterator ida2015 script aggregate per years core variables distribution type core datastream data on memory list container dynamic inference inference engine for dbn ecml2016 temperature humidity dynamic model core variables variable builder core inference sampler core variables distribution type enum core utils fixed batch parallel spliterator wrapper dynamic inference factored frontier for dbn core datastream attribute core inference messagepassing ecml2016 comparison to hugin ida2015 script add indicators core utils key compound vector cajamareval dynamic variables dynamic assignment core datastream filereaders cajamareval test arff core variables assignment flinklink core io cajamareval clients evaluation flinklink core io data set serializer dynamic variables hash map dynamic assignment core utils reservoir sampling ida2015 script remove instances with missing dynamic datastream data sequence flinklink core io data flink loader ecml2016 hidden layer strongly correlated dynamic model core utils utils core datastream filereaders data instance from data row cajamareval naive bayes eval core utils dag generator flinklink core conceptdrift model experiments identifiable idauai model local hidden cajamareval wrapper fs dynamic inference dynamic map inference flinklink core conceptdrift ida concept drift detector core datastream filereaders arff file reader arff data reader model experiments obtain gaussian mixtures core distribution normal ecml2016 sequence recovery experiments core datastream filereaders arff file reader data row weka core variables missing assignment core models dag core utils amidst options handler static flinklink core data data flink converter core learning parametric parallel ml missing data flinklink core data data flink model experiments mixture model distributed svi ecml2016 temperature humidity experiments flinklink core io data flink writer core learning parametric bayesian plateu structure cajamareval main core datastream filereaders arff file reader arff data writer core conceptdrift utils model experiments parse output core models bayesian network ecml2016 dynamic map ijcai 1 cajamareval parallel tan eval model experiments identifiable idauai model core conceptdrift utils gaussian hidden transition method flinklink core learning parametric huginlink learning parallel tan flinklink core learning parametric d vm pv1 core datastream data instance model experiments da gs generation core conceptdrift utils plateu hidden variable concept drift core utils compound vector huginlink io dbn loader from hugin core io bayesian network writer flinklink core learning parametric parallel vb huginlink io dbn writer to hugin core learning parametric bayesian data posterior flinklink core conceptdrift identifiable ida model core conceptdrift utils fading model experiments evaluate auc cajamareval cs vto arff header ecml2016 dynamic map inference experiments core variables variables core exponentialfamily parameter variables c ...
#  'viadee|camunda-kafka-polling-client': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'camunda kafka pollingclient service camunda kafka pollingclient service polling rest camunda rest polling service impl camunda kafka event detail event camunda kafka pollingclient service polling rest camunda kafka pollingclient service polling camunda kafka pollingclient camunda kafka pollingclient config properties camunda rest polling properties camunda kafka pollingclient service event camunda kafka event scope instance event camunda kafka event comment event camunda kafka pollingclient service lastpolled camunda kafka pollingclient config camunda jdbc polling configuration camunda kafka pollingclient config properties polling properties camunda kafka pollingclient config camunda kafka event activity instance event camunda kafka pollingclient service polling jdbc camunda jdbc polling service impl camunda kafka pollingclient config repository data polling configuration camunda kafka event identity link event camunda kafka pollingclient config properties camunda jdbc polling properties camunda kafka pollingclient job repository repository data polling job camunda kafka event deployment event camunda kafka event variable update event camunda kafka pollingclient service polling polling service camunda kafka pollingclient config properties camunda kafka pollingclient service polling jdbc camunda kafka event process instance event camunda kafka pollingclient config properties application properties camunda kafka pollingclient service polling rest response camunda kafka pollingclient service polling rest response get identity link response camunda kafka event process definition event camunda kafka pollingclient service lastpolled last polled service camunda kafka pollingclient service polling rest response get historic process instance response camunda kafka pollingclient service lastpolled polling timeslice camunda kafka pollingclient service lastpolled filebased filebased last polled service impl camunda camunda kafka pollingclient service polling rest response get process definition response camunda kafka pollingclient service event event service camunda kafka camunda kafka pollingclient service polling rest response get deployment response camunda kafka pollingclient service event kafka camunda kafka pollingclient job repository repository data polling service camunda kafka pollingclient job camunda kafka pollingclient service event kafka kafka event service impl camunda kafka pollingclient service polling rest response get historic variable instances response camunda kafka pollingclient job runtime camunda kafka pollingclient config runtime data polling configuration camunda kafka pollingclient service polling rest response get historic activity instance respone camunda kafka pollingclient job repository camunda kafka pollingclient polling client application camunda kafka pollingclient job runtime runtime data polling service camunda kafka pollingclient service polling rest response get historic detail variable update response camunda kafka event camunda kafka pollingclient service lastpolled filebased camunda kafka event incident event camunda kafka pollingclient job runtime runtime data polling job camunda kafka pollingclient service polling rest response get comment response de camunda kafka event history event de viadee camunda kafka pollingclient service polling rest response get process definition xml response camunda kafka pollingclient config camunda rest polling configuration'],
#  'tony-framework|TonY': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'xgboost tree xgboost spark xgboost gbm biz k11i xgboost gbm gb linear xgboost tree reg tree xgboost spark spark model param xgboost config xgboost util f vec xgboost gbm dart xgboost xgboost config predictor configuration xgboost gbm gb base xgboost util model reader xgboost learner xgboost util f vec map impl xgboost predictor xgboost gbm gb tree xgboost learner obj function xgboost util xgboost gbm grad booster biz xgboost util f vec array impl'],
#  'klevis|DigitRecognizer': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cnn nn ramo klevis cnn convolution ui ui cnn lenet mnist example run data idx reader cnn accuracy calculator cnn edge detection nn neural network ramo cnn convolutional neural network ui draw area ui data data labeled image ui progress bar'],
#  'vishnugh|evo-NEAT': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com neat environment neat innovation counter neat com evo neat com evo neat pool neat node gene neat examples neat com evo neat config neat connection gene examples XOR neat species neat com neat genome neat com evo neat config neat config neat com evo'],
#  'viadee|bpmn.ai': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'bpmnai core configuration util bpmnai core listener bpmnai core configuration modelprediction model configuration bpmnai core configuration util configuration utils bpmnai core processing steps importing columns preparation step bpmnai core processing bpmnai core listener spark runner listener bpmnai core configuration configuration bpmnai core configuration modelprediction prediction column configuration bpmnai core configuration preprocessing variable configuration bpmnai core exceptions ki kafka test app bpmnai core configuration preprocessing preprocessing configuration ki bpmnai core runner ki kafka test app app bpmnai core configuration modellearning model learning configuration bpmnai core runner impl bpmnai core configuration ki snapshot bpmnai core configuration preprocessing bpmnai core runner impl kafka processing prediction service runner bpmnai core runner spark runner bpmnai core util logging bpmnai core configuration preprocessing pipeline step configuration bpmnai core configuration dataextraction bpmnai core runner spark prediction service runner bpmnai core configuration modelprediction model prediction configuration bpmnai core processing steps userconfig bpmnai core configuration preprocessing variable name mapping bpmnai core processing steps dataprocessing type cast step bpmnai core processing steps userconfig data filter on activity step bpmnai core configuration dataextraction data extraction configuration bpmnai core configuration preprocessing column configuration bpmnai core util helper spark broadcast helper bpmnai core processing steps dataprocessing column hash step bpmnai core util helper bpmnai core runner config spark runner config bpmnai core configuration preprocessing column hash configuration bpmnai core util logging bpmnai logger bpmnai core processing steps dataprocessing create columns from json step bpmnai core util bpmnai utils bpmnai core annotation bpmnai core processing steps bpmnai core annotation preprocessing step parameter bpmnai core processing steps pipeline manager bpmnai core processing steps output write to data sink step bpmnai core annotation preprocessing step parameters bpmnai core exceptions no data importer defined exception bpmnai core processing steps pipeline step ki snapshot app bpmnai core processing steps dataprocessing determine process variables step bpmnai core annotation preprocessing step description ki snapshot check approved step bpmnai core processing steps parameter definition bpmnai core processing steps dataprocessing add variable columns step bpmnai core annotation preprocessing step bpmnai core processing steps dataprocessing column remove step bpmnai core annotation annotation collector test bpmnai core processing interfaces preprocessing step interface bpmnai core configuration preprocessing step bpmnai core processing steps dataprocessing reduce columns step bpmnai core processing steps pipeline step collector bpmnai core processing steps output bpmnai core processing steps dataprocessing aggregate process instances step bpmnai core processing steps pipeline step definition bpmnai core processing steps importing bpmnai core processing steps dataprocessing data filter step bpmnai core processing aggregation bpmnai core processing steps dataprocessing bpmnai core processing steps output write to disc step bpmnai core processing aggregation process states aggregation function bpmnai core util arguments bpmnai core util bpmnai variables bpmnai core util arguments kafka import arguments bpmnai core processing steps dataprocessing add reduced columns to dataset step bpmnai core util arguments abstract arguments bpmnai core processing aggregation all but empty string aggregation function bpmnai core bpmnai core kafka import application bpmnai core processing steps dataprocessing aggregate activity instances step bpmnai core util arguments csv import and processing arguments bpmnai core runner impl kafka import runner bpmnai core processing steps data ...
#  'girishpai|NumTrans': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com ml r trees core mat of int photo photo com udacity video background subtractor knn calib3d android utils core key point video background subtractor photo calibrate debevec calib3d calib3d ml ann mlp imgcodecs imgcodecs core core core mat photo merge mertens ml ml core mat of double photo tonemap reinhard video video core mat of float ml svm utils converters photo tonemap durand android fps meter core mat of point2f core mat of int4 photo tonemap mantiuk video background subtractor mog2 android open cv loader core size utils photo calibrate robertson android async service helper core rect core mat of float4 videoio video capture photo calibrate crf core mat of point3f core mat of point mlndcapstone numtrans videoio videoio core term criteria imgproc mlndcapstone numtrans io utils videoio video writer core point core mat of point3 imgproc line segment detector mlndcapstone numtrans application test calib3d stereo bm mlndcapstone numtrans main activity imgproc clahe features2d features2d core algorithm mlndcapstone numtrans digit detector calib3d stereo matcher imgproc moments features2d feature detector mlndcapstone numtrans image processor core cv exception org opencv core mat of rect mlndcapstone numtrans roi object features2d descriptor matcher calib3d stereo sgbm imgproc subdiv2 d features2d descriptor extractor core core mat of key point mlndcapstone numtrans number to word conv objdetect core range org video core mat of d match android mlndcapstone videoio core cv type android base loader callback ml imgcodecs features2d android loader callback interface core d match ml train data android install callback interface photo ml em core mat of float6 photo merge robertson objdetect hog descriptor android static helper ml stat model photo merge exposures android camera gl surface view core scalar ml normal bayes classifier objdetect objdetect android camera2 renderer photo merge debevec android camera gl renderer base objdetect cascade classifier ml logistic regression core rotated rect photo tonemap drago android camera renderer photo tonemap objdetect base cascade classifier ml k nearest core point3 android camera bridge view base photo align exposures core mat of byte video dual tvl1 optical flow ml boost video dense optical flow android java camera view ml d trees photo align mtb imgproc imgproc video kalman filter'],
#  'rahul-raj|Deeplearning4J': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'examples examples Test services CustomerLossPredictionService examples DataSetIteratorSplitter examples HyperParamTuning examples CustomerLossPrediction services impl examples AnimalClassifier customer loss prediction service impl examples SantanderValuePrediction services'],
#  'cookiengineer|lycheejs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'internal nativeintegration internal classloader default class loader factory internal tri action api internal artifacts ivyservice ivyresolve module component resolve state tooling internal protocol internal connection internal nativeintegration native integration exception tooling model gradle task api internal default class path registry internal resource abstract external resource nativeplatform toolchain internal compilespec objective c compile spec internal nativeintegration native integration unavailable exception api file empty file visitor internal classloader mutable url class loader tooling model model tooling model project dependency nativeplatform toolchain internal compilespec objective cpch compile spec api internal artifacts ivyservice ivyresolve base module component repository internal nativeintegration reflective environment internal classloader class loader factory api file unable to delete file exception tooling build controller internal resolve internal os operating system api internal artifacts ivyservice ivyresolve dynamic version resolver language objectivec internal default objective c source set nativeplatform internal pch api file copy source spec internal resource transfer internal resource language nativeplatform internal abstract header exporting dependent source set internal resolve module version not found exception internal nativeintegration process environment tooling model build internal id nativeplatform internal pch default pre compiled header transform container tooling internal protocol configurable connection internal resolve result buildable component selection result internal nativeintegration processenvironment nativeplatform toolchain internal tools tooling model eclipse internal nativeplatform internal nativeintegration console nativeplatform toolchain internal tools gcc command line tool configuration internal api publish ivy tooling provider internal jacoco internal nativeintegration jna nativeplatform toolchain gcc command line tool configuration internal resolve result default buildable component selection result tooling provider model internal nativeintegration services api publish ivy ivy publication foundation common internal graph nativeplatform toolchain internal tool type internal classloader class loader hierarchy internal resolve result resource aware resolve result tooling internal consumer connection connection version4 backed consumer connection api publish ivy ivy module descriptor spec internal nativeintegration filesystem foundation common list reorderer internal classloader class loader visitor api reporting dependencies internal nativeplatform toolchain internal tools tool search path internal classloader internal resolve result default buildable module component meta data resolve result tooling internal build version only build environment api publish ivy ivy artifact set api reporting dependencies internal strict dependency result spec internal classloader class loader spec nativeplatform toolchain internal tools command line tool search result internal util tooling internal protocol eclipse eclipse project dependency version2 internal resolve result default buildable module version listing resolve result api artifacts component component selector api publish ivy ivy configuration container internal operations tooling internal protocol eclipse hierarchical eclipse project version1 tooling internal consumer converters build invocations converter api specs spec nativeplatform toolchain internal tools command line tool configuration internal api internal artifacts ivyservice ivyresolve component selection rules processor nativeplatform internal resolve default project locator internal text tooling internal protocol eclipse eclipse linked resource version1 api artifacts component component identifier nativeplatform toolchain command line tool configuration api publish ivy ivy extra info spec internal typeconversion api internal artifacts component selection inte ...
#  'alipay|jpmml-sparkml-lightgbm': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sparkml sparkml lightgbm sparkml lightgbm light gbm classification model converter org org jpmml sparkml lightgbm booster util']}

# %%
with open("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/java_stopwords", 'rt') as inf:
    java_stopwords = {x.strip() for x in inf.readlines()}

# %%
java_stopwords.update(['get', 'set', 'org', 'com', 'exception', 'override', 'java', 'string',
                       'list', 'util', 'value', 'length', 'println'])

# %%
import yake
kw_extractor = yake.KeywordExtractor(n=1, stopwords=java_stopwords, top=50)
extracted_kw = {}

# %%
for project in content:
   extracted_kw[project] = kw_extractor.extract_keywords(" ".join(content[project]).lower().strip())

# %%
from collections import Counter

counter = Counter()
for p in extracted_kw:
    terms = [x[0] for x in extracted_kw[p]]
    counter.update(terms)

# %%
counter.most_common()
# Out:
# [('data', 41),
#  ('model', 40),
#  ('test', 29),
#  ('result', 21),
#  ('function', 21),
#  ('tree', 20),
#  ('feature', 20),
#  ('config', 20),
#  ('main', 19),
#  ('service', 19),
#  ('classifier', 19),
#  ('type', 17),
#  ('activity', 17),
#  ('example', 17),
#  ('factory', 16),
#  ('impl', 16),
#  ('configuration', 14),
#  ('file', 14),
#  ('core', 14),
#  ('text', 13),
#  ('filter', 13),
#  ('base', 13),
#  ('response', 12),
#  ('task', 12),
#  ('application', 12),
#  ('helper', 12),
#  ('image', 12),
#  ('api', 12),
#  ('client', 11),
#  ('random', 11),
#  ('node', 11),
#  ('object', 10),
#  ('loss', 10),
#  ('linear', 10),
#  ('instance', 10),
#  ('matrix', 10),
#  ('stream', 10),
#  ('functions', 10),
#  ('handler', 9),
#  ('distance', 9),
#  ('vector', 9),
#  ('classification', 9),
#  ('metric', 9),
#  ('loader', 9),
#  ('flow', 9),
#  ('info', 9),
#  ('services', 9),
#  ('parser', 9),
#  ('view', 9),
#  ('context', 9),
#  ('models', 8),
#  ('error', 8),
#  ('search', 8),
#  ('parameter', 8),
#  ('algorithm', 8),
#  ('spark', 8),
#  ('analysis', 8),
#  ('reader', 8),
#  ('learning', 8),
#  ('request', 8),
#  ('app', 8),
#  ('adapter', 8),
#  ('input', 8),
#  ('language', 7),
#  ('logging', 7),
#  ('variable', 7),
#  ('split', 7),
#  ('parallel', 7),
#  ('github', 7),
#  ('builder', 7),
#  ('map', 7),
#  ('extractor', 7),
#  ('features', 7),
#  ('evaluation', 7),
#  ('evaluator', 7),
#  ('tokenizer', 7),
#  ('server', 7),
#  ('tensor', 7),
#  ('json', 7),
#  ('stats', 7),
#  ('point', 7),
#  ('eval', 7),
#  ('regression', 7),
#  ('generator', 7),
#  ('examples', 7),
#  ('output', 7),
#  ('instrumented', 7),
#  ('sentence', 7),
#  ('trees', 7),
#  ('name', 7),
#  ('attribute', 7),
#  ('job', 6),
#  ('manager', 6),
#  ('log', 6),
#  ('and', 6),
#  ('batch', 6),
#  ('cluster', 6),
#  ('sample', 6),
#  ('parameters', 6),
#  ('metrics', 6),
#  ('label', 6),
#  ('converter', 6),
#  ('train', 6),
#  ('predictor', 6),
#  ('common', 6),
#  ('thread', 6),
#  ('trainer', 6),
#  ('merge', 6),
#  ('network', 6),
#  ('event', 6),
#  ('driver', 6),
#  ('provider', 6),
#  ('rule', 6),
#  ('prediction', 6),
#  ('neural', 6),
#  ('user', 6),
#  ('graph', 6),
#  ('resource', 6),
#  ('wrapper', 6),
#  ('action', 6),
#  ('learner', 6),
#  ('kernel', 5),
#  ('dataset', 5),
#  ('processor', 5),
#  ('distribution', 5),
#  ('clustering', 5),
#  ('similarity', 5),
#  ('array', 5),
#  ('execution', 5),
#  ('math', 5),
#  ('optimizer', 5),
#  ('sequence', 5),
#  ('vec', 5),
#  ('simple', 5),
#  ('run', 5),
#  ('boosting', 5),
#  ('entity', 5),
#  ('scorer', 5),
#  ('net', 5),
#  ('weka', 5),
#  ('kafka', 5),
#  ('rest', 5),
#  ('process', 5),
#  ('update', 5),
#  ('instances', 5),
#  ('xml', 5),
#  ('worker', 5),
#  ('callback', 5),
#  ('fragment', 5),
#  ('listener', 5),
#  ('score', 5),
#  ('state', 5),
#  ('message', 5),
#  ('status', 5),
#  ('android', 5),
#  ('meta', 5),
#  ('nlp', 5),
#  ('basic', 5),
#  ('controller', 5),
#  ('predict', 5),
#  ('plugin', 5),
#  ('step', 5),
#  ('source', 5),
#  ('tag', 5),
#  ('persistence', 5),
#  ('collection', 4),
#  ('code', 4),
#  ('types', 4),
#  ('cli', 4),
#  ('weight', 4),
#  ('queue', 4),
#  ('light', 4),
#  ('query', 4),
#  ('visualization', 4),
#  ('means', 4),
#  ('index', 4),
#  ('executor', 4),
#  ('date', 4),
#  ('all', 4),
#  ('group', 4),
#  ('tools', 4),
#  ('svm', 4),
#  ('sparse', 4),
#  ('table', 4),
#  ('token', 4),
#  ('method', 4),
#  ('ramo', 4),
#  ('klevis', 4),
#  ('csv', 4),
#  ('layer', 4),
#  ('inference', 4),
#  ('bayes', 4),
#  ('repository', 4),
#  ('spec', 4),
#  ('optimization', 4),
#  ('connection', 4),
#  ('item', 4),
#  ('settings', 4),
#  ('dialog', 4),
#  ('term', 4),
#  ('one', 4),
#  ('param', 4),
#  ('panel', 4),
#  ('gui', 4),
#  ('comparator', 4),
#  ('standard', 4),
#  ('transform', 4),
#  ('video', 4),
#  ('camera', 4),
#  ('ann', 4),
#  ('matcher', 4),
#  ('component', 4),
#  ('project', 4),
#  ('strategy', 4),
#  ('discrete', 4),
#  ('binary', 4),
#  ('rules', 4),
#  ('learn', 4),
#  ('writer', 4),
#  ('recognition', 4),
#  ('logger', 4),
#  ('extraction', 3),
#  ('entry', 3),
#  ('saver', 3),
#  ('google', 3),
#  ('normalization', 3),
#  ('edu', 3),
#  ('gradient', 3),
#  ('device', 3),
#  ('memory', 3),
#  ('element', 3),
#  ('norm', 3),
#  ('iterator', 3),
#  ('estimator', 3),
#  ('knn', 3),
#  ('kmeans', 3),
#  ('range', 3),
#  ('sampling', 3),
#  ('session', 3),
#  ('validation', 3),
#  ('pipeline', 3),
#  ('unsupervised', 3),
#  ('encoder', 3),
#  ('neighbor', 3),
#  ('filters', 3),
#  ('structure', 3),
#  ('content', 3),
#  ('parsing', 3),
#  ('word', 3),
#  ('with', 3),
#  ('document', 3),
#  ('line', 3),
#  ('author', 3),
#  ('sampler', 3),
#  ('classify', 3),
#  ('dao', 3),
#  ('retriever', 3),
#  ('utilities', 3),
#  ('tensorflow', 3),
#  ('boost', 3),
#  ('scheduler', 3),
#  ('neuron', 3),
#  ('lambda', 3),
#  ('analyzer', 3),
#  ('dense', 3),
#  ('experiments', 3),
#  ('hidden', 3),
#  ('from', 3),
#  ('classifiers', 3),
#  ('properties', 3),
#  ('runtime', 3),
#  ('detail', 3),
#  ('history', 3),
#  ('rpc', 3),
#  ('gpu', 3),
#  ('framework', 3),
#  ('calculator', 3),
#  ('category', 3),
#  ('add', 3),
#  ('holder', 3),
#  ('res', 3),
#  ('visitor', 3),
#  ('params', 3),
#  ('system', 3),
#  ('tuple', 3),
#  ('actions', 3),
#  ('time', 3),
#  ('command', 3),
#  ('records', 3),
#  ('record', 3),
#  ('intent', 3),
#  ('lazy', 3),
#  ('decision', 3),
#  ('serialization', 3),
#  ('pair', 3),
#  ('streams', 3),
#  ('machinelearning', 3),
#  ('opt', 3),
#  ('preprocessing', 3),
#  ('option', 3),
#  ('decomposition', 3),
#  ('mat', 3),
#  ('domain', 3),
#  ('imgproc', 3),
#  ('objdetect', 3),
#  ('descriptor', 3),
#  ('background', 3),
#  ('subtractor', 3),
#  ('photo', 3),
#  ('rect', 3),
#  ('stereo', 3),
#  ('match', 3),
#  ('key', 3),
#  ('module', 3),
#  ('reducer', 3),
#  ('processing', 3),
#  ('activation', 3),
#  ('expression', 3),
#  ('template', 3),
#  ('coordination', 3),
#  ('categories', 3),
#  ('results', 3),
#  ('mapper', 3),
#  ('internal', 3),
#  ('tags', 3),
#  ('column', 3),
#  ('training', 3),
#  ('statement', 3),
#  ('ast', 3),
#  ('entities', 3),
#  ('mnist', 3),
#  ('tool', 3),
#  ('argument', 3),
#  ('bean', 3),
#  ('remove', 3),
#  ('web', 3),
#  ('serving', 3),
#  ('plugins', 3),
#  ('format', 3),
#  ('path', 3),
#  ('detection', 3),
#  ('detector', 3),
#  ('renderer', 3),
#  ('script', 3),
#  ('counter', 3),
#  ('tasks', 3),
#  ('twitter', 2),
#  ('detect', 2),
#  ('article', 2),
#  ('post', 2),
#  ('screen', 2),
#  ('producer', 2),
#  ('broker', 2),
#  ('errors', 2),
#  ('http', 2),
#  ('sentiment', 2),
#  ('pool', 2),
#  ('blas', 2),
#  ('inner', 2),
#  ('lock', 2),
#  ('product', 2),
#  ('outlier', 2),
#  ('strategies', 2),
#  ('hierarchical', 2),
#  ('pca', 2),
#  ('selection', 2),
#  ('candidate', 2),
#  ('found', 2),
#  ('based', 2),
#  ('viadee', 2),
#  ('neighbors', 2),
#  ('clusterer', 2),
#  ('nearest', 2),
#  ('centroid', 2),
#  ('mean', 2),
#  ('supervised', 2),
#  ('dual', 2),
#  ('constant', 2),
#  ('demo', 2),
#  ('full', 2),
#  ('alignments', 2),
#  ('uni', 2),
#  ('custom', 2),
#  ('advanced', 2),
#  ('hadoop', 2),
#  ('bank', 2),
#  ('metadata', 2),
#  ('enhancer', 2),
#  ('affiliation', 2),
#  ('general', 2),
#  ('doc', 2),
#  ('page', 2),
#  ('libsvm', 2),
#  ('number', 2),
#  ('position', 2),
#  ('pubmed', 2),
#  ('lda', 2),
#  ('topic', 2),
#  ('tui', 2),
#  ('alias', 2),
#  ('indexer', 2),
#  ('ranker', 2),
#  ('space', 2),
#  ('xgboost', 2),
#  ('cent', 2),
#  ('ranking', 2),
#  ('neuralnet', 2),
#  ('rank', 2),
#  ('combiner', 2),
#  ('ensemble', 2),
#  ('lib', 2),
#  ('bayesian', 2),
#  ('normal', 2),
#  ('drift', 2),
#  ('concept', 2),
#  ('arff', 2),
#  ('converters', 2),
#  ('definition', 2),
#  ('link', 2),
#  ('scope', 2),
#  ('url', 2),
#  ('security', 2),
#  ('events', 2),
#  ('writable', 2),
#  ('hdfs', 2),
#  ('multilabel', 2),
#  ('calibration', 2),
#  ('logistic', 2),
#  ('crf', 2),
#  ('multi', 2),
#  ('reg', 2),
#  ('least', 2),
#  ('sms', 2),
#  ('change', 2),
#  ('external', 2),
#  ('predicate', 2),
#  ('approximate', 2),
#  ('online', 2),
#  ('multiclass', 2),
#  ('maker', 2),
#  ('continuous', 2),
#  ('codec', 2),
#  ('master', 2),
#  ('languages', 2),
#  ('backend', 2),
#  ('words', 2),
#  ('stanford', 2),
#  ('correlation', 2),
#  ('numeric', 2),
#  ('intersection', 2),
#  ('sorted', 2),
#  ('letter', 2),
#  ('presenter', 2),
#  ('viewer', 2),
#  ('symbol', 2),
#  ('codes', 2),
#  ('fragments', 2),
#  ('transaction', 2),
#  ('connector', 2),
#  ('permission', 2),
#  ('library', 2),
#  ('receiver', 2),
#  ('grant', 2),
#  ('serializer', 2),
#  ('generate', 2),
#  ('attributes', 2),
#  ('udf', 2),
#  ('megachucky', 2),
#  ('customer', 2),
#  ('spring', 2),
#  ('cnn', 2),
#  ('var', 2),
#  ('tests', 2),
#  ('empirical', 2),
#  ('interactor', 2),
#  ('capture', 2),
#  ('runner', 2),
#  ('frame', 2),
#  ('options', 2),
#  ('cross', 2),
#  ('nodes', 2),
#  ('shared', 2),
#  ('func', 2),
#  ('forward', 2),
#  ('feed', 2),
#  ('genetic', 2),
#  ('sequential', 2),
#  ('exec', 2),
#  ('genlex', 2),
#  ('lexicon', 2),
#  ('lexical', 2),
#  ('parse', 2),
#  ('naive', 2),
#  ('creator', 2),
#  ('export', 2),
#  ('email', 2),
#  ('password', 2),
#  ('call', 2),
#  ('save', 2),
#  ('columns', 2),
#  ('partitioner', 2),
#  ('field', 2),
#  ('cache', 2),
#  ('linked', 2),
#  ('adapters', 2),
#  ('primitive', 2),
#  ('quick', 2),
#  ('pmml', 2),
#  ('obj', 2),
#  ('benchmark', 2),
#  ('cell', 2),
#  ('aggregate', 2),
#  ('dnn', 2),
#  ('scalar', 2),
#  ('platform', 2),
#  ('load', 2),
#  ('files', 2),
#  ('remote', 2),
#  ('evidence', 2),
#  ('servlet', 2),
#  ('low', 2),
#  ('quality', 2),
#  ('dsl', 2),
#  ('identifier', 2),
#  ('convolutional', 2),
#  ('region', 2),
#  ('images', 2),
#  ('opennlp', 2),
#  ('sgd', 2),
#  ('declaration', 2),
#  ('jni', 2),
#  ('beans', 2),
#  ('steps', 2),
#  ('customizer', 2),
#  ('gender', 2),
#  ('target', 2),
#  ('auto', 2),
#  ('registry', 2),
#  ('endpoint', 2),
#  ('mapping', 2),
#  ('only', 2),
#  ('artifact', 2),
#  ('environment', 2),
#  ('workflow', 2),
#  ('annotation', 2),
#  ('constants', 2),
#  ('extension', 2),
#  ('annotated', 2),
#  ('accuracy', 2),
#  ('exchange', 2),
#  ('probability', 2),
#  ('tflite', 2),
#  ('check', 2),
#  ('open', 2),
#  ('reply', 2),
#  ('fast', 2),
#  ('named', 2),
#  ('login', 2),
#  ('generators', 2),
#  ('dependency', 2),
#  ('compact', 2),
#  ('face', 2),
#  ('optical', 2),
#  ('tonemap', 2),
#  ('videoio', 2),
#  ('calibrate', 2),
#  ('imgcodecs', 2),
#  ('pixel', 2),
#  ('translation', 2),
#  ('draw', 2),
#  ('weighted', 2),
#  ('gbm', 2),
#  ('booster', 2),
#  ('scraper', 1),
#  ('bing', 1),
#  ('responses', 1),
#  ('cld', 1),
#  ('php', 1),
#  ('babel', 1),
#  ('blogspot', 1),
#  ('textcat', 1),
#  ('you', 1),
#  ('tube', 1),
#  ('lingpipe', 1),
#  ('fetcher', 1),
#  ('detections', 1),
#  ('tweet', 1),
#  ('lsds', 1),
#  ('crossbow', 1),
#  ('imperial', 1),
#  ('conf', 1),
#  ('dispatcher', 1),
#  ('buffer', 1),
#  ('soft', 1),
#  ('max', 1),
#  ('wise', 1),
#  ('mode', 1),
#  ('dropout', 1),
#  ('concat', 1),
#  ('noop', 1),
#  ('initialiser', 1),
#  ('lrn', 1),
#  ('conv', 1),
#  ('normalisation', 1),
#  ('slotted', 1),
#  ('spatial', 1),
#  ('statistics', 1),
#  ('metrical', 1),
#  ('rstarvariants', 1),
#  ('mtreevariants', 1),
#  ('visualizers', 1),
#  ('integer', 1),
#  ('ids', 1),
#  ('dbid', 1),
#  ('datastructures', 1),
#  ('linearalgebra', 1),
#  ('optionhandling', 1),
#  ('scatterplot', 1),
#  ('scaling', 1),
#  ('mktrees', 1),
#  ('betula', 1),
#  ('initialization', 1),
#  ('projection', 1),
#  ('optics', 1),
#  ('uncertain', 1),
#  ('lizhangqu', 1),
#  ('anchor', 1),
#  ('xai', 1),
#  ('global', 1),
#  ('coverage', 1),
#  ('exploration', 1),
#  ('explainer', 1),
#  ('identification', 1),
#  ('pick', 1),
#  ('submodular', 1),
#  ('perturbation', 1),
#  ('construction', 1),
#  ('threaded', 1),
#  ('disabled', 1),
#  ('lucb', 1),
#  ('best', 1),
#  ('racing', 1),
#  ('reconfigurable', 1),
#  ('bernoulli', 1),
#  ('median', 1),
#  ('elimination', 1),
#  ('sar', 1),
#  ('supplier', 1),
#  ('modified', 1),
#  ('balanced', 1),
#  ('algo', 1),
#  ('preprocess', 1),
#  ('pairwise', 1),
#  ('impute', 1),
#  ('except', 1),
#  ('dbscan', 1),
#  ('imputation', 1),
#  ('optimize', 1),
#  ('scoring', 1),
#  ('formatter', 1),
#  ('transformer', 1),
#  ('min', 1),
#  ('scaler', 1),
#  ('affinity', 1),
#  ('radius', 1),
#  ('downhill', 1),
#  ('hdbscan', 1),
#  ('convergeable', 1),
#  ('liblbfgs', 1),
#  ('lbfgs', 1),
#  ('arithmetic', 1),
#  ('minimizer', 1),
#  ('mutable', 1),
#  ('mmtf', 1),
#  ('demos', 1),
#  ('datasets', 1),
#  ('mappers', 1),
#  ('secondary', 1),
#  ('interactions', 1),
#  ('webfilters', 1),
#  ('contains', 1),
#  ('pdb', 1),
#  ('chain', 1),
#  ('polymer', 1),
#  ('protein', 1),
#  ('prot', 1),
#  ('applications', 1),
#  ('fingerprint', 1),
#  ('read', 1),
#  ('bio', 1),
#  ('ligand', 1),
#  ('swiss', 1),
#  ('aligner', 1),
#  ('drug', 1),
#  ('report', 1),
#  ('webservices', 1),
#  ('cermine', 1),
#  ('icm', 1),
#  ('zoneclassification', 1),
#  ('bibref', 1),
#  ('headers', 1),
#  ('enhancers', 1),
#  ('transformers', 1),
#  ('count', 1),
#  ('relative', 1),
#  ('zone', 1),
#  ('nlm', 1),
#  ('bib', 1),
#  ('uppercase', 1),
#  ('systems', 1),
#  ('citation', 1),
#  ('digit', 1),
#  ('pages', 1),
#  ('topics', 1),
#  ('randomscan', 1),
#  ('dirichlet', 1),
#  ('polya', 1),
#  ('urn', 1),
#  ('pipe', 1),
#  ('uncollapsed', 1),
#  ('poisson', 1),
#  ('likelihood', 1),
#  ('spalias', 1),
#  ('vectorizer', 1),
#  ('loading', 1),
#  ('priors', 1),
#  ('fixed', 1),
#  ('parsed', 1),
#  ('coeff', 1),
#  ('gentle', 1),
#  ('samantha', 1),
#  ('modeler', 1),
#  ('expander', 1),
#  ('featurizer', 1),
#  ('solver', 1),
#  ('separated', 1),
#  ('router', 1),
#  ('objective', 1),
#  ('svd', 1),
#  ('reinforce', 1),
#  ('recommender', 1),
#  ('redis', 1),
#  ('svdfeature', 1),
#  ('mart', 1),
#  ('weak', 1),
#  ('normalizer', 1),
#  ('sorter', 1),
#  ('normalizor', 1),
#  ('ciir', 1),
#  ('umass', 1),
#  ('coor', 1),
#  ('ascent', 1),
#  ('permutation', 1),
#  ('arabic', 1),
#  ('recogntion', 1),
#  ('emaraic', 1),
#  ('dynamic', 1),
#  ('flinklink', 1),
#  ('datastream', 1),
#  ('variables', 1),
#  ('huginlink', 1),
#  ('parametric', 1),
#  ('exponentialfamily', 1),
#  ('standardmodels', 1),
#  ('filereaders', 1),
#  ('amidst', 1),
#  ('hugin', 1),
#  ('multinomial', 1),
#  ('vmp', 1),
#  ('conceptdrift', 1),
#  ('dbn', 1),
#  ('review', 1),
#  ('mixture', 1),
#  ('generation', 1),
#  ('gamma', 1),
#  ('camunda', 1),
#  ('pollingclient', 1),
#  ('polling', 1),
#  ('jdbc', 1),
#  ('lastpolled', 1),
#  ('historic', 1),
#  ('filebased', 1),
#  ('polled', 1),
#  ('identity', 1),
#  ('last', 1),
#  ('comment', 1),
#  ('deployment', 1),
#  ('timeslice', 1),
#  ('respone', 1),
#  ('incident', 1),
#  ('tony', 1),
#  ('register', 1),
#  ('horovod', 1),
#  ('minitony', 1),
#  ('infos', 1),
#  ('per', 1),
#  ('board', 1),
#  ('heartbeat', 1),
#  ('submitter', 1),
#  ('azkaban', 1),
#  ('information', 1),
#  ('port', 1),
#  ('dashboard', 1),
#  ('usage', 1),
#  ('mini', 1),
#  ('pyramid', 1),
#  ('ccs', 1),
#  ('cbm', 1),
#  ('imlgb', 1),
#  ('esplugins', 1),
#  ('inspector', 1),
#  ('calibrator', 1),
#  ('hmlgb', 1),
#  ('clf', 1),
#  ('measures', 1),
#  ('lkboost', 1),
#  ('gmm', 1),
#  ('squares', 1),
#  ('backpropagation', 1),
#  ('mainframe', 1),
#  ('groupingmessages', 1),
#  ('database', 1),
#  ('bridge', 1),
#  ('rahulja', 1),
#  ('swipe', 1),
#  ('contract', 1),
#  ('will', 1),
#  ('fopc', 1),
#  ('ilp', 1),
#  ('mln', 1),
#  ('prover', 1),
#  ('thm', 1),
#  ('clause', 1),
#  ('rdn', 1),
#  ('visitors', 1),
#  ('condor', 1),
#  ('literal', 1),
#  ('std', 1),
#  ('isearch', 1),
#  ('relational', 1),
#  ('walks', 1),
#  ('horn', 1),
#  ('ground', 1),
#  ('defined', 1),
#  ('chirp', 1),
#  ('advice', 1),
#  ('clausebase', 1),
#  ('ytklearn', 1),
#  ('gbdt', 1),
#  ('dataflow', 1),
#  ('operation', 1),
#  ('missing', 1),
#  ('hoag', 1),
#  ('hinge', 1),
#  ('quantile', 1),
#  ('normlization', 1),
#  ('compute', 1),
#  ('gbmlr', 1),
#  ('gbhmlr', 1),
#  ('gbsdt', 1),
#  ('ffm', 1),
#  ('gbhsdt', 1),
#  ('cruise', 1),
#  ('spl', 1),
#  ('mlapps', 1),
#  ('plan', 1),
#  ('pregel', 1),
#  ('gbt', 1),
#  ('centcomm', 1),
#  ('msg', 1),
#  ('nmf', 1),
#  ('addinteger', 1),
#  ('mlr', 1),
#  ('lasso', 1),
#  ('tasklet', 1),
#  ('jobserver', 1),
#  ('linalg', 1),
#  ('comm', 1),
#  ('trace', 1),
#  ('sender', 1),
#  ('drivers', 1),
#  ('generics', 1),
#  ('distances', 1),
#  ('cullers', 1),
#  ('gram', 1),
#  ('canonicizers', 1),
#  ('culler', 1),
#  ('jgaap', 1),
#  ('leave', 1),
#  ('out', 1),
#  ('character', 1),
#  ('strip', 1),
#  ('histogram', 1),
#  ('null', 1),
#  ('chinese', 1),
#  ('truncated', 1),
#  ('punctuation', 1),
#  ('divergence', 1),
#  ('absolute', 1),
#  ('skip', 1),
#  ('part', 1),
#  ('speech', 1),
#  ('english', 1),
#  ('kendall', 1),
#  ('trader', 1),
#  ('tester', 1),
#  ('streaming', 1),
#  ('trade', 1),
#  ('sync', 1),
#  ('candle', 1),
#  ('subscribe', 1),
#  ('stop', 1),
#  ('chart', 1),
#  ('tick', 1),
#  ('trades', 1),
#  ('fire', 1),
#  ('margin', 1),
#  ('profit', 1),
#  ('prices', 1),
#  ('calendar', 1),
#  ('keep', 1),
#  ('alive', 1),
#  ('balance', 1),
#  ('apkfile', 1),
#  ('manifest', 1),
#  ('chunk', 1),
#  ('dex', 1),
#  ('apk', 1),
#  ('namespace', 1),
#  ('uses', 1),
#  ('entropy', 1),
#  ('start', 1),
#  ('end', 1),
#  ('chunks', 1),
#  ('resources', 1),
#  ('screens', 1),
#  ('unknown', 1),
#  ('blamer', 1),
#  ('uri', 1),
#  ('complexity', 1),
#  ('calculating', 1),
#  ('collective', 1),
#  ('flipper', 1),
#  ('ranked', 1),
#  ('randomizable', 1),
#  ('explorer', 1),
#  ('ibk', 1),
#  ('woods', 1),
#  ('weighting', 1),
#  ('triangle', 1),
#  ('chopper', 1),
#  ('splitter', 1),
#  ('yatsi', 1),
#  ('multiple', 1),
#  ('two', 1),
#  ('stage', 1),
#  ('single', 1),
#  ('experiment', 1),
#  ('clock', 1),
#  ('restartable', 1),
#  ('llgc', 1),
#  ('confident', 1),
#  ('bert', 1),
#  ('robrua', 1),
#  ('wordpiece', 1),
#  ('liblevenshtein', 1),
#  ('transducer', 1),
#  ('dictionary', 1),
#  ('transition', 1),
#  ('dawg', 1),
#  ('memoized', 1),
#  ('regr', 1),
#  ('special', 1),
#  ('transposition', 1),
#  ('readme', 1),
#  ('depend', 1),
#  ('integ', 1),
#  ('syntastic', 1),
#  ('protobuf', 1),
#  ('unsubsume', 1),
#  ('prefix', 1),
#  ('subsumes', 1),
#  ('symmetric', 1),
#  ('immutable', 1),
#  ('plain', 1),
#  ('deep', 1),
#  ('ksql', 1),
#  ('bias', 1),
#  ('confluent', 1),
#  ('anomaly', 1),
#  ('multiply', 1),
#  ('names', 1),
#  ('recordreaderexamples', 1),
#  ('cook', 1),
#  ('book', 1),
#  ('retention', 1),
#  ('executorexamples', 1),
#  ('local', 1),
#  ('pre', 1),
#  ('uima', 1),
#  ...]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import spacy

nlp = spacy.load("en_core_web_trf")
label_emb = list(nlp.pipe([LABEL]))[0]._.trf_data.tensors[-1]
keywords = [x[0] for x in counter.most_common()]
print(len(keywords))
similarities = []
for i, doc in tqdm(enumerate(nlp.pipe(keywords))):
    tokvecs = doc._.trf_data.tensors[-1]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities.append((keywords[i], sim))
# Out:
# 2022-10-26 11:54:58.590142: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 11:54:58.798889: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-26 11:54:59.544939: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-26 11:54:59.545096: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-26 11:54:59.545105: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-26 11:55:00.414229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 11:55:00.433106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 11:55:00.433294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 1783
# 1783it [00:09, 187.42it/s]

# %%
similarities.sort(key=lambda x: -x[1])

# %%
len(similarities)
# Out:
# 1783

# %%
similarities[:50]
# Out:
# [('tooling', 0.98146695),
#  ('turing', 0.980965),
#  ('scripting', 0.97998285),
#  ('scaling', 0.978513),
#  ('blocking', 0.97837454),
#  ('grouping', 0.97795147),
#  ('cleaning', 0.97794044),
#  ('racing', 0.97787106),
#  ('streaming', 0.9777824),
#  ('construction', 0.97773445),
#  ('sorting', 0.97772104),
#  ('detection', 0.9767931),
#  ('utility', 0.9767429),
#  ('modeler', 0.97642154),
#  ('arithmetic', 0.9762926),
#  ('detector', 0.9762422),
#  ('structure', 0.97588086),
#  ('coordination', 0.97580934),
#  ('training', 0.97576797),
#  ('featurepruning', 0.975617),
#  ('machinelearning', 0.9753634),
#  ('registry', 0.9751737),
#  ('evaluation', 0.9748831),
#  ('recording', 0.97487015),
#  ('activity', 0.9748595),
#  ('recognition', 0.97475684),
#  ('configuration', 0.9741598),
#  ('trainer', 0.97412884),
#  ('binning', 0.9740665),
#  ('polymer', 0.97387385),
#  ('sampling', 0.97385454),
#  ('cluster', 0.9734316),
#  ('execution', 0.9733811),
#  ('divergence', 0.97336006),
#  ('dependency', 0.9730565),
#  ('exploration', 0.9730322),
#  ('boundary', 0.9729991),
#  ('analysis', 0.9729489),
#  ('configurer', 0.9727793),
#  ('testing', 0.9726312),
#  ('storage', 0.97260875),
#  ('customizer', 0.97259444),
#  ('complexity', 0.972579),
#  ('recogniser', 0.97257733),
#  ('regularization', 0.9725664),
#  ('validation', 0.9725188),
#  ('visitor', 0.97250986),
#  ('language', 0.9725045),
#  ('extension', 0.9724932),
#  ('vendor', 0.9724551)]

# %%
from feature.embedding import FastTextEmbedding

ft = FastTextEmbedding(path='/home/sasce/PycharmProjects/CodeGraphClassification/data/models/wiki.en.bin', model='fastText')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
label_emb = [ft.get_embedding(LABEL)]
keywords = [x[0] for x in counter.most_common()]

similarities_ft = []
for i, key in tqdm(enumerate(keywords)):
    tokvecs = [ft.get_embedding(key)]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities_ft.append((keywords[i], sim))

similarities_ft.sort(key=lambda x: -x[1])
# Out:
# 1783it [00:00, 4118.75it/s]

# %%
similarities_ft[:50]
# Out:
# [('machine', 0.8008606),
#  ('learning', 0.80086046),
#  ('machinelearning', 0.77182347),
#  ('modellearning', 0.60952586),
#  ('learner', 0.59861034),
#  ('learners', 0.5608892),
#  ('learn', 0.5550004),
#  ('turing', 0.54515105),
#  ('weblearner', 0.51500314),
#  ('unsupervised', 0.51103646),
#  ('statemachine', 0.49880147),
#  ('dataflow', 0.48761946),
#  ('algorithms', 0.48238376),
#  ('letterpredictor', 0.4713303),
#  ('neural', 0.469069),
#  ('parsing', 0.46866322),
#  ('retrieval', 0.46826547),
#  ('programming', 0.46619743),
#  ('tool', 0.4624128),
#  ('autoencoder', 0.46194303),
#  ('processing', 0.46188936),
#  ('tasks', 0.4562919),
#  ('backpropagation', 0.45508614),
#  ('mainframe', 0.45230386),
#  ('initialization', 0.44877338),
#  ('optimizer', 0.44834492),
#  ('prover', 0.44755194),
#  ('innovation', 0.44578502),
#  ('languagetool', 0.44306433),
#  ('debugging', 0.44161376),
#  ('algorithm', 0.43994573),
#  ('recursive', 0.43767765),
#  ('dataprocessing', 0.43338186),
#  ('reconfigurable', 0.4320647),
#  ('visualization', 0.4318238),
#  ('libsvm', 0.43107858),
#  ('toolchain', 0.43091434),
#  ('visualizers', 0.42976028),
#  ('tools', 0.4295457),
#  ('labs', 0.4291639),
#  ('visualizer', 0.42692038),
#  ('inference', 0.42638168),
#  ('modeler', 0.4239036),
#  ('opencv', 0.42344636),
#  ('recognizer', 0.4231896),
#  ('methods', 0.42302167),
#  ('iterator', 0.42285484),
#  ('learnlibproxies', 0.422439),
#  ('spiking', 0.4202668),
#  ('predictive', 0.4199339)]
