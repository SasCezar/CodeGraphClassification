# %%
from hydra import initialize, compose

with initialize(version_base=None, config_path="../../src/conf/"):
    cfg = compose(config_name='main.yaml', overrides=["local=default"])
    print(cfg)
# Out:
# {'num_workers': 1, 'num_splits': 10, 'split': 1, 'seed': 42, 'project_path': '${base_path}/data/raw/dataset_with_graphs.csv', 'extraction': {'_target_': 'src.feature.extract.NameFeatureExtraction', 'graph_path': '${arcan_graphs}', 'out_path': '${out_path}/processed/', 'stopwords': 'None'}, 'embedding': {'_target_': 'src.feature.embedding.FastTextEmbedding', 'model': 'fastText', 'path': '${base_path}/data/models/wiki.en.bin'}, 'base_path': '/home/sasce/PycharmProjects/CodeGraphClassification', 'out_path': '${base_path}/data/', 'arcan_out': '${base_path}/data/interim/', 'arcan_graphs': '${arcan_out}/arcanOutput', 'raw_data': '${out_path}/raw/', 'dataset': '${base_path}/data/raw/classification_dataset_lang.csv', 'language': 'JAVA', 'repositories_path': '${base_path}/data/raw/repositories/', 'arcan_script': '${base_path}/scripts/bash/run-arcan.sh', 'arcan_path': '${base_path}/tools/arcan', 'repository_path': '${base_path}/data/raw/repositories', 'logs_path': '${base_path}/logs/', 'model': {'_target_': 'src.model.gcn.GraphConvNetwork', 'hidden_channels': 256}, 'datamodule': {'_target_': 'src.data.datamodule.GitRankingDataModule', 'graph_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/interim/arcanOutput', 'feature_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/embedding/name/fastText', 'out_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/torch', 'embedding_size': 300, 'batch_size': 32, 'num_splits': '${num_splits}', 'split': '${split}', 'has_val': True, 'has_test': True}}

# %%
from data.graph import ArcanGraphLoader
from os.path import join
from feature.content import NameContentExtraction
from utils import git_clone, get_versions, git_checkout, filter_by_label
from loguru import logger
import pandas as pd

LABEL = "database"
projects = pd.read_csv("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/dataset_with_graphs.csv")
content_extractor = NameContentExtraction(graph_path=cfg.arcan_graphs)

# %%
projects.head()
# Out:
#                             name                             label   level  \
# 0  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 1  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 2  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 3  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 4  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
#
#    version                                       sha  nodes  edges
# 0      133  292a42769f7f6f1beaf4b178c3f7170fddfee282     68    212
# 1       63  c01cf7bf4093aa21fafc1fba93ba50ca0343c619     36    110
# 2       72  785b7928896b302fd84d81f9437ec47af5d7b330     36    110
# 3       21  b08c040bfe57cb1f3220ca487d33b0240a6564fa     39    155
# 4      115  30cb73f240f83e7a3a363d4a5a5d27c04e313907     68    212

# %%
projects = filter_by_label(projects.copy(deep=True), [LABEL])
# Out:
# 2022-10-26 11:18:55.601 | INFO     | utils:filter_by_label:105 - Labels ['database']
# /home/sasce/PycharmProjects/CodeGraphClassification/src/utils.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].apply(tuple)

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3360 entries, 975 to 59154
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3360 non-null   object
#  1   label    3360 non-null   object
#  2   level    3360 non-null   object
#  3   version  3360 non-null   int64
#  4   sha      3360 non-null   object
#  5   nodes    3360 non-null   int64
#  6   edges    3360 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 210.0+ KB

# %%
projects = list(set(projects['name'].tolist()))
len(projects)
# Out:
# 111

# %%
from tqdm import tqdm

graph_loader = ArcanGraphLoader()
logger.info(f"Extracting features for {len(projects)} projects")
identifiers = []
content = {}
for project_name in tqdm(projects):
    project = project_name.replace('|', '/')

    project_url = f'https://github.com/{project}'
    if content_extractor.clone:
        git_clone(project_url, project_name, cfg.repositories_path)


    versions = [get_versions(project_name, cfg.arcan_graphs)[-1]]

    logger.info(f"Found {len(versions)} versions for project {project}")
    for num, sha in tqdm(versions):
        try:
            if content_extractor.clone:
                git_checkout(join(cfg.repositories_path, project_name), sha)
            project_graph = graph_loader.load(join(cfg.arcan_graphs, project_name, f'dependency-graph-{num}_{sha}.graphml'))
            res = content_extractor.extract(project_name, sha, num)
            identifiers.append(res)
        except:
            continue

    text = [" ".join(x).replace(".", " ") for x in identifiers]
    content[project_name] = text

    #repo_path = join(cfg.repository_path, project_name)
    #shutil.rmtree(repo_path, ignore_errors=True)
# Out:
# 2022-10-26 11:18:56.302 | INFO     | __main__:<module>:4 - Extracting features for 111 projects
#   0%|          | 0/111 [00:00<?, ?it/s]2022-10-26 11:18:56.305 | INFO     | __main__:<module>:17 - Found 1 versions for project nolia/Noodle
#
# 100%|██████████| 1/1 [00:00<00:00, 418.68it/s]
# 2022-10-26 11:18:56.312 | INFO     | __main__:<module>:17 - Found 1 versions for project srotya/sidewinder
#
# 100%|██████████| 1/1 [00:00<00:00, 48.76it/s]
# 2022-10-26 11:18:56.342 | INFO     | __main__:<module>:17 - Found 1 versions for project zapr-oss/druidry
#
# 100%|██████████| 1/1 [00:00<00:00, 86.35it/s]
# 2022-10-26 11:18:56.365 | INFO     | __main__:<module>:17 - Found 1 versions for project cinchapi/concourse
#
# 100%|██████████| 1/1 [00:00<00:00, 34.81it/s]
# 2022-10-26 11:18:56.402 | INFO     | __main__:<module>:17 - Found 1 versions for project DevinZ1993/SimpleDB-Database-System
#
# 100%|██████████| 1/1 [00:00<00:00, 171.60it/s]
#   5%|▍         | 5/111 [00:00<00:02, 46.88it/s]2022-10-26 11:18:56.413 | INFO     | __main__:<module>:17 - Found 1 versions for project Hemen07/Groupy
#
# 100%|██████████| 1/1 [00:00<00:00, 227.47it/s]
# 2022-10-26 11:18:56.422 | INFO     | __main__:<module>:17 - Found 1 versions for project r2dbc/r2dbc-client
#
# 100%|██████████| 1/1 [00:00<00:00, 487.88it/s]
# 2022-10-26 11:18:56.428 | INFO     | __main__:<module>:17 - Found 1 versions for project jrvansuita/SQLiteHelper
#
# 100%|██████████| 1/1 [00:00<00:00, 507.48it/s]
# 2022-10-26 11:18:56.433 | INFO     | __main__:<module>:17 - Found 1 versions for project ome/openmicroscopy
#
# 100%|██████████| 1/1 [00:00<00:00, 112.45it/s]
# 2022-10-26 11:18:56.447 | INFO     | __main__:<module>:17 - Found 1 versions for project dbeaver/dbeaver
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
#   9%|▉         | 10/111 [00:00<00:04, 22.39it/s]2022-10-26 11:18:56.718 | INFO     | __main__:<module>:17 - Found 1 versions for project janmotl/linkifier
#
# 100%|██████████| 1/1 [00:00<00:00, 101.23it/s]
# 2022-10-26 11:18:56.733 | INFO     | __main__:<module>:17 - Found 1 versions for project JumpMind/symmetric-ds
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.26it/s]
# 2022-10-26 11:18:56.884 | INFO     | __main__:<module>:17 - Found 1 versions for project fauna/faunadb-jvm
#
# 100%|██████████| 1/1 [00:00<00:00, 165.35it/s]
#  12%|█▏        | 13/111 [00:00<00:04, 20.17it/s]2022-10-26 11:18:56.896 | INFO     | __main__:<module>:17 - Found 1 versions for project Jamling/Android-ORM
#
# 100%|██████████| 1/1 [00:00<00:00, 175.90it/s]
# 2022-10-26 11:18:56.907 | INFO     | __main__:<module>:17 - Found 1 versions for project mkalus/segrada
#
# 100%|██████████| 1/1 [00:00<00:00, 51.02it/s]
# 2022-10-26 11:18:56.935 | INFO     | __main__:<module>:17 - Found 1 versions for project quantumdb/quantumdb
#
# 100%|██████████| 1/1 [00:00<00:00, 74.16it/s]
# 2022-10-26 11:18:56.955 | INFO     | __main__:<module>:17 - Found 1 versions for project xpinjection/test-driven-spring-boot
#
# 100%|██████████| 1/1 [00:00<00:00, 318.26it/s]
# 2022-10-26 11:18:56.963 | INFO     | __main__:<module>:17 - Found 1 versions for project FrangSierra/RxFirebase
#
# 100%|██████████| 1/1 [00:00<00:00, 514.07it/s]
# 2022-10-26 11:18:56.969 | INFO     | __main__:<module>:17 - Found 1 versions for project Eldelshell/amforeas
#
# 100%|██████████| 1/1 [00:00<00:00, 159.10it/s]
# 2022-10-26 11:18:56.980 | INFO     | __main__:<module>:17 - Found 1 versions for project maskarade/Android-Orma
#
# 100%|██████████| 1/1 [00:00<00:00, 99.83it/s]
#  18%|█▊        | 20/111 [00:00<00:02, 32.16it/s]2022-10-26 11:18:56.997 | INFO     | __main__:<module>:17 - Found 1 versions for project dpoluyanov/achord
#
# 100%|██████████| 1/1 [00:00<00:00, 326.48it/s]
# 2022-10-26 11:18:57.005 | INFO     | __main__:<module>:17 - Found 1 versions for project schemaanalyst/schemaanalyst
#
# 100%|██████████| 1/1 [00:00<00:00, 13.96it/s]
# 2022-10-26 11:18:57.094 | INFO     | __main__:<module>:17 - Found 1 versions for project taskagile/vuejs.spring-boot.mysql
#
# 100%|██████████| 1/1 [00:00<00:00, 60.92it/s]
# 2022-10-26 11:18:57.118 | INFO     | __main__:<module>:17 - Found 1 versions for project iboxdb/db4o-gpl
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.46it/s]
# 2022-10-26 11:18:57.311 | INFO     | __main__:<module>:17 - Found 1 versions for project apache/phoenix
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.44it/s]
#  23%|██▎       | 25/111 [00:01<00:04, 18.62it/s]2022-10-26 11:18:57.476 | INFO     | __main__:<module>:17 - Found 1 versions for project atomix/copycat
#
# 100%|██████████| 1/1 [00:00<00:00, 61.45it/s]
# 2022-10-26 11:18:57.501 | INFO     | __main__:<module>:17 - Found 1 versions for project goldmansachs/reladomo
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# 2022-10-26 11:18:57.736 | INFO     | __main__:<module>:17 - Found 1 versions for project keeps/dbptk-developer
#
# 100%|██████████| 1/1 [00:00<00:00, 22.64it/s]
# 2022-10-26 11:18:57.794 | INFO     | __main__:<module>:17 - Found 1 versions for project iboxdb/ftserver
#
# 100%|██████████| 1/1 [00:00<00:00, 339.62it/s]
#  26%|██▌       | 29/111 [00:01<00:05, 16.23it/s]2022-10-26 11:18:57.802 | INFO     | __main__:<module>:17 - Found 1 versions for project usc-isi-i2/Web-Karma
#
# 100%|██████████| 1/1 [00:00<00:00, 11.97it/s]
# 2022-10-26 11:18:57.909 | INFO     | __main__:<module>:17 - Found 1 versions for project realm/realm-java
#
# 100%|██████████| 1/1 [00:00<00:00, 17.79it/s]
# 2022-10-26 11:18:57.978 | INFO     | __main__:<module>:17 - Found 1 versions for project trinodb/trino
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
#  29%|██▉       | 32/111 [00:01<00:06, 11.90it/s]2022-10-26 11:18:58.273 | INFO     | __main__:<module>:17 - Found 1 versions for project CorfuDB/CorfuDB
#
# 100%|██████████| 1/1 [00:00<00:00, 15.76it/s]
# 2022-10-26 11:18:58.354 | INFO     | __main__:<module>:17 - Found 1 versions for project blobcity/db
#
# 100%|██████████| 1/1 [00:00<00:00, 23.53it/s]
#  31%|███       | 34/111 [00:02<00:06, 12.27it/s]2022-10-26 11:18:58.414 | INFO     | __main__:<module>:17 - Found 1 versions for project lmdbjava/lmdbjava
#
# 100%|██████████| 1/1 [00:00<00:00, 253.62it/s]
# 2022-10-26 11:18:58.422 | INFO     | __main__:<module>:17 - Found 1 versions for project msathis/SQLToNoSQLImporter
#
# 100%|██████████| 1/1 [00:00<00:00, 467.80it/s]
# 2022-10-26 11:18:58.428 | INFO     | __main__:<module>:17 - Found 1 versions for project r2dbc/r2dbc-pool
#
# 100%|██████████| 1/1 [00:00<00:00, 544.15it/s]
# 2022-10-26 11:18:58.433 | INFO     | __main__:<module>:17 - Found 1 versions for project vladmihalcea/flexy-pool
#
# 100%|██████████| 1/1 [00:00<00:00, 138.16it/s]
# 2022-10-26 11:18:58.446 | INFO     | __main__:<module>:17 - Found 1 versions for project leonhad/paradoxdriver
#
# 100%|██████████| 1/1 [00:00<00:00, 35.22it/s]
# 2022-10-26 11:18:58.483 | INFO     | __main__:<module>:17 - Found 1 versions for project jaxio/celerio
#
# 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
#  36%|███▌      | 40/111 [00:02<00:03, 18.75it/s]2022-10-26 11:18:58.517 | INFO     | __main__:<module>:17 - Found 1 versions for project SumiMakito/QuickKV
#
# 100%|██████████| 1/1 [00:00<00:00, 370.78it/s]
# 2022-10-26 11:18:58.524 | INFO     | __main__:<module>:17 - Found 1 versions for project mhewedy/spwrap
#
# 100%|██████████| 1/1 [00:00<00:00, 240.24it/s]
# 2022-10-26 11:18:58.532 | INFO     | __main__:<module>:17 - Found 1 versions for project apache/zookeeper
#
# 100%|██████████| 1/1 [00:00<00:00, 50.19it/s]
# 2022-10-26 11:18:58.561 | INFO     | __main__:<module>:17 - Found 1 versions for project 3dcitydb/importer-exporter
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.11it/s]
#  40%|███▉      | 44/111 [00:02<00:03, 19.63it/s]2022-10-26 11:18:58.698 | INFO     | __main__:<module>:17 - Found 1 versions for project asdhammu/Library
#
# 100%|██████████| 1/1 [00:00<00:00, 206.24it/s]
# 2022-10-26 11:18:58.708 | INFO     | __main__:<module>:17 - Found 1 versions for project patrick-emmanuel/spring-boot-boilerplate
#
# 100%|██████████| 1/1 [00:00<00:00, 255.98it/s]
# 2022-10-26 11:18:58.717 | INFO     | __main__:<module>:17 - Found 1 versions for project florent37/RxAndroidOrm
#
# 100%|██████████| 1/1 [00:00<00:00, 305.33it/s]
# 2022-10-26 11:18:58.725 | INFO     | __main__:<module>:17 - Found 1 versions for project takezoe/amateras-modeler
#
# 100%|██████████| 1/1 [00:00<00:00, 31.73it/s]
# 2022-10-26 11:18:58.771 | INFO     | __main__:<module>:17 - Found 1 versions for project SeLite/SeLite
#
# 100%|██████████| 1/1 [00:00<00:00, 276.21it/s]
# 2022-10-26 11:18:58.779 | INFO     | __main__:<module>:17 - Found 1 versions for project j256/ormlite-jdbc
#
# 100%|██████████| 1/1 [00:00<00:00, 420.52it/s]
# 2022-10-26 11:18:58.785 | INFO     | __main__:<module>:17 - Found 1 versions for project emrekose26/CopyExternalDB
#
# 100%|██████████| 1/1 [00:00<00:00, 631.48it/s]
# 2022-10-26 11:18:58.790 | INFO     | __main__:<module>:17 - Found 1 versions for project yoomoney/db-queue
#
# 100%|██████████| 1/1 [00:00<00:00, 142.41it/s]
#  47%|████▋     | 52/111 [00:02<00:01, 29.71it/s]2022-10-26 11:18:58.803 | INFO     | __main__:<module>:17 - Found 1 versions for project delight-im/Android-DDP
#
# 100%|██████████| 1/1 [00:00<00:00, 365.64it/s]
# 2022-10-26 11:18:58.810 | INFO     | __main__:<module>:17 - Found 1 versions for project shalvah/simple-db
#
# 100%|██████████| 1/1 [00:00<00:00, 533.22it/s]
# 2022-10-26 11:18:58.815 | INFO     | __main__:<module>:17 - Found 1 versions for project SoftInstigate/restheart
#
# 100%|██████████| 1/1 [00:00<00:00, 26.92it/s]
# 2022-10-26 11:18:58.864 | INFO     | __main__:<module>:17 - Found 1 versions for project bendem/sql-streams
#
# 100%|██████████| 1/1 [00:00<00:00, 276.12it/s]
# 2022-10-26 11:18:58.871 | INFO     | __main__:<module>:17 - Found 1 versions for project Esri/defense-solutions-proofs-of-concept
#
# 100%|██████████| 1/1 [00:00<00:00, 62.49it/s]
# 2022-10-26 11:18:58.901 | INFO     | __main__:<module>:17 - Found 1 versions for project firegloves/MemPOI
#
# 100%|██████████| 1/1 [00:00<00:00, 153.40it/s]
#  52%|█████▏    | 58/111 [00:02<00:01, 34.91it/s]2022-10-26 11:18:58.914 | INFO     | __main__:<module>:17 - Found 1 versions for project arangodb/arangodb-java-driver
#
# 100%|██████████| 1/1 [00:00<00:00, 38.39it/s]
# 2022-10-26 11:18:58.953 | INFO     | __main__:<module>:17 - Found 1 versions for project bwajtr/java-persistence-frameworks-comparison
#
# 100%|██████████| 1/1 [00:00<00:00, 179.49it/s]
# 2022-10-26 11:18:58.963 | INFO     | __main__:<module>:17 - Found 1 versions for project biezhi/anima
#
# 100%|██████████| 1/1 [00:00<00:00, 119.93it/s]
# 2022-10-26 11:18:58.977 | INFO     | __main__:<module>:17 - Found 1 versions for project IBMStreams/samples
#
# 100%|██████████| 1/1 [00:00<00:00, 352.43it/s]
# 2022-10-26 11:18:58.985 | INFO     | __main__:<module>:17 - Found 1 versions for project opentable/otj-pg-embedded
#
# 100%|██████████| 1/1 [00:00<00:00, 453.78it/s]
# 2022-10-26 11:18:58.991 | INFO     | __main__:<module>:17 - Found 1 versions for project goldmansachs/obevo
#
# 100%|██████████| 1/1 [00:00<00:00, 25.07it/s]
#  58%|█████▊    | 64/111 [00:02<00:01, 37.50it/s]2022-10-26 11:18:59.049 | INFO     | __main__:<module>:17 - Found 1 versions for project bridgedb/BridgeDb
#
# 100%|██████████| 1/1 [00:00<00:00, 55.67it/s]
# 2022-10-26 11:18:59.075 | INFO     | __main__:<module>:17 - Found 1 versions for project 3dcitydb/web-feature-service
#
# 100%|██████████| 1/1 [00:00<00:00, 66.75it/s]
# 2022-10-26 11:18:59.098 | INFO     | __main__:<module>:17 - Found 1 versions for project j256/ormlite-core
#
# 100%|██████████| 1/1 [00:00<00:00, 66.17it/s]
# 2022-10-26 11:18:59.120 | INFO     | __main__:<module>:17 - Found 1 versions for project wepay/waltz
#
# 100%|██████████| 1/1 [00:00<00:00, 56.48it/s]
# 2022-10-26 11:18:59.148 | INFO     | __main__:<module>:17 - Found 1 versions for project JetBrains/xodus
#
# 100%|██████████| 1/1 [00:00<00:00, 21.47it/s]
#  62%|██████▏   | 69/111 [00:02<00:01, 35.41it/s]2022-10-26 11:18:59.210 | INFO     | __main__:<module>:17 - Found 1 versions for project florent37/Freezer
#
# 100%|██████████| 1/1 [00:00<00:00, 276.21it/s]
# 2022-10-26 11:18:59.218 | INFO     | __main__:<module>:17 - Found 1 versions for project automenta/spimedb
#
# 100%|██████████| 1/1 [00:00<00:00, 52.37it/s]
# 2022-10-26 11:18:59.246 | INFO     | __main__:<module>:17 - Found 1 versions for project prof18/Database-Backup-Restore
#
# 100%|██████████| 1/1 [00:00<00:00, 433.65it/s]
# 2022-10-26 11:18:59.252 | INFO     | __main__:<module>:17 - Found 1 versions for project nikolamilosevic86/TableDisentangler
#
# 100%|██████████| 1/1 [00:00<00:00, 149.47it/s]
# 2022-10-26 11:18:59.262 | INFO     | __main__:<module>:17 - Found 1 versions for project derickfelix/BankApplication
#
# 100%|██████████| 1/1 [00:00<00:00, 223.92it/s]
# 2022-10-26 11:18:59.271 | INFO     | __main__:<module>:17 - Found 1 versions for project RohanNagar/thunder
#
# 100%|██████████| 1/1 [00:00<00:00, 170.08it/s]
# 2022-10-26 11:18:59.282 | INFO     | __main__:<module>:17 - Found 1 versions for project gitbucket/solidbase
#
# 100%|██████████| 1/1 [00:00<00:00, 484.11it/s]
# 2022-10-26 11:18:59.288 | INFO     | __main__:<module>:17 - Found 1 versions for project ChronixDB/chronix.server
#
# 100%|██████████| 1/1 [00:00<00:00, 128.21it/s]
# 2022-10-26 11:18:59.302 | INFO     | __main__:<module>:17 - Found 1 versions for project in-memoriam/in-memoriam
#
# 100%|██████████| 1/1 [00:00<00:00, 661.77it/s]
# 2022-10-26 11:18:59.307 | INFO     | __main__:<module>:17 - Found 1 versions for project housepower/ClickHouse-Native-JDBC
#
# 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
#  71%|███████   | 79/111 [00:03<00:00, 47.47it/s]2022-10-26 11:18:59.330 | INFO     | __main__:<module>:17 - Found 1 versions for project isfaaghyth/Rak
#
# 100%|██████████| 1/1 [00:00<00:00, 539.74it/s]
# 2022-10-26 11:18:59.335 | INFO     | __main__:<module>:17 - Found 1 versions for project DukeNLIDB/NLIDB
#
# 100%|██████████| 1/1 [00:00<00:00, 267.12it/s]
# 2022-10-26 11:18:59.343 | INFO     | __main__:<module>:17 - Found 1 versions for project DeBukkIt/SimpleFileStorage
#
# 100%|██████████| 1/1 [00:00<00:00, 474.31it/s]
# 2022-10-26 11:18:59.349 | INFO     | __main__:<module>:17 - Found 1 versions for project datacleaner/DataCleaner
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.04it/s]
# 2022-10-26 11:18:59.520 | INFO     | __main__:<module>:17 - Found 1 versions for project Sheep-y/trpg-dnd-4e-db
#
# 100%|██████████| 1/1 [00:00<00:00, 240.36it/s]
# 2022-10-26 11:18:59.528 | INFO     | __main__:<module>:17 - Found 1 versions for project dharmapoudel/WebStore-Spring-MVC
#
# 100%|██████████| 1/1 [00:00<00:00, 370.55it/s]
#  77%|███████▋  | 85/111 [00:03<00:00, 40.51it/s]2022-10-26 11:18:59.535 | INFO     | __main__:<module>:17 - Found 1 versions for project Snapp-FidMe/react-native-image-base64
#
# 100%|██████████| 1/1 [00:00<00:00, 633.01it/s]
# 2022-10-26 11:18:59.540 | INFO     | __main__:<module>:17 - Found 1 versions for project seyhanp/seyhan
#
# 100%|██████████| 1/1 [00:00<00:00, 22.90it/s]
# 2022-10-26 11:18:59.590 | INFO     | __main__:<module>:17 - Found 1 versions for project gagoyal01/mongodb-rdbms-sync
#
# 100%|██████████| 1/1 [00:00<00:00, 63.15it/s]
# 2022-10-26 11:18:59.616 | INFO     | __main__:<module>:17 - Found 1 versions for project AuthMe/AuthMeReloaded
#
# 100%|██████████| 1/1 [00:00<00:00, 27.38it/s]
# 2022-10-26 11:18:59.665 | INFO     | __main__:<module>:17 - Found 1 versions for project hzpz/mongeez-spring-boot-starter
#
# 100%|██████████| 1/1 [00:00<00:00, 501.35it/s]
#  81%|████████  | 90/111 [00:03<00:00, 39.56it/s]2022-10-26 11:18:59.671 | INFO     | __main__:<module>:17 - Found 1 versions for project senx/warp10-platform
#
# 100%|██████████| 1/1 [00:00<00:00, 12.40it/s]
# 2022-10-26 11:18:59.771 | INFO     | __main__:<module>:17 - Found 1 versions for project ezhome/Android-RxFirebase
#
# 100%|██████████| 1/1 [00:00<00:00, 310.09it/s]
# 2022-10-26 11:18:59.778 | INFO     | __main__:<module>:17 - Found 1 versions for project fangjinuo/sqlhelper
#
# 100%|██████████| 1/1 [00:00<00:00, 23.53it/s]
# 2022-10-26 11:18:59.842 | INFO     | __main__:<module>:17 - Found 1 versions for project marklogic/java-client-api
#
# 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
# 2022-10-26 11:18:59.912 | INFO     | __main__:<module>:17 - Found 1 versions for project apache/cassandra-sidecar
#
# 100%|██████████| 1/1 [00:00<00:00, 189.63it/s]
#  86%|████████▌ | 95/111 [00:03<00:00, 31.43it/s]2022-10-26 11:18:59.923 | INFO     | __main__:<module>:17 - Found 1 versions for project arangodb/arangodb-java-driver-async
#
# 100%|██████████| 1/1 [00:00<00:00, 356.48it/s]
# 2022-10-26 11:18:59.930 | INFO     | __main__:<module>:17 - Found 1 versions for project marklogic/marklogic-data-hub
#
# 100%|██████████| 1/1 [00:00<00:00, 59.50it/s]
# 2022-10-26 11:18:59.956 | INFO     | __main__:<module>:17 - Found 1 versions for project eventsourcing/es4j
#
# 100%|██████████| 1/1 [00:00<00:00, 66.11it/s]
# 2022-10-26 11:18:59.978 | INFO     | __main__:<module>:17 - Found 1 versions for project amitshekhariitbhu/Android-Debug-Database
#
# 100%|██████████| 1/1 [00:00<00:00, 237.83it/s]
# 2022-10-26 11:18:59.987 | INFO     | __main__:<module>:17 - Found 1 versions for project mirkosertic/MogwaiERDesignerNG
#
# 100%|██████████| 1/1 [00:00<00:00, 26.95it/s]
#  90%|█████████ | 100/111 [00:03<00:00, 34.07it/s]2022-10-26 11:19:00.037 | INFO     | __main__:<module>:17 - Found 1 versions for project wangjiegulu/RapidORM
#
# 100%|██████████| 1/1 [00:00<00:00, 166.03it/s]
# 2022-10-26 11:19:00.048 | INFO     | __main__:<module>:17 - Found 1 versions for project 7ep/demo
#
# 100%|██████████| 1/1 [00:00<00:00, 224.94it/s]
# 2022-10-26 11:19:00.058 | INFO     | __main__:<module>:17 - Found 1 versions for project tylerbwong/Pokebase
#
# 100%|██████████| 1/1 [00:00<00:00, 250.03it/s]
# 2022-10-26 11:19:00.066 | INFO     | __main__:<module>:17 - Found 1 versions for project Ninja-Squad/DbSetup
#
# 100%|██████████| 1/1 [00:00<00:00, 379.06it/s]
# 2022-10-26 11:19:00.073 | INFO     | __main__:<module>:17 - Found 1 versions for project whirlwind-match/fuzzydb
#
# 100%|██████████| 1/1 [00:00<00:00, 22.70it/s]
# 2022-10-26 11:19:00.133 | INFO     | __main__:<module>:17 - Found 1 versions for project halestudio/hale
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
#  95%|█████████▌| 106/111 [00:04<00:00, 23.83it/s]2022-10-26 11:19:00.451 | INFO     | __main__:<module>:17 - Found 1 versions for project r2dbc/r2dbc-spi
#
# 100%|██████████| 1/1 [00:00<00:00, 175.95it/s]
# 2022-10-26 11:19:00.461 | INFO     | __main__:<module>:17 - Found 1 versions for project hugolgst/pine-database
#
# 100%|██████████| 1/1 [00:00<00:00, 346.41it/s]
# 2022-10-26 11:19:00.468 | INFO     | __main__:<module>:17 - Found 1 versions for project gsvigruha/cosyan
#
# 100%|██████████| 1/1 [00:00<00:00, 66.32it/s]
# 2022-10-26 11:19:00.489 | INFO     | __main__:<module>:17 - Found 1 versions for project cutiko/GeoFirebase
#
# 100%|██████████| 1/1 [00:00<00:00, 490.56it/s]
# 2022-10-26 11:19:00.495 | INFO     | __main__:<module>:17 - Found 1 versions for project indrekru/spring-boot-2-oauth2-resource-server
#
# 100%|██████████| 1/1 [00:00<00:00, 496.43it/s]
# 100%|██████████| 111/111 [00:04<00:00, 26.46it/s]

# %%
content
# Out:
# {'nolia|Noodle': ['com com noodle collection collection id storage random access file storage storage storage description storage record collection collection stored converted collection call collection gson converter storage bytes wrapper storage collection converter noodle storage encryption'],
#  'srotya|sidewinder': ['',
#   'sidewinder core api minuteman rpc sidewinder core functions list single series function sidewinder core predicates between predicate sidewinder core api database ops api minuteman cluster minuteman wal remote wal client sidewinder core storage series output sidewinder core functions list constant function sidewinder ingesters statsd sidewinder core utils time utils sidewinder core storage item not found exception sidewinder ingesters statsd statds decoder minuteman cluster router mod hash routing strategy sidewinder core api grafana target series sidewinder core functions list basic constant functions sidewinder ingesters statsd statsd server sidewinder core predicates not equals predicate sidewinder core utils misc utils minuteman cluster router sidewinder core functions list windowed aggregator sidewinder core storage storage engine sidewinder cluster storage sidewinder core predicates complex predicate sidewinder core analytics nd4j test sidewinder core storage archive exception sidewinder cluster storage clustered mem storage engine sidewinder core storage measurement sidewinder core functions list basic windowed functions sidewinder core predicates not predicate sidewinder core storage database sidewinder cluster utils sidewinder core predicates less than equals predicate sidewinder core functions list basic single functions sidewinder cluster storage tcp client sidewinder core api correlation ops api sidewinder core analytics math utils sidewinder core predicates and predicate sidewinder core storage mem mem storage engine sidewinder core api measurement ops api sidewinder cluster atomix atomix slave sidewinder core storage compression roll over exception sidewinder core predicates equals predicate sidewinder core storage data point sidewinder core functions list chain function sidewinder cluster atomix cluster table sidewinder core functions iterative sidewinder core predicates greater than predicate sidewinder core storage byte string sidewinder core functions list signal processing functions com sidewinder core functions list sidewinder core predicates or predicate sidewinder core api influx api sidewinder core sql calcite sidewinder cluster api delta api sidewinder core utils influx decoder sidewinder core sql calcite sidewinder database schema sidewinder core predicates less than predicate sidewinder core storage processor point processor sidewinder core sql calcite sql functions sidewinder core storage no lock sidewinder core predicates greater than equals predicate sidewinder ingesters sidewinder cluster api merkle tree utils sidewinder core monitoring metrics registry service sidewinder core sql calcite sidewinder table schema sidewinder ingesters influx sidewinder core utils byte utils sidewinder core api grafana sidewinder core sql calcite sidewinder schema factory sidewinder core security user sidewinder ingesters graphite sidewinder core storage disk sidewinder core storage disk persistent measurement sidewinder core storage compression gorilla compressor sidewinder core sql calcite measurement enumerator implementation sidewinder cluster sidewinder core storage archival time series archival object sidewinder core utils invalid filter exception sidewinder core storage series sidewinder core storage compression gorilla bit output sidewinder cluster cluster resource monitor sidewinder core sql calcite measurement table minuteman connectors cluster connector sidewinder core storage disk mapped bitmap tag index sidewinder core storage archival sidewinder core storage compression gorilla gorilla value writer sidewinder core storage db metadata sidewinder core utils grafana streaming output sidewinder core storage processor sidewinder core storage compression gorilla gorilla value reader sidewinder cluster sidewinder clustered server sidewinder core api grafana grafana outputv2 sidewinder core storage malloc sidewinder core storage mem mem malloc sidewinder core storage compression sidewinder core storage compre ...
#  'zapr-oss|druidry': ['',
#   '',
#   'druid druidry extraction functions druid druidry extraction functions string format extraction function druid druidry query metadata druid segment metadata query druid druidry client druid configuration druid druidry dimension extraction dimension druid druidry granularity predefined granularity druid druidry extraction functions extraction function druid druidry client druid query protocol druid druidry granularity simple granularity druid druidry extensions histogram post aggregator druid druidry dimension simple dimension druid druidry extensions histogram post aggregator max post aggregator druid druidry client druid jersey client druid druidry extraction functions partial extraction function druid druidry granularity period granularity druid druidry post aggregator druid post aggregator druid druidry dimension regex filtered dimension druid druidry client druid error druid druidry extraction functions registered look up extraction function druid druidry query select druid select query druid druidry look up spec look up spec druid druidry extensions histogram post aggregator quantile post aggregator druid druidry extensions datasketches druid druidry client exception druid druidry extensions histogram post aggregator equal buckets post aggregator druid druidry extraction functions search query extraction function druid druidry query select paging spec druid druidry extensions datasketches post aggregator druid druidry averager druid druidry filter search query spec search query spec druid druidry extensions histogram post aggregator custom buckets post aggregator druid druidry averager long sum averager druid druidry filter search query spec insensitive contains search query spec druid druidry averager druid averager druid druid druidry extensions histogram post aggregator min post aggregator druid druidry extraction functions regex extraction function druid druidry filter search query spec regex search query spec druid druidry averager long mean averager druid druidry extraction functions time parsing extraction function druid druidry extensions histogram post aggregator quantiles post aggregator druid druidry filter search query spec fragment search query spec druid druidry averager double mean averager druid druidry extraction functions cascade extraction function druid druidry extensions histogram aggregator druid druidry extensions distinctcount druid druidry filter search query spec contains search query spec druid druidry extensions histogram aggregator approx histogram aggregator druid druidry averager long mean no nulls averager druid druidry extraction functions str len extraction function in druid druidry query scan result format druid druidry extensions histogram aggregator approx histogram fold aggregator druid druidry averager double max averager in zapr druid druidry extraction functions look up extraction function druid druidry query scan druid scan query druid druidry extensions histogram aggregator quantile post aggregator druid druidry druid druidry averager long min averager druid druidry extraction functions sub string extraction function druid druidry post aggregator druid druidry averager double sum averager druid druidry post aggregator arithmetic post aggregator druid druidry extraction functions time format extraction function druid druidry post aggregator arithmetic ordering druid druidry granularity granularity druid druidry averager double mean no nulls averager druid druidry post aggregator arithmetic function druid druidry granularity druid druidry averager double min averager druid druidry extraction functions javascript extraction function druid druidry look up spec druid druidry averager long max averager druid druidry query config druid druidry post aggregator constant post aggregator druid druidry limit spec druid druidry query config context druid druidry top n metric druid druidry query config group by strategy druid druidry post aggregator hyper unique cardinality post aggregator d ...
#  'cinchapi|concourse': ['',
#   '',
#   '',
#   'concourse importer csv importer org cinchapi concourse server http routers index router concourse util file ops concourse server storage temp concourse common util non blocking hash multimap concourse server upgrade upgrader concourse server http http requests concourse util networking common common util incremental sort map simple route matcher concourse server storage versioned concourse server concourse server concourse util object utils concourse util concourse importer cli spark concourse util multimap views concourse server http router filter tools jsr166e concourse util t lists concourse server storage temp capacity exception spark ResponseTransformerRoute concourse util natural sorter spark Request spark filter jsr166e ForkJoinWorkerThread concourse util collections concourse server storage temp limbo matcher filter spark HaltException concourse util timestamps jsr166e ForkJoinPool concourse server http http args concourse server cli concourse timestamp spark AbstractRoute spark application concourse server cli env tool cli jsr166e LongAdder concourse server http resource concourse server storage permanent store concourse annotate authorized concourse util version concourse server jmx concourse server mx bean jsr166e Striped64 spark Access concourse server model t object sorter concourse server http errors bad login syntax error spark Spark thrift async concourse server cli options concourse util long bit set jsr166e StampedLock spark Response concourse server storage base store concourse util auto skip list map concourse server cli managed operation cli concourse security passwords jsr166e ThreadLocalRandom io utils concourse annotate must override concourse annotate experimental concourse server http routers help router concourse server storage temp buffer spark Session concourse server cli manage users cli jsr166e LongAdderTable concourse util auto map concourse server model ranges jsr166e ConcurrentHashMapV8 http method concourse server storage db database concourse server cli environment options concourse util pretty linked table map route match jsr166e CompletableFuture concourse server concurrent concourse executors concourse thrift t parse exception concourse util reflection jsr166e ForkJoinTask concourse server cli dump tool cli spark utils concourse server concurrent token concourse server storage version change listener concourse server concurrent locks concourse util convert jsr166e CompletionException spark QueryParamsMap concourse tag concourse server concurrent guava internals concourse thrift t criteria concourse link concourse annotate restricted jsr166e LongMaxUpdater concourse thrift t symbol concourse server concurrent lock service concourse server storage version change notifier concourse time string to time route matcher factory concourse annotate package private concourse server concurrent abstract lock service jsr166e RecursiveAction concourse thrift t symbol type route matcher concourse concourse concourse server storage inventory concourse util byte buffers concourse server concurrent token read write lock concourse server storage version getter concourse thrift access token jsr166e RecursiveTask concourse server io byteable collections spark server concourse thrift operator concourse server concurrent lock type concourse thrift transaction token concourse server concurrent priority read write lock spark server factory concourse annotate utility class jsr166e CountedCompleter concourse server storage stores concourse server concurrent range token spark template concourse security client security spark Filter concourse util strings concourse server storage temp queue jsr166e DoubleAdder mustache template route concourse transaction exception concourse thrift t object spark RequestResponseFactory template route concourse server concurrent atomic lock jsr166e DoubleMaxUpdater concourse lang buildable state concourse thrift type concourse server storage db concourse server concurrent range lock ...
#  'DevinZ1993|SimpleDB-Database-System': ['',
#   '',
#   '',
#   '',
#   'simpledb simpledb RecordId simpledb Operator simpledb StringAggregator simpledb LogicalFilterNode simpledb ParsingException simpledb Aggregator simpledb Parser simpledb HeapFileEncoder simpledb CostCard simpledb AbstractDbFileIterator simpledb Delete simpledb LogicalJoinNode simpledb TransactionAbortedException simpledb LogFile simpledb Project simpledb Insert simpledb DbFileIterator simpledb Join simpledb CommitRecord simpledb TupleIterator simpledb JoinPredicate simpledb Transaction simpledb DbException simpledb BeginRecord simpledb AbortRecord simpledb Aggregate simpledb IntField simpledb LogRecord simpledb Tuple simpledb CheckPointRecord simpledb IntegerAggregator simpledb PlanCache simpledb TupleArrayIterator simpledb StringHistogram simpledb BufferPool simpledb Field simpledb Type simpledb DbFile simpledb IntHistogram simpledb Predicate simpledb TupleComparator simpledb Catalog simpledb LogicalPlan simpledb LockManager simpledb Debug simpledb UpdateRecord simpledb Query simpledb TransactionId simpledb JoinOptimizer simpledb LogicalSelectListNode simpledb Utility simpledb TupleDesc simpledb Page simpledb LogicalScanNode simpledb HeapPage simpledb StringField simpledb Database simpledb Filter simpledb HeapFile simpledb LogicalSubplanJoinNode simpledb TableStats simpledb Permissions simpledb OrderBy simpledb HeapPageId simpledb SeqScan simpledb DbIterator simpledb PageId simpledb SimpleDb'],
#  'Hemen07|Groupy': ['',
#   '',
#   '',
#   '',
#   '',
#   'redfox util common util util validation data redfox chatroom ui profile profile ui login ui reset password util common util util snack bar profile ui login login activity ui reset password password reset util common util util snack bar register ui interfaces firebase auth callbacks ui interfaces pwd reset callbacks data models sign up model ui main screen main activity util common util util constant network util common util util net dialog receiver ui interfaces load messages callbacks util common util util snack bar auth ui data models receiver constant net monitor receiver ui interfaces ui interfaces adapter callbacks ui interfaces net dialog btn callbacks network handler callbacks ui adapter util firebase util util fb constants network net monitor callbacks ui interfaces tag image callbacks ui interfaces input validation callbacks ui main screen load message thread network handler thread ui holders ui adapter message adapter ui signup sign up activity ui signup util common util ui holders sent message holder util common util util extra ui main screen util common util util snack bar common ui holders received message holder util common util util network detect ui profile util common util util image data models message model data models image model data pref sign in pref example instrumented test data pref util common util util snack bar login util common util util notification util firebase util util firebase util util authentication util util common util util cal'],
#  'r2dbc|r2dbc-client': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'client util client handle client query client util reactive utils client client batch client util assert client result bearing client update io client r2dbc io r2dbc'],
#  'jrvansuita|SQLiteHelper': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com sqliteparser sql parser sqliteparser insert com vansuita sqliteparser delete sqlitehelper sample sqliteparser sqliteparser create sqlitehelper sample main activity sqliteparser query sqliteparser content sqliteparser utils sqliteparser cursor sqlitehelper'],
#  'ome|openmicroscopy': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'pojos ome model ome performance data annotation transformations pojos model2 pojos mapper ome data thumbnail reflection utils project string utils abstract omero hierarchy browser integration test pojos PixelsData base model utils hierarchy transformations group model mapper hierarchy browsing tests classification utils dataset annotation ome aop hibernate abstract pojos service test dataset return logger builders hibernate container dao hibernate pojos ImageData exception handler formal output ome rules container dao drools engine category ome client rules engine channel component image annotation hibernate proxy cleanup filter ome logic category group pojos impl drools hibernate omero session factory bean image pixel ome dynamic hibernate annotation dao hibernate omero db class loader experimenter dao factory annotation dao drools all objects session updater pojos ProjectData hibernate queries pojos query builder analysis chain link hibernate pixels dao hibernate drools filter build runner pojos CategoryData analysis chain pixels dao analysis impl build time drools graph rule pojos CategoryGroupData analysis chain execution formal input pojos DatasetData code generation hibernate generic dao hibernate drools classification exclusivity rule analysis chain node generic dao image binary service drools time rule pixels impl pojos AnnotationData binary service impl hibernate analysis dao hibernate ome security pojos ExperimenterData analysis dao semantic element utils jdbc class loader write impl pojos omero entry hibernate queries crypt semantic type output ome api ome session pojos authentication dao builders pojo options semantic type hierarchy browsing service factory granted authority impl pojos module analysis node execution primitive hierarchy browsing pojos omero exception pojos DataObject ome adapters results ome conditions hierarchy browsing impl repository ome policy image dimension root exception pixels rendering setting ome model ome util feature write context filter image info filterable analysis module execution filter ome facade ome testing primitive hierarchy browsing impl model based ome dao logical channel ome tools'],
#  'dbeaver|dbeaver': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'dbeaver ext oracle edit tools ant driverman generate features task dbeaver model exec jdbc jdbc database meta data dbeaver ext nosql cassandra data cassandra struct value handler dbeaver ext oracle edit oracle package manager dbeaver runtime jobs connect job dbeaver tools transfer stream dbeaver ext erd editor erd editor standalone dbeaver model impl edit abstract database persist action tools ant driverman driver info dbeaver tools transfer stream stream consumer page output dbeaver model impl jdbc struct jdbc data type dbeaver ui actions datasource data source invalidate handler dbeaver ext oracle oracle messages dbeaver tools transfer stream stream consumer settings dbeaver ext erd navigator dbn diagram folder dbeaver ui editors text dbeaver model impl jdbc jdbc constants dbeaver ext oracle model oracle global object dbeaver ext erd dnd data element factory dbeaver ui editors text line number column dbeaver runtime jobs invalidate job dbeaver model impl resources abstract resource handler dbeaver ext import config wizards dbvis dbeaver ext oracle model oracle schema dbeaver tools transfer stream stream transfer consumer dbeaver ext erd dnd object creation factory dbeaver model impl jdbc cache jdbc object simple cache dbeaver ui editors text property event dispatcher dbeaver ext db2 views dbeaver ext erd editor erd editor input dbeaver model edit dbe command context dbeaver ext erd dnd data edit drop target listener dbeaver tools transfer stream i stream data exporter site dbeaver ui actions datasource data source rollback handler dbeaver ext db2 views db2 connection trace page dbeaver ui editors text text change hover dbeaver ext erd model diagram loader dbeaver ext oracle model oracle schema object dbeaver model impl jdbc cache jdbc composite cache dbeaver ext erd dnd node drop target listener dbeaver ui editors text base text document provider dbeaver ext i database persist action dbeaver model exec dbc result set dbeaver ext db2 views db2 connection page dbeaver ext erd navigator create diagram handler dbeaver ui editors text file ref document provider dbeaver model impl jdbc edit struct jdbc object editor dbeaver model exec dbc attribute meta data dbeaver runtime jobs disconnect job dbeaver ext db2 activator dbeaver ext mysql model my sql partition dbeaver model edit dbe object maker dbeaver runtime load dbeaver ui editors text text editor property tester dbeaver model impl dbs object cache dbeaver ui actions datasource data source tools contributor dbeaver tools transfer stream i stream data exporter dbeaver ext oracle model plan dbeaver runtime load i load service dbeaver ext oracle model oracle package dbeaver ui editors text handlers abstract text handler dbeaver ext oracle model plan oracle plan analyser dbeaver ext mssql views mssql connection page dbeaver ui actions datasource data source menu contributor dbeaver ext oracle model oracle utils dbeaver ext oracle model plan oracle plan node dbeaver tools transfer stream i stream data exporter descriptor dbeaver model runtime dbr blocking object code nullable dbeaver ui actions datasource data source transaction mode contributor dbeaver ui editors text script position column dbeaver ui dialogs struct create entity dialog dbeaver ext mysql model query transformer fetch all dbeaver ext mysql tools my sql tool script dbeaver runtime load database load service dbeaver tools transfer stream stream consumer page settings utils common utils dbeaver ext oracle model oracle object type dbeaver ext mysql model my sql dialect dbeaver ext mysql tools my sql script execute wizard dbeaver runtime load jobs dbeaver ui editors text handlers dbeaver ext oracle edit oracle trigger manager dbeaver ui actions datasource data source auto commit handler dbeaver core application dbeaver ui preferences pref page data format dbeaver ext erd command association create command dbeaver ext mysql tools my sql database wizard page settings dbeaver ext mysql model query transformer limit dbeav ...
#  'janmotl|linkifier': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'main utility MultiMap metrics needleman wunch main Accuracy metrics string metrics simplifiers match rating approach main Relationship simplifiers simplifier main Doppelganger simplifiers daitch mokotoff soundex main Table utility LCS metrics levenshtein builders string distance builder main Column metrics longest common subsequence simplifiers refined soundex utility String2Num utility Multiplication export utility Tpc metrics jaro main NullsExpected simplifiers nysiis utility MultiSet main Setting metrics longest common substring utility Levenshtein metrics functions metrics monge elkan simplifiers metaphone metrics functions gap metrics jaro winkler utility Tokenization metrics functions constant gap org utility NonNullByDefault metrics damerau levenshtein utility Histogram vendor example metrics functions match mismatch vendor Default simplifiers soundex utility Logistic metrics functions substitution example Demo metrics simon white utility Chen vendor MySQL metrics overlap coefficient utility TokenShareRatio metrics functions linear gap vendor PostgreSQL example Linkifier metrics cosine similarity vendor MSSQL metrics functions affine gap export Justification main TrainingRelationship metrics identity vendor Oracle main Schema org simmetrics builders string metric builder string metric main Optimization metrics dice vendor QualityControl metric tokenizers tokenizer vendor VendorFactory tokenizers tokenizers metrics tanimoto coefficient multiset distance tokenizers abstract tokenizer distance utility HeapWithFixedSize metrics hamming distance vendor Vendor multiset metric metrics jaccard metrics math set distance main Training builders string metrics list metric metrics smith waterman gotoh main Scoring metrics generalized overlap coefficient export GraphML builders string distances set metric metrics euclidean distance list distance export CSV metrics generalized jaccard export DDL string distance export TGF metrics smith waterman tokenizers main CompoundRelationship simplifiers double metaphone metrics main OptimizationRelationship metrics block distance builders simplifiers caverphone1 export SQL simplifiers simplifiers caverphone2 utility simplifiers simplifiers metrics string distances utility Hungarian simplifiers cologne phonetic'],
#  'JumpMind|symmetric-ds': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'symmetric io data transform db platform oracle oracle ddl builder symmetric service i data extractor service db platform mariadb maria db database platform persist symmetric io data transform i single value column transform symmetric ext symmetric io stage staging file lock symmetric service impl offline pull service persist i persistence manager db platform mysql my sql database platform symmetric io data transform i column transform symmetric ext ftp data loader factory db abstract ddl types test symmetric io data writer ms sql bulk database writer test persist abstract persistence manager symmetric route i data router db platform hana hana database platform symmetric route java data router symmetric transport file file incoming transport symmetric io data transform new and old value symmetric util symmetric utils db platform db2 db platform firebird firebird database platform symmetric io data transform substr column transform symmetric service i offline pull service db platform db2 db2 database platform properties environment specific properties symmetric io data reader extract data reader db platform greenplum greenplum platform symmetric io data transform i single new and old value column transform symmetric ext ms sql bulk data loader factory db platform db2 db2 ddl builder symmetric transport batch buffered writer db platform i database platform db sql db platform informix informix database platform symmetric service impl client extension service db sql i sql row mapper db platform db2 db2 ddl reader symmetric io data transform transformed data db io db platform sqlite sqlite database platform symmetric service impl extension service symmetric service i trigger router service db platform db2 db2 jdbc sql template symmetric io data transform ignore row exception db alter symmetric ext teradata bulk data loader factory symmetric io data writer database writer error ignorer db platform raima raima database platform symmetric io data data context symmetric service i outgoing batch service symmetric service impl trigger router service db platform symmetric service symmetric io data transform ignore column exception db platform redshift symmetric service impl cluster lock refresh listener db platform hsqldb2 hsql db2 database platform db platform redshift redshift dml statement symmetric io data data event type symmetric ext redshift bulk data loader factory symmetric io data writer transform writer test symmetric util counter stat db platform firebird firebird dialect1 database platform extension i built in extension point db platform db2 db2 as400 database platform symmetric config i trigger creation listener symmetric config symmetric service i router service db platform redshift redshift jdbc sql template db platform hbase hbase platform symmetric io data transform transform column db platform postgresql postgre sql95 database platform db platform db2 db2 as400 ddl reader symmetric io data writer transform writer db platform redshift redshift ddl builder symmetric ext big query data loader factory symmetric io data transform transform table db platform postgresql postgre sql database platform db platform db2 db2 as400 ddl builder symmetric common table constants symmetric config trigger failure listener symmetric io data writer database writer conflict test symmetric io data csv data db platform redshift redshift database platform db platform bigquery symmetric config trigger selector symmetric service i sequence service db model table db platform sybase symmetric ext i database upgrade listener symmetric service i node communication service$ i node communication executor symmetric io data transform copy column transform db platform redshift redshift ddl reader symmetric io data transform column policy db platform mariadb symmetric service impl configuration service sql map symmetric io data transform target dml action db platform postgresql symmetric service i service symmetric io data transform transform point symme ...
#  'fauna|faunadb-jvm': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com client errors permission denied exception client streaming event fields com faunadb client errors fauna exception client streaming event field client query client types path client types decoder client types field client query language client types value client types deserializer client errors unavailable exception client types fauna enum client query pagination client types types client streaming snapshot event flow processor client query fn client types result client errors internal exception client types transformations client query expr client errors transaction contention exception client errors streaming exception client types encoder client types enums client errors unauthorized exception client types codecs client types codec common client common http response body string processor client types fauna field client http responses common http driver version checker client errors not found exception client types properties client fauna client common connection common http client types fauna ignore client errors bad request exception client errors unknown exception client errors client util symbol generator client types constructors client util client types metrics response client streaming client streaming body value flow processor client types fauna constructor client types'],
#  'Jamling|Android-ORM': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'aorm aorm mapping factory aorm mapping aorm db sqlite sq lite database aorm example example content provider aorm annotation table aorm example main activity aorm example aorm db table info aorm example abstract base adapter android aorm annotation table wrap aorm annotation aorm criteria aorm example student detail activity aorm annotation column wrap android database aorm order android util android net aorm orm exception fast print writer aorm restrictions aorm example student grade activity sqlite aorm session observer cn printer handler aorm update intercepter cn ieclipse aorm example list activity content values content observer android content aorm example bean uri aorm column meta aorm example course list activity aorm example bean course aorm example course detail activity aorm session aorm annotation column sqlite sq lite program sqlite sq lite closable aorm example bean grade aorm aorm log aorm example bean student sqlite sq lite open helper aorm db column info aorm example example application aorm example detail activity cursor content resolver aorm example base activity aorm example student list activity aorm cursor utils android os sqlite sq lite statement aorm example student grade detail activity'],
#  'mkalus|segrada': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'config service repository relation type repository rendering markup markup filter config template module util image manipulator model base abstract segrada entity servlet segrada message body reader service repository orientdb base abstract colored orient db repository rendering markup markup filter factory search search hit util jd min max renderer servlet thymeleaf view processor service repository orientdb orient db relation repository rendering export config authentication module util application status changed listener rendering export exporter service repository orientdb orient db config repository auth check authentication util text extractor service repository orientdb querybuilder service repository factory service repository config repository rendering export gexf exporter session application settings properties service repository orientdb querybuilder query part worker dynamic query rendering service repository orientdb util abstract late converter model prototype i relation service repository orientdb orient db file repository session application settings service repository prototype service model prototype segrada taggable service repository orientdb querybuilder query part worker service repository prototype search term repository rendering markdown config service module service repository orientdb base abstract core orient db repository service base search term service model prototype i relation type service repository orientdb orient db node repository service relation service service repository prototype segrada repository service repository node repository util flexible date parser service repository prototype paginating repository or service service repository orientdb factory orient db repository factory search service repository orientdb querybuilder query builder search solr solr search engine service repository orientdb orient db location repository controller service repository orientdb querybuilder query part worker manual list search search engine rendering markdown page markdown renderer org segrada search lucene service repository location repository service repository orientdb orient db source repository service source reference service model savedquery segrada launcher service repository orientdb base abstract orient db repository service base abstract repository service service base segrada service model prototype i tag service repository prototype crud repository service repository orientdb querybuilder query part worker factory service file service service repository orientdb base abstract segrada orient db repository model prototype i node model prototype i file util pbkdf2 with hmac sha1 password encoder service util abstract lazy loaded object model savedquery graph data service repository orientdb orient remember me repository controller base abstract colored controller model prototype i saved query service binarydata binary data service file service repository orientdb orient db saved query repository model prototype i source search lucene lucene search engine model util service base binary data handler service repository orientdb base abstract orient db base repository model util fuzzy flag service node service service repository saved query repository servlet service base abstract full text service servlet orient db filter model service repository orientdb orient db user repository service relation type service model user model relation service repository remember me repository service repository user repository service repository orientdb init orient db schema updater model base abstract core model org service location service segrada application search lucene lucene segrada analyzer service repository orientdb orient db color repository service comment service controller login controller model location service repository color repository util password encoder model prototype i location model user group service user service service repository orientdb orient db comment repository ser ...
#  'quantumdb|quantumdb': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'core backends core migration version traverser cli xml xml column core migration operations create table migrator core backends planner migration state core backends backend core schema definitions copyable core migration migrator core schema definitions postgres types core schema operations create index cli core backends database migrator core backends planner operation core migration operations schema operation migrator cli cli core schema operations add column core versioning version core backends planner graph core schema operations column definition cli main core core versioning state core schema definitions column type core migration operations core planner postgresql migrator core migration operations transitive table mirrorer cli commands status core schema core versioning change set core schema definitions identity core schema operations cli utils cli writer core backends config core migration cli xml xml drop foreign key core versioning version id generator core migration operations alter column migrator cli commands fork core versioning core backends postgresql core planner table data migrator core schema operations drop foreign key core utils random hasher core planner cli commands query core backends planner core planner table creator core utils core migration operations create view migrator cli xml cli xml xml drop view cli commands nuke core versioning backend core schema definitions sequence driver core schema operations drop view cli xml xml drop table cli commands init core schema definitions pretty string writer core schema definitions catalog core schema operations drop table driver proxy callable statement core planner null records core migration operations add column migrator cli commands command driver transformer cli xml xml operation core versioning operations cli xml xml create view cli commands changelog core planner postgresql backend driver proxy connection core schema operations schema operations cli xml xml query core migration operations drop foreign key migrator cli commands cleanup core versioning quantum tables cli xml xml element query rewriter query rewriter core planner sync function core schema operations create view cli commands drop core schema definitions table core backends planner plan validator driver driver cli xml xml drop default expression core migration operations cleanup tables migrator cli commands cli xml xml drop index query rewriter postgresql query rewriter core schema operations alter column core planner query utils core schema operations drop index cli utils driver proxy prepared statement cli xml xml rename table core planner migrator function core migration operations drop table migrator core schema operations partition table core schema operations rename table driver proxy database meta data query core migration operations add foreign key migrator driver meta result set cli xml xml add foreign key cli xml xml alter column core schema operations decompose table driver proxy statement core planner selective migrator function core schema operations add foreign key cli xml xml copy table core schema operations cleanup tables core migration operations drop index migrator core schema definitions foreign key cli xml xml drop column core schema operations join table core schema definitions query rewriter experimental cli xml xml create table core schema operations merge table core migration operations create index migrator cli xml xml alter default expression cli utils cli exception cli xml xml create index core backends postgresql migrator core schema definitions index core backends postgresql migrator view creator cli xml changelog loader core migration operations drop view migrator core planner postgresql migration planner core versioning changelog core versioning ref log core schema operations data operation core backends planner plan cli xml xml changelog core utils query builder core backends planner step core schema definitions view core utils output file cli xml x ...
#  'xpinjection|test-driven-spring-boot': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com library adaptors persistence entity library domain library service dto library adaptors api book rest controller com xpinjection library config init library service impl library service dto recommendation library service impl expert service impl library adaptors api expert rest controller library service library config init application started without active profile exception library config default library initializer library service exception invalid recommendation exception library service expert service library adaptors api dto new expert library config init dev environment configurer library library service dto create expert dto library adaptors persistence library config init http server port logger library config actuator basic security config library library application library adaptors api common error handler library adaptors persistence expert dao library service book service library config library settings library config init active profile missed failure analyzer library config demo runner library adaptors persistence entity expert entity library adaptors api dto library service dto book dto library config init active profiles checker library adaptors persistence book dao library config api config library service dto books library adaptors library adaptors ui library domain book library adaptors ui book controller library config library service exception library adaptors api library service impl book service impl'],
#  'FrangSierra|RxFirebase': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'durdinapps rx firebase database rx firebase auth exceptions rx firebase data cast exception rx handler durdinapps rxfirebase2 exceptions rx firebase null data exception rx firebase child event rx firebase remote exceptions rx firebase user document snapshot mapper rx completable handler data snapshot mapper rx firebase storage rx firestore rx firebase functions rx firebase query exceptions rx firebase data exception rx firestore offline handler'],
#  'Eldelshell|amforeas': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'amforeas enums demo xstream usage limit param error code xstream success response permission update demo singleton factory xstream amforeas response operator insert jdbc connection factory demo jetty xstream pagination jdbc driver dialect dialect factory xstream head response model query params dialect my sql dialect car maker model success response model pagination dialect dialect amforeas xstream error response model row dialect postgre sql dialect amforeas PerformanceLogger model amforeas response dialect hsql dialect amforeas exceptions startup exception database configuration amforeas RestController amforeas bad request exception model error response dialect h2 dialect dialect derby dialect amforeas handler model stored procedure param amforeas result set handler amforeas App model head response select count result set handler amforeas AmforeasJetty amforeas acl result set meta data handler acl filter amforeas config acl manager amforeas properties amforeas configuration system wrapper select param acl rule amforeas property amforeas SingletonFactory amforeas SingletonFactoryImpl amforeas AmforeasShutdown amforeas rest amforeas cache amforeas resource simple cache amforeas client amforeas DefaultRestService amforeas client handler amforeas AmforeasWS handler amforeas response handler request params amforeas RestService amforeas sql app dialect amforeas demo dialect mssql dialect amforeas ws impl amforeas rest client dialect sql dialect xstream dialect oracle dialect amforeas filter delete default format filter order param amforeas AmforeasUtils amforeas jdbc jdbc executor table xstream row demo configuration dynamic finder stored procedure param'],
#  'maskarade|Android-Orma': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'gfx android orma processor generator deleter writer gfx android orma annotation gfx android orma example orma gfx android orma migration migration engine gfx android orma annotation getter gfx android orma rx rx relation gfx android orma processor generator relation writer gfx android orma gfx android orma access thread constraint gfx android orma annotation static type adapters gfx android orma processor processing context gfx android orma event gfx android orma rx rx orma connection gfx android orma annotation static type adapter gfx android orma migration manual step migration gfx android orma processor util types gfx android orma processor model database definition gfx android orma rx rx inserter gfx android orma encryption encrypted database statement gfx android orma migration orma migration gfx android orma annotation database gfx android orma processor util strings gfx android orma processor model schema definition gfx android orma example tool type adapters gfx android orma event data set changed event gfx android orma annotation on conflict gfx android orma processor util annotations gfx android orma processor generator association condition writer gfx android orma example tool large log gfx android orma rx rx updater gfx android orma association def gfx android orma annotation primary key gfx android orma migration sqliteparser g gfx android orma processor generator schema writer gfx android orma inserter gfx android orma example activity main activity gfx android orma exception orma exception gfx android orma annotation virtual table gfx android orma processor model type adapter definition gfx android orma exception database access on main thread exception gfx android orma processor model column definition gfx android orma example fragment main fragment gfx android orma model factory gfx android orma annotation column gfx android orma processor tool annotation handle gfx android orma example fragment benchmark fragment gfx android orma exception type adapter not found exception gfx android orma processor model association definition gfx android orma annotation experimental gfx android orma processor tool synchronized filer gfx android orma updater gfx android orma example fragment list view fragment gfx android orma exception insertion failure exception gfx android orma annotation index gfx android orma processor generator database writer gfx android orma example fragment recycler view fragment gfx android orma migration sqliteparser sq lite parser utils gfx android orma processor model index definition gfx android orma exception transaction abort exception gfx android orma rx rx single association gfx android orma annotation setter gfx android orma processor util sql types gfx android orma exception no value exception gfx android orma example handwritten hand written open helper gfx android orma annotation table gfx android orma exception invalid model exception gfx android orma single association gfx android orma migration sqliteparser gfx android orma processor generator sql generator gfx android orma processor model schema validator gfx android orma internal gfx android orma example orma item2 gfx android orma gson single association type adapter factory gfx android orma migration sqliteparser sq lite component gfx android orma internal type holder gfx android orma example orma category gfx android orma migration sqlite ddl builder gfx android orma rx rx data set changed trigger gfx android orma processor util gfx android orma internal orma iterator gfx android orma core database gfx android orma migration sqliteparser create table statement gfx android orma example orma entry gfx android orma selector gfx android orma processor model gfx android orma migration sqliteparser select statement gfx android orma migration migration schema gfx android orma processor tool gfx android orma event data set changed trigger gfx android orma internal aliases gfx android orma example orma item gfx android orma processor g ...
#  'dpoluyanov|achord': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...
#  'halestudio|hale': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'hale common schema model validate factory impl number validator factory hale io codelist xml reader hale common align io impl internal generated condition type hale io xslt ui x path parameter page hale common instance geometry impl hale io codelist xml reader xml code list hale common schema model validate factory validator factory hale common align io impl internal property bean hale common codelist code list hale ui schema presets internal schema preset label provider hale common align io impl internal generated q name type hale ui schema presets extension named hale common schema model validate factory impl pattern validator factory hale io codelist xml reader xml code list reader hale common instance geometry impl internal hale common align io impl internal generated class type hale common core io progress indicator hale ui schema presets internal schema preset selection dialog hale common schema model validate factory impl abstract combined validator factory metaclass hale common app application util hale common core io report io report hale common align io impl internal generated child context type metaclass custom meta class creation handle hale ui schema presets internal schema preset content provider util validator combined validator hale common core io impl abstract import provider hale ui schema presets internal schema preset comparator hale common core io util hale common align io impl internal abstract base alignment loader hale common core io io provider configuration exception hale common schema model validate factory impl enumeration validator factory hale common core io util debug input stream util io path update hale common codelist io code list reader hale common core io util input stream decorator hale common align model impl default alignment hale common schema model validate factory impl and validator factory hale common core io report io reporter hale common core io util g zip content describer util io io utils hale common core io util output stream decorator hale ui templates extension project template extension hale ui views schemas explorer hale common schema model validate factory impl digit count validator factory hale ui views schemas explorer entity schema explorer hale common core io util g zip xml root element content describer hale io gml reader internal instance group property hale ui util viewer tree tree path provider adapter hale common align io impl internal modifier bean hale common schema model validate factory impl length validator factory hale common core io util g zip xml content describer hale ui service entity util entity type index content provider hale io gml reader internal instance group util hale common schema model validate factory impl or validator factory hale ui views schemas explorer schema explorer hale common schema model validate factory hale ui function contribution set transformation mode contribution hale common align io impl internal entity bean hale ui views schemas internal schemas view plugin hale common schema model validate factory extension validator factory extension util definition abstract object factory hale common core io project hale io gml reader internal instance group path hale ui common definition viewer inherited properties filter hale common core io project project test hale ui function contribution replace function wizard contribution hale common schema schema space id hale common schema model validate factory extension hale common align io impl internal child context bean hale common core io project complex configuration service hale ui util viewer filter action hale ui service entity hale common align io impl internal type bean hale common core io project project reader hale ui service entity util entity type index hierarchy hale ui service entity util content provider action hale common core io project project writer hale ui service entity internal hale ui service population unpopulated properties filter hale ui functions groovy internal pa ...
#  'r2dbc|r2dbc-spi': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'io spi r2dbc data integrity violation exception spi constant pool spi batch spi out parameter metadata io r2dbc spi validation depth spi r2dbc permission denied exception spi spi clob spi default lob spi connection factory provider spi result spi r2dbc exception spi type spi connection factories spi nullable spi r2dbc non transient resource exception spi blob spi row spi r2dbc non transient exception spi isolation level spi r2dbc transient resource exception spi row metadata spi transaction definition spi closeable spi assert spi column metadata spi r2dbc bad grammar exception spi out parameters spi nullability spi readable metadata spi readable spi parameters spi lifecycle spi r2dbc timeout exception spi connection factory spi connection url parser spi wrapped spi connection factory metadata spi parameter spi option spi r2dbc type spi out parameters metadata spi connection factory options spi connection spi non null api spi statement spi r2dbc rollback exception spi no such option exception spi connection metadata spi r2dbc transient exception'],
#  'hugolgst|pine-database': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'fr pine api request pine core connector fr iambluedev pine core utils method pine core table table pine api connector pine core field xyz pine api connector i connector pine pine api database i database pine core field field pine xyz anana pine core pine core connector my sql connector pine core field fields pine api table pine core request request handler pine core request pine api table i table pine api pine api request i request pine core table pine api field i fields pine api database pine core connector maria db connector pine core database database pine core database pine api field i field pine api field pine core utils'],
#  'gsvigruha|cosyan': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com cosyan db entity load entity statement db index db transaction meta resources db db lang sql users db entity entity meta statement db io table io db model table meta$ exposed table meta db util ui db lang sql alter statement columns db model derived tables db auth local users db session db model references$ referenced table ui entity db io raf buffered input stream db entity entity db lang expr func call expression db model column meta db conf ui entity entity meta servlet ui sql db auth ldap connector db io readable table db logic db db api db meta view ui sql sql servlets db lang expr node db io record provider db io indexes db entity entity handler db meta meta writer db io meta serializer db io table writer db model aggr tables ui session handler db model data types db meta meta reader db session session db model seekable table meta db index leaf types db lang expr table definition db entity entity meta db lang sql db index byte trie ui param servlet db model ident db logic predicate helper db lang transaction db io serializer ui entity entity load servlet db model compiled object db transaction resources db lang expr db io tree map input stream db index byte multi trie db lang expr statements$ global statement ui admin db model join tables db lang sql csv statements ui admin meta repo connector db entity entity fields db tools backup manager db index id index db io seekable output stream db model table meta db model basic column db lang sql parser db lang expr statements$ statement db io table reader$ seekable table reader db lang expr literals db model keys db index multi leaf tries db conf config db model table multi index db io mapped data file db io table reader db model rule db meta grants db logging meta journal db auth authenticator db util util db io indexes$ index reader db meta materialized table db auth auth token db model table context db io memory buffered seekable file stream com db io indexes$ index writer db transaction global transaction db model table ref db lock lock manager db lang sql tokens db transaction transaction db transaction transaction handler ui admin session servlets db model table unique index db model builtin functions db lang sql select statement db session admin session db model aggregators ui admin users servlet db lang expr statements db transaction data transaction db logging transaction journal db lang sql wait statement db model table meta$ iterable table meta ui admin admin servlet db meta meta repo db lang sql update statement db model string functions db lang sql lexer db meta db object db transaction alter transaction ui admin settings servlet db lang sql insert into statement db doc function documentation db model stat column stats db model db lang expr case expression ui admin index servlet db doc db lang sql delete statement db tools ui admin monitoring servlet db lang sql drop statement db entity db model stat db model math functions db meta table stat db session i parser db lang db model list aggregators db index index stat db lang sql alter statement refs db logging db doc doc printer db io seekable input stream db transaction db lang expr binary expression db model stat aggregators db conf config type db lang sql create statement db io db model date functions db model stat table stats db lang transaction result db io rule dependency reader db meta ui web server db model references db lang expr expression db lock db lang sql grant statement db session i lexer db auth db meta table provider db lang sql alter statement constraints db meta dependencies'],
#  'cutiko|GeoFirebase': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cl cutiko cl geopods geopods main activity geopods example instrumented test geopods map fragment geopods maps activity'],
#  'indrekru|spring-boot-2-oauth2-resource-server': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'com config authorization server configuration repository user repository service user details service impl com ruubel model model user config web security configuration repository api api user controller api config resource server configuration service role service repository role repository application config model role config app config config simple cors filter service user service service']}

# %%
with open("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/java_stopwords", 'rt') as inf:
    java_stopwords = {x.strip() for x in inf.readlines()}

# %%
java_stopwords.update(['get', 'set', 'org', 'com', 'exception', 'override', 'java', 'string',
                       'list', 'util', 'value', 'length', 'println'])

# %%
import yake
kw_extractor = yake.KeywordExtractor(n=1, stopwords=java_stopwords, top=50)
extracted_kw = {}

# %%
for project in content:
   extracted_kw[project] = kw_extractor.extract_keywords(" ".join(content[project]).lower().strip())

# %%
from collections import Counter

counter = Counter()
for p in extracted_kw:
    terms = [x[0] for x in extracted_kw[p]]
    counter.update(terms)

# %%
counter.most_common()
# Out:
# [('data', 55),
#  ('type', 48),
#  ('model', 38),
#  ('factory', 37),
#  ('database', 36),
#  ('impl', 35),
#  ('table', 34),
#  ('query', 34),
#  ('handler', 30),
#  ('sql', 29),
#  ('config', 29),
#  ('connection', 28),
#  ('service', 27),
#  ('column', 25),
#  ('result', 24),
#  ('client', 23),
#  ('manager', 23),
#  ('server', 21),
#  ('main', 21),
#  ('test', 20),
#  ('entity', 19),
#  ('file', 18),
#  ('filter', 18),
#  ('activity', 18),
#  ('builder', 18),
#  ('api', 17),
#  ('common', 17),
#  ('provider', 17),
#  ('request', 16),
#  ('transaction', 16),
#  ('application', 16),
#  ('index', 16),
#  ('configuration', 16),
#  ('processor', 15),
#  ('source', 15),
#  ('node', 15),
#  ('info', 15),
#  ('statement', 15),
#  ('user', 15),
#  ('view', 15),
#  ('core', 14),
#  ('function', 14),
#  ('reader', 14),
#  ('search', 14),
#  ('metadata', 14),
#  ('field', 14),
#  ('mapper', 14),
#  ('object', 14),
#  ('response', 14),
#  ('schema', 14),
#  ('writer', 13),
#  ('cache', 13),
#  ('auth', 13),
#  ('dao', 13),
#  ('listener', 13),
#  ('event', 13),
#  ('base', 13),
#  ('stream', 13),
#  ('security', 12),
#  ('parser', 12),
#  ('example', 12),
#  ('jdbc', 12),
#  ('types', 12),
#  ('controller', 12),
#  ('key', 12),
#  ('app', 12),
#  ('storage', 11),
#  ('map', 11),
#  ('message', 11),
#  ('update', 11),
#  ('internal', 11),
#  ('meta', 11),
#  ('simple', 11),
#  ('collection', 10),
#  ('functions', 10),
#  ('output', 10),
#  ('time', 10),
#  ('store', 10),
#  ('operation', 10),
#  ('adapter', 10),
#  ('session', 10),
#  ('properties', 10),
#  ('log', 10),
#  ('helper', 10),
#  ('repository', 10),
#  ('array', 10),
#  ('constants', 9),
#  ('input', 9),
#  ('property', 9),
#  ('command', 9),
#  ('export', 9),
#  ('proxy', 9),
#  ('row', 9),
#  ('date', 9),
#  ('converter', 8),
#  ('version', 8),
#  ('tree', 8),
#  ('validation', 8),
#  ('cursor', 8),
#  ('ext', 8),
#  ('oracle', 8),
#  ('web', 8),
#  ('generator', 8),
#  ('expression', 8),
#  ('error', 8),
#  ('name', 8),
#  ('annotations', 8),
#  ('validator', 8),
#  ('json', 8),
#  ('resource', 8),
#  ('cluster', 7),
#  ('iterator', 7),
#  ('tuple', 7),
#  ('models', 7),
#  ('batch', 7),
#  ('loader', 7),
#  ('module', 7),
#  ('page', 7),
#  ('metrics', 7),
#  ('dialect', 7),
#  ('rest', 7),
#  ('not', 7),
#  ('bean', 7),
#  ('tables', 7),
#  ('definition', 7),
#  ('context', 7),
#  ('mongo', 7),
#  ('memory', 7),
#  ('access', 6),
#  ('record', 6),
#  ('http', 6),
#  ('state', 6),
#  ('read', 6),
#  ('write', 6),
#  ('range', 6),
#  ('operator', 6),
#  ('delete', 6),
#  ('net', 6),
#  ('holder', 6),
#  ('instrumented', 6),
#  ('create', 6),
#  ('content', 6),
#  ('annotation', 6),
#  ('tools', 6),
#  ('editor', 6),
#  ('views', 6),
#  ('plan', 6),
#  ('template', 6),
#  ('driver', 6),
#  ('android', 6),
#  ('mapping', 6),
#  ('open', 6),
#  ('migration', 6),
#  ('logger', 6),
#  ('document', 6),
#  ('single', 6),
#  ('with', 6),
#  ('postgres', 6),
#  ('results', 6),
#  ('entry', 6),
#  ('extension', 6),
#  ('github', 6),
#  ('spring', 6),
#  ('status', 6),
#  ('wrapper', 5),
#  ('predicate', 5),
#  ('buffer', 5),
#  ('order', 5),
#  ('lang', 5),
#  ('cli', 5),
#  ('lock', 5),
#  ('task', 5),
#  ('auto', 5),
#  ('project', 5),
#  ('network', 5),
#  ('login', 5),
#  ('image', 5),
#  ('dialog', 5),
#  ('load', 5),
#  ('register', 5),
#  ('handle', 5),
#  ('sample', 5),
#  ('execution', 5),
#  ('rule', 5),
#  ('generic', 5),
#  ('binary', 5),
#  ('mysql', 5),
#  ('handlers', 5),
#  ('job', 5),
#  ('change', 5),
#  ('permission', 5),
#  ('decoder', 5),
#  ('snapshot', 5),
#  ('expr', 5),
#  ('lite', 5),
#  ('resolver', 5),
#  ('xml', 5),
#  ('add', 5),
#  ('domain', 5),
#  ('settings', 5),
#  ('code', 5),
#  ('executor', 5),
#  ('system', 5),
#  ('stats', 5),
#  ('protocol', 5),
#  ('strategy', 5),
#  ('attribute', 5),
#  ('out', 5),
#  ('cell', 5),
#  ('graph', 5),
#  ('async', 5),
#  ('options', 5),
#  ('plugin', 5),
#  ('serializer', 5),
#  ('custom', 5),
#  ('utilities', 5),
#  ('stored', 4),
#  ('point', 4),
#  ('router', 4),
#  ('aggregator', 4),
#  ('metric', 4),
#  ('select', 4),
#  ('importer', 4),
#  ('route', 4),
#  ('token', 4),
#  ('block', 4),
#  ('insert', 4),
#  ('aggregate', 4),
#  ('catalog', 4),
#  ('password', 4),
#  ('thread', 4),
#  ('extra', 4),
#  ('hibernate', 4),
#  ('analysis', 4),
#  ('queries', 4),
#  ('group', 4),
#  ('engine', 4),
#  ('category', 4),
#  ('mssql', 4),
#  ('runtime', 4),
#  ('bulk', 4),
#  ('fields', 4),
#  ('codec', 4),
#  ('path', 4),
#  ('checker', 4),
#  ('orm', 4),
#  ('relation', 4),
#  ('servlet', 4),
#  ('creator', 4),
#  ('library', 4),
#  ('dto', 4),
#  ('persistence', 4),
#  ('analyzer', 4),
#  ('demo', 4),
#  ('runner', 4),
#  ('null', 4),
#  ('fragment', 4),
#  ('updater', 4),
#  ('method', 4),
#  ('events', 4),
#  ('local', 4),
#  ('sequence', 4),
#  ('pool', 4),
#  ('integer', 4),
#  ('transformation', 4),
#  ('entities', 4),
#  ('callback', 4),
#  ('resources', 4),
#  ('preferences', 4),
#  ('components', 4),
#  ('feature', 4),
#  ('check', 4),
#  ('action', 4),
#  ('instance', 4),
#  ('pattern', 4),
#  ('logging', 4),
#  ('prepared', 4),
#  ('text', 4),
#  ('math', 4),
#  ('item', 4),
#  ('encryption', 3),
#  ('predicates', 3),
#  ('basic', 3),
#  ('tag', 3),
#  ('monitoring', 3),
#  ('post', 3),
#  ('extensions', 3),
#  ('limit', 3),
#  ('aggregation', 3),
#  ('last', 3),
#  ('first', 3),
#  ('concurrent', 3),
#  ('symbol', 3),
#  ('primary', 3),
#  ('join', 3),
#  ('debug', 3),
#  ('firebase', 3),
#  ('profile', 3),
#  ('sign', 3),
#  ('constant', 3),
#  ('monitor', 3),
#  ('messages', 3),
#  ('semantic', 3),
#  ('primitive', 3),
#  ('performance', 3),
#  ('transfer', 3),
#  ('wizard', 3),
#  ('utility', 3),
#  ('transform', 3),
#  ('transport', 3),
#  ('alter', 3),
#  ('sync', 3),
#  ('denied', 3),
#  ('pagination', 3),
#  ('ignore', 3),
#  ('bad', 3),
#  ('sqlite', 3),
#  ('student', 3),
#  ('uri', 3),
#  ('reference', 3),
#  ('renderer', 3),
#  ('operations', 3),
#  ('migrator', 3),
#  ('planner', 3),
#  ('commands', 3),
#  ('foreign', 3),
#  ('postgresql', 3),
#  ('copy', 3),
#  ('book', 3),
#  ('invalid', 3),
#  ('dev', 3),
#  ('environment', 3),
#  ('remote', 3),
#  ('param', 3),
#  ('singleton', 3),
#  ('postgre', 3),
#  ('hsql', 3),
#  ('hash', 3),
#  ('city', 3),
#  ('constraint', 3),
#  ('operators', 3),
#  ('mail', 3),
#  ('member', 3),
#  ('btree', 3),
#  ('execute', 3),
#  ('compiler', 3),
#  ('serialization', 3),
#  ('calculator', 3),
#  ('than', 3),
#  ('non', 3),
#  ('modules', 3),
#  ('component', 3),
#  ('external', 3),
#  ('mongodb', 3),
#  ('tests', 3),
#  ('pojo', 3),
#  ('spi', 3),
#  ('connector', 3),
#  ('benchmark', 3),
#  ('bindings', 3),
#  ('val', 3),
#  ('iterable', 3),
#  ('threshold', 3),
#  ('jmx', 3),
#  ('lifecycle', 3),
#  ('general', 3),
#  ('account', 3),
#  ('binder', 3),
#  ('generated', 3),
#  ('gui', 3),
#  ('panel', 3),
#  ('geometry', 3),
#  ('spatial', 3),
#  ('global', 3),
#  ('gml', 3),
#  ('services', 3),
#  ('authentication', 3),
#  ('details', 3),
#  ('swagger', 3),
#  ('process', 3),
#  ('parameter', 3),
#  ('closeable', 3),
#  ('report', 3),
#  ('step', 3),
#  ('average', 3),
#  ('geo', 3),
#  ('email', 3),
#  ('format', 3),
#  ('admin', 3),
#  ('health', 3),
#  ('users', 3),
#  ('multi', 3),
#  ('random', 2),
#  ('description', 2),
#  ('compression', 2),
#  ('rpc', 2),
#  ('iterative', 2),
#  ('disk', 2),
#  ('series', 2),
#  ('timestamp', 2),
#  ('replication', 2),
#  ('histogram', 2),
#  ('max', 2),
#  ('sum', 2),
#  ('spark', 2),
#  ('upgrade', 2),
#  ('errors', 2),
#  ('simpledb', 2),
#  ('callbacks', 2),
#  ('reset', 2),
#  ('holders', 2),
#  ('pref', 2),
#  ('bearing', 2),
#  ('sqliteparser', 2),
#  ('transformations', 2),
#  ('channel', 2),
#  ('builders', 2),
#  ('rules', 2),
#  ('edit', 2),
#  ('struct', 2),
#  ('dialogs', 2),
#  ('actions', 2),
#  ('distance', 2),
#  ('match', 2),
#  ('platform', 2),
#  ('ddl', 2),
#  ('trigger', 2),
#  ('flow', 2),
#  ('codecs', 2),
#  ('deserializer', 2),
#  ('encoder', 2),
#  ('found', 2),
#  ('detail', 2),
#  ('course', 2),
#  ('wrap', 2),
#  ('criteria', 2),
#  ('worker', 2),
#  ('color', 2),
#  ('comment', 2),
#  ('location', 2),
#  ('part', 2),
#  ('backend', 2),
#  ('cleanup', 2),
#  ('init', 2),
#  ('books', 2),
#  ('failure', 2),
#  ('child', 2),
#  ('procedure', 2),
#  ('usage', 2),
#  ('car', 2),
#  ('maker', 2),
#  ('widget', 2),
#  ('realm', 2),
#  ('adapters', 2),
#  ('collector', 2),
#  ('house', 2),
#  ('click', 2),
#  ('packet', 2),
#  ('send', 2),
#  ('objects', 2),
#  ('end', 2),
#  ('compressed', 2),
#  ('and', 2),
#  ('sender', 2),
#  ('generation', 2),
#  ('supplier', 2),
#  ('datatype', 2),
#  ('remover', 2),
#  ('card', 2),
#  ('payload', 2),
#  ('infrastructure', 2),
#  ('socket', 2),
#  ('team', 2),
#  ('registration', 2),
#  ('collections', 2),
#  ('depth', 2),
#  ('jdk', 2),
#  ('parse', 2),
#  ('hbase', 2),
#  ('iterate', 2),
#  ('mapreduce', 2),
#  ('hadoop', 2),
#  ('compaction', 2),
#  ('segment', 2),
#  ('unregister', 2),
#  ('leader', 2),
#  ('descriptor', 2),
#  ('follower', 2),
#  ('connect', 2),
#  ('finder', 2),
#  ('behavior', 2),
#  ('validate', 2),
#  ('factories', 2),
#  ('word', 2),
#  ('html', 2),
#  ('rdf', 2),
#  ('selection', 2),
#  ('all', 2),
#  ('dynamic', 2),
#  ('scalar', 2),
#  ('cassandra', 2),
#  ('redis', 2),
#  ('protocols', 2),
#  ('management', 2),
#  ('statements', 2),
#  ('executors', 2),
#  ('beans', 2),
#  ('records', 2),
#  ('env', 2),
#  ('txn', 2),
#  ('stat', 2),
#  ('unsafe', 2),
#  ('doc', 2),
#  ('pooled', 2),
#  ('option', 2),
#  ('adaptor', 2),
#  ('decorator', 2),
#  ('timeout', 2),
#  ('reflection', 2),
#  ('unique', 2),
#  ('nodes', 2),
#  ('numeric', 2),
#  ('comparable', 2),
#  ('constraints', 2),
#  ('support', 2),
#  ('pack', 2),
#  ('getter', 2),
#  ('attributes', 2),
#  ('optional', 2),
#  ('caller', 2),
#  ('archive', 2),
#  ('citygml', 2),
#  ('kml', 2),
#  ('comparison', 2),
#  ('mode', 2),
#  ('texture', 2),
#  ('borrower', 2),
#  ('loan', 2),
#  ('author', 2),
#  ('initial', 2),
#  ('such', 2),
#  ('role', 2),
#  ('expired', 2),
#  ('authorization', 2),
#  ('dog', 2),
#  ('dependency', 2),
#  ('cat', 2),
#  ('visual', 2),
#  ('generate', 2),
#  ('partition', 2),
#  ('target', 2),
#  ('apps', 2),
#  ('run', 2),
#  ('ormlite', 2),
#  ('maria', 2),
#  ('embedded', 2),
#  ('hsqldb', 2),
#  ('processing', 2),
#  ('layer', 2),
#  ('composite', 2),
#  ('transformer', 2),
#  ('setting', 2),
#  ('consumer', 2),
#  ('dbtest', 2),
#  ('plugins', 2),
#  ('files', 2),
#  ('style', 2),
#  ('standard', 2),
#  ('arango', 2),
#  ('velocystream', 2),
#  ('edge', 2),
#  ('vertex', 2),
#  ('vst', 2),
#  ('communication', 2),
#  ('mybatis', 2),
#  ('converters', 2),
#  ('bridge', 2),
#  ('complex', 2),
#  ('legacy', 2),
#  ('bind', 2),
#  ('url', 2),
#  ('liquibase', 2),
#  ('translator', 2),
#  ('vfs', 2),
#  ('deploy', 2),
#  ('statistics', 2),
#  ('misc', 2),
#  ('raw', 2),
#  ('wrapped', 2),
#  ('big', 2),
#  ('mock', 2),
#  ('jmh', 2),
#  ('cartesian', 2),
#  ('form', 2),
#  ('bank', 2),
#  ('crypto', 2),
#  ('disabled', 2),
#  ('nullable', 2),
#  ('crypt', 2),
#  ('product', 2),
#  ('sources', 2),
#  ('contact', 2),
#  ('datasource', 2),
#  ('boot', 2),
#  ('autoconfigure', 2),
#  ('script', 2),
#  ('marker', 2),
#  ('layout', 2),
#  ('person', 2),
#  ('noodle', 1),
#  ('converted', 1),
#  ('call', 1),
#  ('gson', 1),
#  ('sidewinder', 1),
#  ('minuteman', 1),
#  ('gorilla', 1),
#  ('grafana', 1),
#  ('wal', 1),
#  ('ingesters', 1),
#  ('byzantine', 1),
#  ('mem', 1),
#  ('calcite', 1),
#  ('influx', 1),
#  ('measurement', 1),
#  ('consistency', 1),
#  ('graphite', 1),
#  ('archival', 1),
#  ('atomix', 1),
#  ('druidry', 1),
#  ('druid', 1),
#  ('spec', 1),
#  ('datasketches', 1),
#  ('extraction', 1),
#  ('sketch', 1),
#  ('averager', 1),
#  ('dimension', 1),
#  ('having', 1),
#  ('granularity', 1),
#  ('quantiles', 1),
#  ('top', 1),
#  ('hll', 1),
#  ('filtered', 1),
#  ('virtual', 1),
#  ('look', 1),
#  ('min', 1),
#  ('theta', 1),
#  ('mean', 1),
#  ('scan', 1),
#  ('estimate', 1),
#  ('regex', 1),
#  ('quantile', 1),
#  ('concourse', 1),
#  ('thrift', 1),
#  ('annotate', 1),
#  ('shell', 1),
#  ('ast', 1),
#  ('atomic', 1),
#  ('temp', 1),
#  ('line', 1),
#  ('revision', 1),
#  ('matcher', 1),
#  ('routers', 1),
#  ('recordid', 1),
#  ('stringaggregator', 1),
#  ('logicalfilternode', 1),
#  ('parsingexception', 1),
#  ('heapfileencoder', 1),
#  ('costcard', 1),
#  ('abstractdbfileiterator', 1),
#  ('logicaljoinnode', 1),
#  ('transactionabortedexception', 1),
#  ('logfile', 1),
#  ('dbfileiterator', 1),
#  ('commitrecord', 1),
#  ('tupleiterator', 1),
#  ('joinpredicate', 1),
#  ('dbexception', 1),
#  ('beginrecord', 1),
#  ('abortrecord', 1),
#  ('intfield', 1),
#  ('logrecord', 1),
#  ('checkpointrecord', 1),
#  ('integeraggregator', 1),
#  ('plancache', 1),
#  ('tuplearrayiterator', 1),
#  ('stringhistogram', 1),
#  ('bufferpool', 1),
#  ('dbfile', 1),
#  ('inthistogram', 1),
#  ('tuplecomparator', 1),
#  ('logicalplan', 1),
#  ('lockmanager', 1),
#  ('updaterecord', 1),
#  ('transactionid', 1),
#  ('joinoptimizer', 1),
#  ('snack', 1),
#  ('bar', 1),
#  ('screen', 1),
#  ('receiver', 1),
#  ('signup', 1),
#  ('redfox', 1),
#  ('cal', 1),
#  ('chatroom', 1),
#  ('pwd', 1),
#  ('btn', 1),
#  ('sent', 1),
#  ('received', 1),
#  ('detect', 1),
#  ('reactive', 1),
#  ('sqlitehelper', 1),
#  ('vansuita', 1),
#  ('ome', 1),
#  ('pojos', 1),
#  ('hierarchy', 1),
#  ('drools', 1),
#  ('browsing', 1),
#  ('omero', 1),
#  ('chain', 1),
#  ('pixels', 1),
#  ('container', 1),
#  ('classification', 1),
#  ('dataset', 1),
#  ('formal', 1),
#  ('build', 1),
#  ('dbeaver', 1),
#  ('editors', 1),
#  ('erd', 1),
#  ('navigator', 1),
#  ('controls', 1),
#  ('wmi', 1),
#  ('registry', 1),
#  ('exec', 1),
#  ('dict', 1),
#  ('dbs', 1),
#  ('simplifiers', 1),
#  ('vendor', 1),
#  ('tokenizers', 1),
#  ('gap', 1),
#  ('soundex', 1),
#  ('coefficient', 1),
#  ('levenshtein', 1),
#  ('multiset', 1),
#  ('distances', 1),
#  ('tokenizer', 1),
#  ('longest', 1),
#  ('smith', 1),
#  ('jaro', 1),
#  ('metaphone', 1),
#  ('overlap', 1),
#  ('waterman', 1),
#  ('generalized', 1),
#  ('jaccard', 1),
#  ('phonetic', 1),
#  ('multimap', 1),
#  ('needleman', 1),
#  ('wunch', 1),
#  ('accuracy', 1),
#  ('rating', 1),
#  ('approach', 1),
#  ('relationship', 1),
#  ('doppelganger', 1),
#  ('daitch', 1),
#  ('mokotoff', 1),
#  ('lcs', 1),
#  ('subsequence', 1),
#  ('refined', 1),
#  ('multiplication', 1),
#  ('tpc', 1),
#  ('nullsexpected', 1),
#  ('nysiis', 1),
#  ('symmetric', 1),
#  ('vaadin', 1),
#  ('sqlexplorer', 1),
#  ('firebird', 1),
#  ('streaming', 1),
#  ('fauna', 1),
#  ('body', 1),
#  ('constructors', 1),
#  ('responses', 1),
#  ('faunadb', 1),
#  ('language', 1),
#  ('unavailable', 1),
#  ('contention', 1),
#  ('unauthorized', 1),
#  ('unknown', 1),
#  ('aorm', 1),
#  ('grade', 1),
#  ('observer', 1),
#  ('fast', 1),
#  ('print', 1),
#  ('restrictions', 1),
#  ('printer', 1),
#  ('intercepter', 1),
#  ('ieclipse', 1),
#  ('program', 1),
#  ('closable', 1),
#  ('orientdb', 1),
#  ('orient', 1),
#  ('prototype', 1),
#  ('rendering', 1),
#  ('segrada', 1),
#  ('thymeleaf', 1),
#  ('markup', 1),
#  ('saved', 1),
#  ('querybuilder', 1),
#  ('savedquery', 1),
#  ('markdown', 1),
#  ('period', 1),
#  ('pictogram', 1),
#  ('binarydata', 1),
#  ('lucene', 1),
#  ('colored', 1),
#  ('drop', 1),
#  ('backends', 1),
#  ('definitions', 1),
#  ('versioning', 1),
#  ('rewriter', 1),
#  ('changelog', 1),
#  ('rename', 1),
#  ('pretty', 1),
#  ('adaptors', 1),
#  ('expert', 1),
#  ('active', 1),
#  ('recommendation', 1),
#  ('profiles', 1),
#  ('xpinjection', 1),
#  ('started', 1),
#  ('without', 1),
#  ('initializer', 1),
#  ('configurer', 1),
#  ('port', 1),
#  ('actuator', 1),
#  ('missed', 1),
#  ('firestore', 1),
#  ('durdinapps', 1),
#  ('cast', 1),
#  ('completable', 1),
#  ('offline', 1),
#  ('amforeas', 1),
#  ('xstream', 1),
#  ('acl', 1),
#  ('params', 1),
#  ('success', 1),
#  ('head', 1),
#  ('jetty', 1),
#  ('performancelogger', 1),
#  ('startup', 1),
#  ('restcontroller', 1),
#  ('orma', 1),
#  ('gfx', 1),
#  ('association', 1),
#  ('tool', 1),
#  ('condition', 1),
#  ('changed', 1),
#  ('deleter', 1),
#  ('selector', 1),
#  ('encrypted', 1),
#  ('publisher', 1),
#  ('encoding', 1),
#  ('achord', 1),
#  ('limits', 1),
#  ('revisions', 1),
#  ('hello', 1),
#  ('decompressing', 1),
#  ('empty', 1),
#  ('compressing', 1),
#  ('mutation', 1),
#  ('objective', 1),
#  ('testgeneration', 1),
#  ('manualevaluation', 1),
#  ('sqlrepresentation', 1),
#  ('coveragecriterion', 1),
#  ('pipeline', 1),
#  ('classified', 1),
#  ('technique', 1),
#  ('normal', 1),
#  ('dbms', 1),
#  ('parsedcasestudy', 1),
#  ('hyper', 1),
#  ('equivalence', 1),
#  ('schemata', 1),
#  ('mutant', 1),
#  ('alters', 1),
#  ('reduction', 1),
#  ('removers', 1),
#  ('suite', 1),
#  ('faultlocalization', 1),
#  ('redundancy', 1),
#  ('board', 1),
#  ('attachment', 1),
#  ('apis', 1),
#  ('cardlist', 1),
#  ('positions', 1),
#  ('authenticate', 1),
#  ('added', 1),
#  ('title', 1),
#  ('bloat', 1),
#  ('foundation', 1),
#  ('reflect', 1),
#  ('instrumentation', 1),
#  ('activation', 1),
#  ('objectmanager', 1),
#  ('nativequery', 1),
#  ('marshall', 1),
#  ('slot', 1),
#  ('freespace', 1),
#  ('phoenix', 1),
#  ('pherf', 1),
#  ('compile', 1),
#  ('covered', 1),
#  ('visitor', 1),
#  ('coprocessor', 1),
#  ('trace', 1),
#  ('parallel', 1),
#  ('unsigned', 1),
#  ('copycat', 1),
#  ('machine', 1),
#  ('offset', 1),
#  ('keep', 1),
#  ('commit', 1),
#  ('appender', 1),
#  ('alive', 1),
#  ('strategies', 1),
#  ('minor', 1),
#  ('major', 1),
#  ('leave', 1),
#  ('mithra', 1),
#  ('extractor', 1),
#  ('reladomo', 1),
#  ('notification', 1),
#  ('dated', 1),
#  ('transactional', 1),
#  ('offheap', 1),
#  ('cacheloader', 1),
#  ('off', 1),
#  ('heap', 1),
#  ('metamodel', 1),
#  ('detached', 1),
#  ('tempobject', 1),
#  ('computedattribute', 1),
#  ('siard', 1),
#  ('structure', 1),
#  ('xmlns', 1),
#  ('diark', 1),
#  ('lobs', 1),
#  ('tableindex', 1),
#  ('siarddk', 1),
#  ('sybase', 1),
#  ('ftserver', 1),
#  ('fts', 1),
#  ('readonlyindexserver', 1),
#  ('indexserver', 1),
#  ('delayservice', 1),
#  ('indexpage', 1),
#  ('readonlylist', 1),
#  ('indexapi', 1),
#  ('applistener', 1),
#  ('easyor', 1),
#  ('pagetext', 1),
#  ('pagesearchterm', 1),
#  ('karma', 1),
#  ('alignment', 1),
#  ('modeling', 1),
#  ('worksheet', 1),
#  ('rep', 1),
#  ('publish', 1),
#  ('steiner', 1),
#  ('rml', 1),
#  ('learner', 1),
#  ('link', 1),
#  ('jsonldjava', 1),
#  ('history', 1),
#  ('importdata', 1),
#  ('python', 1),
#  ('topk', 1),
#  ('semanticlabeling', 1),
#  ('research', 1),
#  ('imp', 1),
#  ('planning', 1),
#  ('triple', 1),
#  ('dsl', 1),
#  ('semantictypes', 1),
#  ('fetch', 1),
#  ('term', 1),
#  ('csv', 1),
#  ('any', 1),
#  ('objectstore', 1),
#  ('objectserver', 1),
#  ('obfuscator', 1),
#  ('ordered', 1),
#  ('jni', 1),
#  ('managed', 1),
#  ('boxed', 1),
#  ('required', 1),
#  ('presto', 1),
#  ('hive', 1),
#  ('raptor', 1),
#  ('orc', 1),
#  ('parquet', 1),
#  ('bytecode', 1),
#  ...]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import spacy

nlp = spacy.load("en_core_web_trf")
label_emb = list(nlp.pipe([LABEL]))[0]._.trf_data.tensors[-1]
keywords = [x[0] for x in counter.most_common()]
print(len(keywords))
similarities = []
for i, doc in tqdm(enumerate(nlp.pipe(keywords))):
    tokvecs = doc._.trf_data.tensors[-1]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities.append((keywords[i], sim))
# Out:
# 1823
# 1823it [00:07, 234.37it/s]

# %%
similarities.sort(key=lambda x: -x[1])

# %%
len(similarities)
# Out:
# 1823

# %%
similarities[:50]
# Out:
# [('database', 1.0),
#  ('network', 0.9952489),
#  ('array', 0.9949566),
#  ('memory', 0.9948596),
#  ('template', 0.99437517),
#  ('archive', 0.99385405),
#  ('activity', 0.9937778),
#  ('item', 0.99373776),
#  ('production', 0.993542),
#  ('reader', 0.99353135),
#  ('pattern', 0.9934614),
#  ('instance', 0.9934313),
#  ('browser', 0.99339503),
#  ('selection', 0.99336755),
#  ('storage', 0.9933018),
#  ('layer', 0.99299926),
#  ('shell', 0.9929731),
#  ('record', 0.99292314),
#  ('computer', 0.99290323),
#  ('performance', 0.9928975),
#  ('history', 0.9928813),
#  ('platform', 0.9928543),
#  ('console', 0.9928153),
#  ('definition', 0.9927453),
#  ('journal', 0.99247694),
#  ('wave', 0.9924642),
#  ('product', 0.9924138),
#  ('callback', 0.99235606),
#  ('depth', 0.99230707),
#  ('software', 0.9922871),
#  ('property', 0.9922705),
#  ('activation', 0.9922137),
#  ('collection', 0.9922061),
#  ('layout', 0.9921307),
#  ('container', 0.99212086),
#  ('project', 0.9919642),
#  ('expression', 0.9919148),
#  ('process', 0.9919102),
#  ('loader', 0.99187255),
#  ('analysis', 0.9918318),
#  ('letter', 0.99176157),
#  ('student', 0.99169314),
#  ('builder', 0.991669),
#  ('stream', 0.9915734),
#  ('operation', 0.9915704),
#  ('author', 0.99156874),
#  ('application', 0.99154127),
#  ('load', 0.9914488),
#  ('context', 0.99142814),
#  ('training', 0.9914264)]

# %%
from feature.embedding import FastTextEmbedding

ft = FastTextEmbedding(path='/home/sasce/PycharmProjects/CodeGraphClassification/data/models/wiki.en.bin', model='fastText')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
label_emb = [ft.get_embedding(LABEL)]
keywords = [x[0] for x in counter.most_common()]

similarities_ft = []
for i, key in tqdm(enumerate(keywords)):
    tokvecs = [ft.get_embedding(key)]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities_ft.append((keywords[i], sim))

similarities_ft.sort(key=lambda x: -x[1])
# Out:
# 1823it [00:00, 4475.38it/s]

# %%
similarities_ft[:50]
# Out:
# [('database', 1.0),
#  ('dbms', 0.57058567),
#  ('query', 0.55238044),
#  ('resource', 0.5301167),
#  ('hmdb', 0.52991575),
#  ('metadata', 0.5251692),
#  ('mysql', 0.51636124),
#  ('lmdb', 0.51181525),
#  ('bsql', 0.5078706),
#  ('sqlite', 0.5057728),
#  ('mssql', 0.50572383),
#  ('hsql', 0.5025117),
#  ('postgresql', 0.5009709),
#  ('sql', 0.49948573),
#  ('dataset', 0.496668),
#  ('hsqldb', 0.49662802),
#  ('odbc', 0.49397185),
#  ('datasource', 0.49052164),
#  ('catalog', 0.4900716),
#  ('dataservices', 0.48991224),
#  ('queries', 0.48664963),
#  ('repository', 0.48496497),
#  ('jdbc', 0.4808603),
#  ('hbase', 0.47848862),
#  ('server', 0.4743712),
#  ('backend', 0.47358575),
#  ('repositories', 0.47180155),
#  ('dbmetadata', 0.47095165),
#  ('annotation', 0.4706476),
#  ('annotate', 0.46840617),
#  ('directory', 0.46519646),
#  ('data', 0.46244183),
#  ('browser', 0.45689577),
#  ('webservice', 0.455578),
#  ('mongodb', 0.45305884),
#  ('sparql', 0.45140108),
#  ('sqliteparser', 0.450005),
#  ('indexserver', 0.44592124),
#  ('orientdb', 0.4444078),
#  ('logfile', 0.43874678),
#  ('web', 0.43823174),
#  ('postgres', 0.4358923),
#  ('profile', 0.43455896),
#  ('transactional', 0.43374714),
#  ('validation', 0.43369672),
#  ('mapreduce', 0.4317056),
#  ('resources', 0.42968196),
#  ('querybuilder', 0.42948574),
#  ('bquery', 0.4288654),
#  ('workflows', 0.42864883)]
