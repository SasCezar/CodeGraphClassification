# %%
from hydra import initialize, compose

with initialize(version_base=None, config_path="../../src/conf/"):
    cfg = compose(config_name='main.yaml', overrides=["local=default"])
    print(cfg)
# Out:
# {'num_workers': 1, 'num_splits': 10, 'split': 1, 'seed': 42, 'project_path': '${base_path}/data/raw/dataset_with_graphs.csv', 'extraction': {'_target_': 'src.feature.extract.NameFeatureExtraction', 'graph_path': '${arcan_graphs}', 'out_path': '${out_path}/processed/', 'stopwords': 'None'}, 'embedding': {'_target_': 'src.feature.embedding.FastTextEmbedding', 'model': 'fastText', 'path': '${base_path}/data/models/wiki.en.bin'}, 'base_path': '/home/sasce/PycharmProjects/CodeGraphClassification', 'out_path': '${base_path}/data/', 'arcan_out': '${base_path}/data/interim/', 'arcan_graphs': '${arcan_out}/arcanOutput', 'raw_data': '${out_path}/raw/', 'dataset': '${base_path}/data/raw/classification_dataset_lang.csv', 'language': 'JAVA', 'repositories_path': '${base_path}/data/raw/repositories/', 'arcan_script': '${base_path}/scripts/bash/run-arcan.sh', 'arcan_path': '${base_path}/tools/arcan', 'repository_path': '${base_path}/data/raw/repositories', 'logs_path': '${base_path}/logs/', 'model': {'_target_': 'src.model.gcn.GraphConvNetwork', 'hidden_channels': 256}, 'datamodule': {'_target_': 'src.data.datamodule.GitRankingDataModule', 'graph_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/interim/arcanOutput', 'feature_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/embedding/name/fastText', 'out_dir': '/home/sasce/PycharmProjects/CodeGraphClassification/data/processed/torch', 'embedding_size': 300, 'batch_size': 32, 'num_splits': '${num_splits}', 'split': '${split}', 'has_val': True, 'has_test': True}}

# %%
from data.graph import ArcanGraphLoader
from os.path import join
from feature.content import IdentifiersContentExtraction
from utils import git_clone, get_versions, git_checkout, filter_by_label
from loguru import logger
import pandas as pd

projects = pd.read_csv("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/dataset_with_graphs.csv")
content_extractor = IdentifiersContentExtraction(graph_path=cfg.arcan_graphs,
                                                 repo_path=cfg.repository_path)

# %%
projects.head()
# Out:
#                             name                             label   level  \
# 0  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 1  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 2  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 3  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
# 4  Norconex|collector-filesystem  ['search engine', 'web crawler']  [3, 5]
#
#    version                                       sha  nodes  edges
# 0      133  292a42769f7f6f1beaf4b178c3f7170fddfee282     68    212
# 1       63  c01cf7bf4093aa21fafc1fba93ba50ca0343c619     36    110
# 2       72  785b7928896b302fd84d81f9437ec47af5d7b330     36    110
# 3       21  b08c040bfe57cb1f3220ca487d33b0240a6564fa     39    155
# 4      115  30cb73f240f83e7a3a363d4a5a5d27c04e313907     68    212

# %%
projects = filter_by_label(projects.copy(deep=True), ['machine learning'])
# Out:
# 2022-10-26 09:05:18.330 | INFO     | utils:filter_by_label:105 - Labels ['machine learning']
# /home/sasce/PycharmProjects/CodeGraphClassification/src/utils.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].apply(tuple)

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2012 entries, 907 to 59634
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2012 non-null   object
#  1   label    2012 non-null   object
#  2   level    2012 non-null   object
#  3   version  2012 non-null   int64
#  4   sha      2012 non-null   object
#  5   nodes    2012 non-null   int64
#  6   edges    2012 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 125.8+ KB

# %%
projects = set(projects['name'].tolist())
len(projects)
# Out:
# 100

# %%
from tqdm import tqdm
import shutil

graph_loader = ArcanGraphLoader()
logger.info(f"Extracting features for {len(projects)} projects")
identifiers = []
keywords = {}
for project_name in tqdm(projects):
    project = project_name.replace('|', '/')

    project_url = f'https://github.com/{project}'
    git_clone(project_url, project_name, cfg.repositories_path)


    versions = [get_versions(project_name, cfg.arcan_graphs)[-1]]

    logger.info(f"Found {len(versions)} versions for project {project}")
    for num, sha in tqdm(versions):
        try:
            if content_extractor.clone:
                git_checkout(join(cfg.repositories_path, project_name), sha)
            project_graph = graph_loader.load(join(cfg.arcan_graphs, project_name, f'dependency-graph-{num}_{sha}.graphml'))
            res = content_extractor.extract(project_name, sha, num)
            identifiers.append(res)
        except:
            continue

    content = [" ".join(x) for x in identifiers]
    keywords[project_name] = content

    #repo_path = join(cfg.repository_path, project_name)
    #shutil.rmtree(repo_path, ignore_errors=True)
# Out:
# 2022-10-26 09:05:18.878 | INFO     | __main__:<module>:5 - Extracting features for 100 projects
#   0%|          | 0/100 [00:00<?, ?it/s]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/vishnugh|evo-NEAT'...
# 2022-10-26 09:05:19.504 | INFO     | __main__:<module>:17 - Found 1 versions for project vishnugh/evo-NEAT
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '8cb412eb1faaefa713c09a94ecd585c64f23b38d'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 8cb412e docs: update README
# 100%|██████████| 1/1 [00:00<00:00, 25.41it/s]
#   1%|          | 1/100 [00:00<01:10,  1.41it/s]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/lejon|PartiallyCollapsedLDA'...
# 2022-10-26 09:05:28.449 | INFO     | __main__:<module>:17 - Found 1 versions for project lejon/PartiallyCollapsedLDA
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'a75d5ff64f228d11056da0b7595bf3fcfcdbe983'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at a75d5ff Refactoring and bugfix
#
# 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
#   2%|▏         | 2/100 [00:11<10:26,  6.39s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/openturing|turing'...
# 2022-10-26 09:05:46.328 | INFO     | __main__:<module>:17 - Found 1 versions for project openturing/turing
#
#   0%|          | 0/1 [00:00<?, ?it/s]fatal: reference is not a tree: b3cca179e53c582f860542ff68c62d46f6e141ad
# 100%|██████████| 1/1 [00:00<00:00, 21.48it/s]
#   3%|▎         | 3/100 [00:28<18:46, 11.61s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Cerenaut|agi'...
# 2022-10-26 09:05:54.081 | INFO     | __main__:<module>:17 - Found 1 versions for project Cerenaut/agi
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '92498488de2164595b678f43b03f4f0079180fda'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 9249848 Changed pooling logic from ranked relative error, to -log likelihood based on error. ad hoc testing shows 1% increase in accuracy at 1 epoch.
# 100%|██████████| 1/1 [00:00<00:00, 13.16it/s]
#   4%|▍         | 4/100 [00:37<16:21, 10.23s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/starling-lab|BoostSRL'...
# 2022-10-26 09:06:01.072 | INFO     | __main__:<module>:17 - Found 1 versions for project starling-lab/BoostSRL
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '4cf16a8c559958d68fe57caacb1964cb794e4cbf'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 4cf16a8 updating url.
#
# 100%|██████████| 1/1 [00:00<00:00,  8.63it/s]
#   5%|▌         | 5/100 [00:49<17:15, 10.90s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/ShifuML|shifu'...
# 2022-10-26 09:06:10.847 | INFO     | __main__:<module>:17 - Found 1 versions for project ShifuML/shifu
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'f0f64ad0b11f1be3ff66f82d5bc4b3d7ed261b9f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at f0f64ad0 Parquet input format support for raw file data (correlation job with parquet format not supported now)
#
# 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
#   6%|▌         | 6/100 [00:56<14:57,  9.55s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/claczny|VizBin'...
# 2022-10-26 09:06:44.712 | INFO     | __main__:<module>:17 - Found 1 versions for project claczny/VizBin
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '9bbf771d05713bb5e2cbb42d67c7503ca91b1066'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 9bbf771 Bump commons-io from 2.4 to 2.7 in /src/interface/VizBin
#
# 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]
#   7%|▋         | 7/100 [01:26<25:17, 16.32s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/girishpai|NumTrans'...
# Updating files: 100% (578/578), done.
# 2022-10-26 09:06:56.902 | INFO     | __main__:<module>:17 - Found 1 versions for project girishpai/NumTrans
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '6e24816b8cea3f2b06fbc8890989dfb3172b451b'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6e24816 docs : Adding images for readme
#
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
#   8%|▊         | 8/100 [01:39<23:31, 15.34s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/raulh82vlc|Image-Detection-Samples'...
# 2022-10-26 09:06:59.353 | INFO     | __main__:<module>:17 - Found 1 versions for project raulh82vlc/Image-Detection-Samples
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '7992ef5aaed881f082d20f05b98bc9679855bd2a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 7992ef5 Package and app name to face detection sample
# 100%|██████████| 1/1 [00:00<00:00, 22.30it/s]
#   9%|▉         | 9/100 [01:41<16:54, 11.15s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/qupath|qupath'...
# 2022-10-26 09:07:13.614 | INFO     | __main__:<module>:17 - Found 1 versions for project qupath/qupath
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'a69c418a3647af70a8cb9dc830f30bde4d368511'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at a69c418a Add show javadocs command to script editor
#
# 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
#  10%|█         | 10/100 [02:01<20:44, 13.83s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/cTJakt|glaucus'...
# 2022-10-26 09:07:22.673 | INFO     | __main__:<module>:17 - Found 1 versions for project cTJakt/glaucus
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'e488b670d046e5814764ffb9e60d21ee388926af'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at e488b67 添加自动化机器学习测试结果
# 100%|██████████| 1/1 [00:00<00:00, 12.39it/s]
#  11%|█         | 11/100 [02:03<15:27, 10.42s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/viadee|camunda-kafka-polling-client'...
# 2022-10-26 09:07:24.022 | INFO     | __main__:<module>:17 - Found 1 versions for project viadee/camunda-kafka-polling-client
#
#   0%|          | 0/1 [00:00<?, ?it/s]fatal: reference is not a tree: d3242b5cf67800955305847552350701bb875a9d
# 100%|██████████| 1/1 [00:00<00:00, 72.47it/s]
#  12%|█▏        | 12/100 [02:05<11:12,  7.65s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/monkeylearn|monkeylearn-java'...
# 2022-10-26 09:07:24.836 | INFO     | __main__:<module>:17 - Found 1 versions for project monkeylearn/monkeylearn-java
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'f6cfa5fa5ed3d44df1fca94273251440b365d965'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at f6cfa5f added support for extra params in extractors.
# 100%|██████████| 1/1 [00:00<00:00, 39.42it/s]
#  13%|█▎        | 13/100 [02:06<08:03,  5.56s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Remper|sociallink'...
# 2022-10-26 09:07:26.181 | INFO     | __main__:<module>:17 - Found 1 versions for project Remper/sociallink
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '32c348d4dc6d6e3e08bfad707b3f1171b219e864'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 32c348d Added two new options to the post processing step
# 100%|██████████| 1/1 [00:00<00:00, 16.07it/s]
#  14%|█▍        | 14/100 [02:08<06:28,  4.52s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/indeedeng|vowpal-wabbit-java'...
# 2022-10-26 09:07:38.142 | INFO     | __main__:<module>:17 - Found 1 versions for project indeedeng/vowpal-wabbit-java
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '366f124f4536d9e30e5118572a6a0805bc34efda'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 366f124 Updates repo to current Indeed repo standards.
#
# 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
#  15%|█▌        | 15/100 [02:19<09:20,  6.59s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/alipay|jpmml-sparkml-lightgbm'...
# 2022-10-26 09:07:39.550 | INFO     | __main__:<module>:17 - Found 1 versions for project alipay/jpmml-sparkml-lightgbm
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '1aa2ac26b10d42c1764144310a2a7942b2267fe2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 1aa2ac2 Main (#13)
# 100%|██████████| 1/1 [00:00<00:00, 27.23it/s]
#  16%|█▌        | 16/100 [02:20<06:56,  4.96s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/pushkar|ABAGAIL'...
# 2022-10-26 09:07:40.808 | INFO     | __main__:<module>:17 - Found 1 versions for project pushkar/ABAGAIL
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '8afed80dc681aa269d2fd28b4102832c387db70d'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 8afed80 add new kcolor test to jython
# 100%|██████████| 1/1 [00:00<00:00, 20.41it/s]
#  17%|█▋        | 17/100 [02:22<05:35,  4.04s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/lsds|Crossbow'...
# 2022-10-26 09:07:42.959 | INFO     | __main__:<module>:17 - Found 1 versions for project lsds/Crossbow
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '4e951a1df73caed70707cba7ddc204fb5cb47f55'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 4e951a1 Bump log4j-api from 2.5 to 2.16.0
# 100%|██████████| 1/1 [00:00<00:00, 20.31it/s]
#  18%|█▊        | 18/100 [02:24<04:47,  3.50s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/tony-framework|TonY'...
# 2022-10-26 09:07:44.838 | INFO     | __main__:<module>:17 - Found 1 versions for project tony-framework/TonY
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'c0cd6d3d3502d8f7ce723c2ed7e1c3de8519fcdf'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at c0cd6d3 Check registrationTimeoutMs in advance to prevent decrease in efficiency (#674)
# 100%|██████████| 1/1 [00:00<00:00, 27.44it/s]
#  19%|█▉        | 19/100 [02:26<03:57,  2.93s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/sbl-sdsc|mmtf-spark'...
# 2022-10-26 09:07:46.453 | INFO     | __main__:<module>:17 - Found 1 versions for project sbl-sdsc/mmtf-spark
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'fc513624bdea89732ab5261d4ed7bbaa500edf89'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at fc51362 updated Spark version
# 100%|██████████| 1/1 [00:00<00:00, 31.72it/s]
#  20%|██        | 20/100 [02:28<03:23,  2.55s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/sanity|quickml'...
# 2022-10-26 09:07:48.273 | INFO     | __main__:<module>:17 - Found 1 versions for project sanity/quickml
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'f84ab5ae45c885e149aa8720717c15645565a97c'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at f84ab5ae Bump gson from 2.3 to 2.8.9
# 100%|██████████| 1/1 [00:00<00:00, 18.56it/s]
#  21%|██        | 21/100 [02:30<03:11,  2.42s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/vinhkhuc|jcrfsuite'...
# 2022-10-26 09:07:50.841 | INFO     | __main__:<module>:17 - Found 1 versions for project vinhkhuc/jcrfsuite
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '3da2f665b300373818a70667937a2b07747106eb'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 3da2f66 Added custom build for Linux.
#
# 100%|██████████| 1/1 [00:00<00:00,  7.27it/s]
#  22%|██▏       | 22/100 [02:32<02:56,  2.26s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/lizhangqu|TensorflowLite'...
# 2022-10-26 09:07:52.294 | INFO     | __main__:<module>:17 - Found 1 versions for project lizhangqu/TensorflowLite
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'e8cfaf107f4261946362129d67ea1a5b79930a9e'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at e8cfaf1 init project
# 100%|██████████| 1/1 [00:00<00:00, 18.01it/s]
#  23%|██▎       | 23/100 [02:33<02:32,  1.98s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/universal-automata|liblevenshtein-java'...
# 2022-10-26 09:07:53.651 | INFO     | __main__:<module>:17 - Found 1 versions for project universal-automata/liblevenshtein-java
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'ba6b6b88ebd1f3e50f04ad7a64ec56b7081d63f9'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ba6b6b8 Adds integration test suite; adds regression test suite; checks for expected, dependency cycles with JDepend
# 100%|██████████| 1/1 [00:00<00:00, 35.87it/s]
#  24%|██▍       | 24/100 [02:34<02:18,  1.82s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/EdwardRaff|jLZJD'...
# 2022-10-26 09:07:54.455 | INFO     | __main__:<module>:17 - Found 1 versions for project EdwardRaff/jLZJD
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'b9c7ba482b742e11e71323d39e795a64c3c37c47'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at b9c7ba4 Removing un-needed dependency that started breaking build for no reason
# 100%|██████████| 1/1 [00:00<00:00, 33.47it/s]
#  25%|██▌       | 25/100 [02:35<01:52,  1.50s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/CogComp|lbjava'...
# 2022-10-26 09:07:59.653 | INFO     | __main__:<module>:17 - Found 1 versions for project CogComp/lbjava
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'b438e8cf596c1d0e6a3783e974f8a8a5c0b5f2c2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at b438e8c Bump plexus-utils from 3.0.8 to 3.0.16 in /lbjava-mvn-plugin
#
# 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
#  26%|██▌       | 26/100 [02:42<03:50,  3.11s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/USCDataScience|AgePredictor'...
# 2022-10-26 09:08:25.547 | INFO     | __main__:<module>:17 - Found 1 versions for project USCDataScience/AgePredictor
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '2387e239adefbbc113fd64ffedccd5c50f9848a6'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 2387e23 Bump opennlp-tools from 1.6.0 to 1.8.2 in /age-predictor-opennlp
#
# 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
#  27%|██▋       | 27/100 [03:07<11:40,  9.59s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/ptnplanet|Java-Naive-Bayes-Classifier'...
# 2022-10-26 09:08:26.795 | INFO     | __main__:<module>:17 - Found 1 versions for project ptnplanet/Java-Naive-Bayes-Classifier
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'fa5ac24a9e49ed963a40d4ab0a968a217ebdb13b'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at fa5ac24 Update README.md
# 100%|██████████| 1/1 [00:00<00:00, 71.09it/s]
#  28%|██▊       | 28/100 [03:07<08:18,  6.92s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/elki-project|elki'...
# 2022-10-26 09:08:48.174 | INFO     | __main__:<module>:17 - Found 1 versions for project elki-project/elki
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '0eb901846611f33f356f7d01a62caf1b43c4b423'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 0eb9018466 Add FastMSC, SISAP 2022. Not optimized for k=2 yet
#
# 100%|██████████| 1/1 [00:00<00:00,  2.00it/s]
#  29%|██▉       | 29/100 [03:38<16:24, 13.87s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/rabidgremlin|Mutters'...
# 2022-10-26 09:08:57.776 | INFO     | __main__:<module>:17 - Found 1 versions for project rabidgremlin/Mutters
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'ff223b817ef2b7bfd37c8da04047405d5caf3757'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ff223b8 Fix bad story state (#19)
# 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
#  30%|███       | 30/100 [03:39<11:40, 10.01s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/punit-naik|MLHadoop'...
# 2022-10-26 09:08:58.710 | INFO     | __main__:<module>:17 - Found 1 versions for project punit-naik/MLHadoop
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '42ae96dcec5b5964528e69e6906fd4ae5a849f90'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 42ae96d fixed typo
# 100%|██████████| 1/1 [00:00<00:00, 25.42it/s]
#  31%|███       | 31/100 [03:39<08:22,  7.28s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Waikato|weka-3.8'...
# Updating files: 100% (5494/5494), done.
# 2022-10-26 09:09:27.376 | INFO     | __main__:<module>:17 - Found 1 versions for project Waikato/weka-3.8
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '04804ccd6dff03534cbf3f2a71a35c73eef24fe8'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 04804cc linked new git repo
#
# 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
#  32%|███▏      | 32/100 [04:31<23:23, 20.64s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/padreati|rapaio'...
# 2022-10-26 09:10:03.990 | INFO     | __main__:<module>:17 - Found 1 versions for project padreati/rapaio
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '5f5ad7d2dffded2616ac406d751279ba15510114'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 5f5ad7d2 - implement float var
#
# 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
#  33%|███▎      | 33/100 [04:49<22:10, 19.86s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/kaiwaehner|tensorflow-serving-java-grpc-kafka-streams'...
# 2022-10-26 09:10:09.632 | INFO     | __main__:<module>:17 - Found 1 versions for project kaiwaehner/tensorflow-serving-java-grpc-kafka-streams
#
#   0%|          | 0/1 [00:00<?, ?it/s]fatal: reference is not a tree: 67f6c67a58adc6d86cd9f7c10149aec336f0f9b4
# 100%|██████████| 1/1 [00:00<00:00, 66.38it/s]
#  34%|███▍      | 34/100 [04:50<15:37, 14.21s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/xRahul|GroupingMessages'...
# 2022-10-26 09:10:11.933 | INFO     | __main__:<module>:17 - Found 1 versions for project xRahul/GroupingMessages
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '06da47f7cda7ebba21e932e1b392d24703c5e954'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 06da47f Update dependency com.android.tools.build:gradle to v7
# 100%|██████████| 1/1 [00:00<00:00, 13.21it/s]
#  35%|███▌      | 35/100 [04:53<11:36, 10.71s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/kaiwaehner|ksql-udf-deep-learning-mqtt-iot'...
# 2022-10-26 09:10:13.429 | INFO     | __main__:<module>:17 - Found 1 versions for project kaiwaehner/ksql-udf-deep-learning-mqtt-iot
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'a605d197733650634df891744bcf2543dc418999'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at a605d19 Upgraded syntax to ksqlDB
# 100%|██████████| 1/1 [00:00<00:00, 27.43it/s]
#  36%|███▌      | 36/100 [05:10<13:19, 12.50s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/indix|mlflow-gocd'...
# 2022-10-26 09:10:29.720 | INFO     | __main__:<module>:17 - Found 1 versions for project indix/mlflow-gocd
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'd85cce90ba703462534d8748fa89be35367d5090'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at d85cce9 Enable PR runs (#2)
# 100%|██████████| 1/1 [00:00<00:00, 49.57it/s]
#  37%|███▋      | 37/100 [05:10<09:28,  9.02s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/SAG-KeLP|kelp-input-generator'...
# 2022-10-26 09:10:30.686 | INFO     | __main__:<module>:17 - Found 1 versions for project SAG-KeLP/kelp-input-generator
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'a001a786d3367661c769336672664e037c7283cd'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at a001a78 update pom to support jenkins-maven lifecycle
# 100%|██████████| 1/1 [00:00<00:00, 28.37it/s]
#  38%|███▊      | 38/100 [05:11<06:49,  6.61s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/hanuor|onyx'...
# 2022-10-26 09:10:31.946 | INFO     | __main__:<module>:17 - Found 1 versions for project hanuor/onyx
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'd66b9fad824ad7ded6b8be17b1e88a636efb0b96'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at d66b9fa Updated gradle and added Rx
# 100%|██████████| 1/1 [00:00<00:00, 24.70it/s]
#  39%|███▉      | 39/100 [05:13<05:10,  5.09s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/rahul-raj|Deeplearning4J'...
# 2022-10-26 09:10:35.341 | INFO     | __main__:<module>:17 - Found 1 versions for project rahul-raj/Deeplearning4J
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'eea1cf062af827b9ee7a6a655e00e4ea78d73a51'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at eea1cf0 Update README.md
#
# 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
#  40%|████      | 40/100 [05:16<04:36,  4.61s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Angel-ML|serving'...
# 2022-10-26 09:10:36.978 | INFO     | __main__:<module>:17 - Found 1 versions for project Angel-ML/serving
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '4ecb79d4702bee88a0a4a0c0b40cb17074f1e891'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 4ecb79d Bump hadoop-common from 2.7.2 to 3.2.3
# 100%|██████████| 1/1 [00:00<00:00, 21.97it/s]
#  41%|████      | 41/100 [05:24<05:30,  5.60s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/o19s|RankyMcRankFace'...
# 2022-10-26 09:10:44.542 | INFO     | __main__:<module>:17 - Found 1 versions for project o19s/RankyMcRankFace
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'b0e473a30471fcebf7352795b1f3b36702a649d7'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at b0e473a Setup for publishing
# 100%|██████████| 1/1 [00:00<00:00, 23.55it/s]
#  42%|████▏     | 42/100 [05:26<04:09,  4.30s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/klevis|KMeansImageColorReduction'...
# 2022-10-26 09:10:46.025 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/KMeansImageColorReduction
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'a1aeec427b158e444699450a7de30c1810636e9e'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at a1aeec4 read me
# 100%|██████████| 1/1 [00:00<00:00, 31.21it/s]
#  43%|████▎     | 43/100 [05:27<03:09,  3.33s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/dividiti|crowdsource-video-experiments-on-android'...
# 2022-10-26 09:10:47.306 | INFO     | __main__:<module>:17 - Found 1 versions for project dividiti/crowdsource-video-experiments-on-android
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '6d592404b16108f347738425bee495b72d317b00'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6d59240 updated target SDK
# 100%|██████████| 1/1 [00:00<00:00, 28.09it/s]
#  44%|████▍     | 44/100 [05:28<02:36,  2.80s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/klevis|DigitRecognizer'...
# 2022-10-26 09:10:51.497 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/DigitRecognizer
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '19fdb5ed677c2be9eb0455c0e900c4348f40b602'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 19fdb5e read me
#
# 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
#  45%|████▌     | 45/100 [05:32<02:55,  3.19s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/intuit|foremast'...
# Updating files: 100% (26862/26862), done.
# 2022-10-26 09:11:02.613 | INFO     | __main__:<module>:17 - Found 1 versions for project intuit/foremast
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'c559ae55f689bd03a3211522e943b6f7dd12a981'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at c559ae55 Bump tzinfo from 1.2.5 to 1.2.10 in /docs
#
# 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
#  46%|████▌     | 46/100 [05:44<05:12,  5.79s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/klevis|frauddetection'...
# 2022-10-26 09:11:06.189 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/frauddetection
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '7c5e520c0656854c8183141776628dd9ab7ad356'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 7c5e520 read me
#
# 100%|██████████| 1/1 [00:00<00:00,  7.29it/s]
#  47%|████▋     | 47/100 [05:47<04:18,  4.88s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/klevis|CatAndDogRecognizer'...
# 2022-10-26 09:11:07.098 | INFO     | __main__:<module>:17 - Found 1 versions for project klevis/CatAndDogRecognizer
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '87f44cecf543a5902ecb18a15b1d9855ce7cd215'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 87f44ce init commit
# 100%|██████████| 1/1 [00:00<00:00, 42.89it/s]
#  48%|████▊     | 48/100 [05:48<03:09,  3.65s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/komiya-atsushi|xgboost-predictor-java'...
# 2022-10-26 09:11:15.339 | INFO     | __main__:<module>:17 - Found 1 versions for project komiya-atsushi/xgboost-predictor-java
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'caf3884742f4acda23a9205d0ba10d9054d4783f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at caf3884 Support reg:squarederror for objective
# 100%|██████████| 1/1 [00:00<00:00, 27.28it/s]
#  49%|████▉     | 49/100 [05:56<04:17,  5.04s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/lil-lab|amr'...
# 2022-10-26 09:11:17.049 | INFO     | __main__:<module>:17 - Found 1 versions for project lil-lab/amr
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '8aa413126e6001b7ec940fbd7869e54d46b2e8fe'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# ...
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '5053ac159c5cb33e925028c3af3d20fa76a83330'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 5053ac1 Migrated to Androidx
# 100%|██████████| 1/1 [00:00<00:00, 13.02it/s]
#  85%|████████▌ | 85/100 [10:38<01:10,  4.70s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/cookiengineer|lycheejs'...
# Updating files: 100% (7803/7803), done.
# 2022-10-26 09:16:21.194 | INFO     | __main__:<module>:17 - Found 1 versions for project cookiengineer/lycheejs
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'b3880202599c6a2e4a5fb597dbc21970837e1ff7'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at b3880202 :unicorn: Integration of lychee.js Runtimes
#
# 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
#  86%|████████▌ | 86/100 [11:12<03:08, 13.45s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/snuspl|cruise'...
# 2022-10-26 09:16:33.190 | INFO     | __main__:<module>:17 - Found 1 versions for project snuspl/cruise
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '7c250f030c0327ba0f44905c9c65068f9ff211a2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 7c250f03 Update checkstyle plugin version to avoid security vulnerability (#1281)
#
# 100%|██████████| 1/1 [00:00<00:00,  8.34it/s]
#  87%|████████▋ | 87/100 [11:16<02:17, 10.60s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/CalebFenton|apkfile'...
# 2022-10-26 09:16:35.921 | INFO     | __main__:<module>:17 - Found 1 versions for project CalebFenton/apkfile
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'fedb2ba55821ad9a29b63f337480237d59e75092'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at fedb2ba Progress commit before 2.x rewrite
# 100%|██████████| 1/1 [00:00<00:00, 24.23it/s]
#  88%|████████▊ | 88/100 [11:17<01:33,  7.76s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/nikolamilosevic86|owasp-seraphimdroid'...
# 2022-10-26 09:17:04.178 | INFO     | __main__:<module>:17 - Found 1 versions for project nikolamilosevic86/owasp-seraphimdroid
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '4d2f37e33d694a98a45da47ac866bd494d6cbc1d'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 4d2f37e Update README.md
#
# 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
#  89%|████████▉ | 89/100 [11:47<02:38, 14.39s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/viadee|javaAnchorExplainer'...
# 2022-10-26 09:17:07.181 | INFO     | __main__:<module>:17 - Found 1 versions for project viadee/javaAnchorExplainer
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '195dbf8f7751c6c2b235c1adb8883db4fb693403'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 195dbf8 Bump slf4j-ext from 1.7.16 to 1.7.26
# 100%|██████████| 1/1 [00:00<00:00, 25.54it/s]
#  90%|█████████ | 90/100 [11:48<01:44, 10.48s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/cheng-li|pyramid'...
# 2022-10-26 09:17:09.381 | INFO     | __main__:<module>:17 - Found 1 versions for project cheng-li/pyramid
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'fdcae6cfaf8607060f3f7607061155c4cffd421e'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at fdcae6cf Bump gson from 2.8.1 to 2.8.9 in /core
# 100%|██████████| 1/1 [00:00<00:00, 12.66it/s]
#  91%|█████████ | 91/100 [11:53<01:18,  8.77s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/tugraz-isds|systemds'...
# 2022-10-26 09:17:14.714 | INFO     | __main__:<module>:17 - Found 1 versions for project tugraz-isds/systemds
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '6574c9349b64fbd1373b52c7afebfde21bb7802a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6574c934 [SYSTEMDS-202] Fix rewrite split DAGs after data-dependent ops
#
# 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
#  92%|█████████▏| 92/100 [12:06<01:21, 10.19s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Hortensie|AI_Trader'...
# 2022-10-26 09:17:32.968 | INFO     | __main__:<module>:17 - Found 1 versions for project Hortensie/AI_Trader
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '1cd6c8b517bf96f5cc5ae2367f66b504eb749539'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 1cd6c8b Welcome Back - Android development !
#
# 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
#  93%|█████████▎| 93/100 [12:14<01:06,  9.47s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/Pradyuman7|LookAtMe'...
# 2022-10-26 09:17:35.291 | INFO     | __main__:<module>:17 - Found 1 versions for project Pradyuman7/LookAtMe
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'ec338a1cfa438799b6320fce5cc35cf8e5afc89a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ec338a1 Update README.md
# 100%|██████████| 1/1 [00:00<00:00, 15.34it/s]
#  94%|█████████▍| 94/100 [12:16<00:43,  7.19s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/MindorksOpenSource|AndroidTensorFlowMNISTExample'...
# 2022-10-26 09:17:43.811 | INFO     | __main__:<module>:17 - Found 1 versions for project MindorksOpenSource/AndroidTensorFlowMNISTExample
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'be06f1257d159ff10d9ea86d5fb8cf0187f32531'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at be06f12 update project to be compatible with AS 3.3.x
# 100%|██████████| 1/1 [00:00<00:00, 17.44it/s]
#  95%|█████████▌| 95/100 [12:25<00:37,  7.59s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/jblas-project|jblas'...
# 2022-10-26 09:17:51.281 | INFO     | __main__:<module>:17 - Found 1 versions for project jblas-project/jblas
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '1265b8d82e3133a156d9bcca5c67fbb24237ca94'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 1265b8d Removed libgfortran again and fixed Java home config for Mac OS X
#
# 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
#  96%|█████████▌| 96/100 [12:33<00:31,  7.85s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/gidim|Babler'...
# 2022-10-26 09:17:56.627 | INFO     | __main__:<module>:17 - Found 1 versions for project gidim/Babler
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'c5eb576dbee28c2895e1c2108ddab13ac22ad80a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at c5eb576 Fixed call to FileSaver
#
# 100%|██████████| 1/1 [00:00<00:00,  2.40it/s]
#  97%|█████████▋| 97/100 [12:38<00:20,  6.99s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/igorrendulic|food_recognition_with_calorie_mama'...
# 2022-10-26 09:17:58.072 | INFO     | __main__:<module>:17 - Found 1 versions for project igorrendulic/food_recognition_with_calorie_mama
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'fd3c068ef130ddde5a2fc2c91722dcd16bb07eba'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at fd3c068 Added display of calories
# 100%|██████████| 1/1 [00:00<00:00, 38.43it/s]
#  98%|█████████▊| 98/100 [12:39<00:10,  5.13s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/CeON|CERMINE'...
# 2022-10-26 09:18:20.209 | INFO     | __main__:<module>:17 - Found 1 versions for project CeON/CERMINE
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to 'ce9167af71d365d8515c155be25ef678beebf51a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ce9167af Bump itextpdf from 5.5.11 to 5.5.12 in /cermine-impl
#
# 100%|██████████| 1/1 [00:00<00:00,  3.60it/s]
#  99%|█████████▉| 99/100 [13:03<00:10, 10.77s/it]Cloning into '/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/repositories/rosette-api|rosette-elasticsearch-plugin'...
# 2022-10-26 09:18:22.856 | INFO     | __main__:<module>:17 - Found 1 versions for project rosette-api/rosette-elasticsearch-plugin
#
#   0%|          | 0/1 [00:00<?, ?it/s]Note: switching to '6d6f3e9774b123883507b3b1b1789acdd2904f25'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6d6f3e9 Bump elasticsearch from 7.17.0 to 7.17.1
# 100%|██████████| 1/1 [00:00<00:00, 57.53it/s]
# 100%|██████████| 100/100 [13:04<00:00,  7.84s/it]

# %%
with open("/home/sasce/PycharmProjects/CodeGraphClassification/data/raw/java_stopwords", 'rt') as inf:
    java_stopwords = {x.strip() for x in inf.readlines()}

# %%
java_stopwords.update(['get', 'set', 'org', 'com', 'exception', 'override', 'java', 'string',
                       'list', 'util', 'value', 'length', 'println'])

# %%
import yake
kw_extractor = yake.KeywordExtractor(n=1, stopwords=java_stopwords, top=50)
extracted_kw = {}

# %%
for project in keywords:
   extracted_kw[project] = kw_extractor.extract_keywords(" ".join(keywords[project]).lower().strip())

# %%
from collections import Counter

counter = Counter()
for p in extracted_kw:
    terms = [x[0] for x in extracted_kw[p]]
    counter.update(terms)

# %%
counter.most_common()
# Out:
# [('name', 66),
#  ('data', 63),
#  ('size', 61),
#  ('type', 55),
#  ('array', 54),
#  ('add', 54),
#  ('file', 54),
#  ('map', 52),
#  ('model', 50),
#  ('result', 45),
#  ('index', 39),
#  ('input', 35),
#  ('text', 30),
#  ('path', 30),
#  ('stream', 30),
#  ('log', 29),
#  ('output', 29),
#  ('builder', 29),
#  ('label', 28),
#  ('node', 27),
#  ('out', 27),
#  ('count', 27),
#  ('object', 27),
#  ('logger', 26),
#  ('integer', 25),
#  ('num', 25),
#  ('max', 25),
#  ('key', 23),
#  ('instance', 22),
#  ('context', 22),
#  ('create', 21),
#  ('vector', 21),
#  ('config', 20),
#  ('put', 20),
#  ('system', 20),
#  ('request', 19),
#  ('configuration', 18),
#  ('image', 18),
#  ('core', 17),
#  ('info', 17),
#  ('min', 17),
#  ('tree', 16),
#  ('hash', 16),
#  ('line', 16),
#  ('test', 16),
#  ('field', 15),
#  ('response', 15),
#  ('train', 15),
#  ('android', 15),
#  ('start', 15),
#  ('weight', 14),
#  ('error', 14),
#  ('height', 14),
#  ('args', 14),
#  ('matrix', 14),
#  ('feature', 14),
#  ('reader', 14),
#  ('entry', 13),
#  ('width', 13),
#  ('names', 13),
#  ('score', 13),
#  ('parameters', 13),
#  ('val', 13),
#  ('view', 13),
#  ('json', 13),
#  ('apache', 13),
#  ('features', 13),
#  ('url', 12),
#  ('tag', 12),
#  ('classifier', 12),
#  ('option', 12),
#  ('options', 12),
#  ('item', 12),
#  ('function', 12),
#  ('filter', 12),
#  ('types', 11),
#  ('token', 11),
#  ('sum', 11),
#  ('edu', 11),
#  ('task', 11),
#  ('source', 11),
#  ('append', 11),
#  ('point', 11),
#  ('labels', 11),
#  ('action', 11),
#  ('listener', 11),
#  ('color', 11),
#  ('activity', 11),
#  ('time', 11),
#  ('code', 11),
#  ('factory', 11),
#  ('next', 10),
#  ('entity', 10),
#  ('attribute', 10),
#  ('variable', 10),
#  ('column', 10),
#  ('params', 10),
#  ('split', 10),
#  ('conf', 10),
#  ('frame', 10),
#  ('dist', 10),
#  ('parameter', 10),
#  ('pair', 10),
#  ('iterator', 10),
#  ('row', 10),
#  ('api', 10),
#  ('math', 10),
#  ('element', 10),
#  ('message', 10),
#  ('points', 9),
#  ('idx', 9),
#  ('sample', 9),
#  ('current', 9),
#  ('layer', 9),
#  ('event', 9),
#  ('service', 9),
#  ('files', 9),
#  ('category', 9),
#  ('format', 9),
#  ('method', 9),
#  ('spark', 9),
#  ('state', 9),
#  ('layout', 9),
#  ('instances', 8),
#  ('intent', 8),
#  ('attributes', 8),
#  ('results', 8),
#  ('sentence', 8),
#  ('panel', 8),
#  ('find', 8),
#  ('param', 8),
#  ('end', 8),
#  ('resource', 8),
#  ('buffer', 8),
#  ('app', 8),
#  ('col', 8),
#  ('content', 8),
#  ('from', 8),
#  ('nodes', 7),
#  ('print', 7),
#  ('dir', 7),
#  ('query', 7),
#  ('server', 7),
#  ('javax', 7),
#  ('batch', 7),
#  ('learning', 7),
#  ('weights', 7),
#  ('network', 7),
#  ('var', 7),
#  ('obj', 7),
#  ('property', 7),
#  ('camera', 7),
#  ('user', 7),
#  ('base', 7),
#  ('build', 7),
#  ('classification', 7),
#  ('manager', 7),
#  ('arrays', 7),
#  ('main', 7),
#  ('run', 7),
#  ('read', 7),
#  ('rows', 7),
#  ('target', 7),
#  ('parse', 7),
#  ('click', 7),
#  ('button', 7),
#  ('inputs', 6),
#  ('word', 6),
#  ('sequence', 6),
#  ('document', 6),
#  ('annotation', 6),
#  ('job', 6),
#  ('layers', 6),
#  ('number', 6),
#  ('write', 6),
#  ('columns', 6),
#  ('menu', 6),
#  ('mat', 6),
#  ('img', 6),
#  ('date', 6),
#  ('runtime', 6),
#  ('http', 6),
#  ('dataset', 6),
#  ('uid', 6),
#  ('predict', 6),
#  ('load', 6),
#  ('cluster', 6),
#  ('version', 6),
#  ('distance', 6),
#  ('database', 6),
#  ('parser', 6),
#  ('activation', 6),
#  ('bitmap', 6),
#  ('keys', 5),
#  ('all', 5),
#  ('random', 5),
#  ('tokens', 5),
#  ('local', 5),
#  ('nlp', 5),
#  ('xml', 5),
#  ('repository', 5),
#  ('group', 5),
#  ('springframework', 5),
#  ('offset', 5),
#  ('prediction', 5),
#  ('pos', 5),
#  ('example', 5),
#  ('debug', 5),
#  ('common', 5),
#  ('awt', 5),
#  ('process', 5),
#  ('scale', 5),
#  ('buffered', 5),
#  ('selected', 5),
#  ('adapter', 5),
#  ('client', 5),
#  ('record', 5),
#  ('space', 5),
#  ('regression', 5),
#  ('memory', 5),
#  ('status', 5),
#  ('session', 5),
#  ('serializable', 5),
#  ('support', 5),
#  ('algorithm', 5),
#  ('merge', 5),
#  ('vec', 5),
#  ('expression', 5),
#  ('equals', 5),
#  ('tokenizer', 5),
#  ('temp', 5),
#  ('descriptor', 5),
#  ('internal', 5),
#  ('table', 5),
#  ('unknown', 5),
#  ('dialog', 5),
#  ('transform', 5),
#  ('google', 5),
#  ('metric', 5),
#  ('recognition', 5),
#  ('check', 5),
#  ('language', 5),
#  ('connection', 4),
#  ('child', 4),
#  ('remove', 4),
#  ('total', 4),
#  ('words', 4),
#  ('alpha', 4),
#  ('persistence', 4),
#  ('training', 4),
#  ('examples', 4),
#  ('variables', 4),
#  ('level', 4),
#  ('stats', 4),
#  ('left', 4),
#  ('swing', 4),
#  ('ret', 4),
#  ('opencv', 4),
#  ('rect', 4),
#  ('mask', 4),
#  ('border', 4),
#  ('threshold', 4),
#  ('images', 4),
#  ('services', 4),
#  ('csv', 4),
#  ('lang', 4),
#  ('last', 4),
#  ('simple', 4),
#  ('impl', 4),
#  ('scorer', 4),
#  ('wrapper', 4),
#  ('loss', 4),
#  ('validation', 4),
#  ('first', 4),
#  ('scores', 4),
#  ('schema', 4),
#  ('binary', 4),
#  ('trainer', 4),
#  ('description', 4),
#  ('linalg', 4),
#  ('executor', 4),
#  ('structure', 4),
#  ('indices', 4),
#  ('ids', 4),
#  ('counter', 4),
#  ('with', 4),
#  ('mean', 4),
#  ('leaf', 4),
#  ('github', 4),
#  ('collection', 4),
#  ('iter', 4),
#  ('thread', 4),
#  ('body', 4),
#  ('means', 4),
#  ('records', 4),
#  ('driver', 4),
#  ('range', 4),
#  ('prob', 4),
#  ('cols', 4),
#  ('tmp', 4),
#  ('other', 4),
#  ('inference', 4),
#  ('fields', 4),
#  ('graph', 4),
#  ('tags', 4),
#  ('processor', 4),
#  ('tensor', 4),
#  ('progress', 4),
#  ('component', 4),
#  ('real', 4),
#  ('parent', 4),
#  ('counts', 3),
#  ('iteration', 3),
#  ('position', 3),
#  ('term', 3),
#  ('search', 3),
#  ('cell', 3),
#  ('rate', 3),
#  ('predictor', 3),
#  ('old', 3),
#  ('literal', 3),
#  ('predicate', 3),
#  ('vars', 3),
#  ('handler', 3),
#  ('arg', 3),
#  ('constants', 3),
#  ('eval', 3),
#  ('plugin', 3),
#  ('dst', 3),
#  ('src', 3),
#  ('mats', 3),
#  ('vals', 3),
#  ('buff', 3),
#  ('channels', 3),
#  ('addr', 3),
#  ('flags', 3),
#  ('face', 3),
#  ('objects', 3),
#  ('tools', 3),
#  ('pixel', 3),
#  ('channel', 3),
#  ('dao', 3),
#  ('res', 3),
#  ('header', 3),
#  ('stack', 3),
#  ('normal', 3),
#  ('properties', 3),
#  ('kafka', 3),
#  ('viadee', 3),
#  ('link', 3),
#  ('update', 3),
#  ('learn', 3),
#  ('samples', 3),
#  ('categories', 3),
#  ('execute', 3),
#  ('delete', 3),
#  ('command', 3),
#  ('learner', 3),
#  ('initial', 3),
#  ('distribution', 3),
#  ('times', 3),
#  ('gpu', 3),
#  ('proto', 3),
#  ('tasks', 3),
#  ('hadoop', 3),
#  ('resources', 3),
#  ('protos', 3),
#  ('probability', 3),
#  ('loader', 3),
#  ('folder', 3),
#  ('compat', 3),
#  ('null', 3),
#  ('serial', 3),
#  ('head', 3),
#  ('cache', 3),
#  ('lexicon', 3),
#  ('symbol', 3),
#  ('identifier', 3),
#  ('clone', 3),
#  ('author', 3),
#  ('queue', 3),
#  ('elements', 3),
#  ('basic', 3),
#  ('compare', 3),
#  ('match', 3),
#  ('str', 3),
#  ('weka', 3),
#  ('att', 3),
#  ('inst', 3),
#  ('step', 3),
#  ('registry', 3),
#  ('extension', 3),
#  ('bit', 3),
#  ('generated', 3),
#  ('mutable', 3),
#  ('holder', 3),
#  ('extra', 3),
#  ('neurons', 3),
#  ('pattern', 3),
#  ('writer', 3),
#  ('datavec', 3),
#  ('multi', 3),
#  ('categorical', 3),
#  ('def', 3),
#  ('best', 3),
#  ('show', 3),
#  ('draw', 3),
#  ('klevis', 3),
#  ('ramo', 3),
#  ('metrics', 3),
#  ('transaction', 3),
#  ('dense', 3),
#  ('constant', 3),
#  ('flow', 3),
#  ('symbols', 3),
#  ('parallel', 3),
#  ('net', 3),
#  ('evidence', 3),
#  ('block', 3),
#  ('uri', 3),
#  ('mode', 3),
#  ('enabled', 2),
#  ('pool', 2),
#  ('mutate', 2),
#  ('evaluate', 2),
#  ('topic', 2),
#  ('lda', 2),
#  ('doc', 2),
#  ('zero', 2),
#  ('non', 2),
#  ('filename', 2),
#  ('cnt', 2),
#  ('bean', 2),
#  ('mapping', 2),
#  ('region', 2),
#  ('age', 2),
#  ('datas', 2),
#  ('sparse', 2),
#  ('pred', 2),
#  ('agg', 2),
#  ('models', 2),
#  ('grid', 2),
#  ('bag', 2),
#  ('settings', 2),
#  ('sequences', 2),
#  ('pane', 2),
#  ('cap', 2),
#  ('prop', 2),
#  ('criteria', 2),
#  ('pts', 2),
#  ('texture', 2),
#  ('surface', 2),
#  ('callback', 2),
#  ('lib', 2),
#  ('lombok', 2),
#  ('pojo', 2),
#  ('autowired', 2),
#  ('constructor', 2),
#  ('trace', 2),
#  ('infos', 2),
#  ('func', 2),
#  ('hdfs', 2),
#  ('events', 2),
#  ('identity', 2),
#  ('rest', 2),
#  ('execution', 2),
#  ('headers', 2),
#  ('module', 2),
#  ('make', 2),
#  ('gson', 2),
#  ('twitter', 2),
#  ('pointer', 2),
#  ('lock', 2),
#  ('second', 2),
#  ('save', 2),
#  ('gbm', 2),
#  ('has', 2),
#  ('linked', 2),
#  ('logistic', 2),
#  ('normalization', 2),
#  ('opt', 2),
#  ('probabilities', 2),
#  ('decision', 2),
#  ('kernel', 2),
#  ('capacity', 2),
#  ('illegal', 2),
#  ('spec', 2),
#  ('register', 2),
#  ('application', 2),
#  ('env', 2),
#  ('sql', 2),
#  ('rdd', 2),
#  ('supervised', 2),
#  ('strategy', 2),
#  ('ptr', 2),
#  ('library', 2),
#  ('bundle', 2),
#  ('dictionary', 2),
#  ('transition', 2),
#  ('candidate', 2),
#  ('sorted', 2),
#  ('len', 2),
#  ('vecs', 2),
#  ('seed', 2),
#  ('children', 2),
#  ('anchor', 2),
#  ('classify', 2),
#  ('generator', 2),
#  ('generators', 2),
#  ('confusion', 2),
#  ('per', 2),
#  ('calculator', 2),
#  ('comparator', 2),
#  ('relation', 2),
#  ('utilities', 2),
#  ('functions', 2),
#  ('ignore', 2),
#  ('mapper', 2),
#  ('classes', 2),
#  ('tensorflow', 2),
#  ('serving', 2),
#  ('lite', 2),
#  ('invalid', 2),
#  ('changed', 2),
#  ('ensure', 2),
#  ('cursor', 2),
#  ('preference', 2),
#  ('pref', 2),
#  ('bias', 2),
#  ('preds', 2),
#  ('runs', 2),
#  ('revision', 2),
#  ('success', 2),
#  ('artifact', 2),
#  ('previous', 2),
#  ('dependency', 2),
#  ('root', 2),
#  ('lexical', 2),
#  ('right', 2),
#  ('evaluation', 2),
#  ('protobuf', 2),
#  ('rank', 2),
#  ('sort', 2),
#  ('bar', 2),
#  ('rgb', 2),
#  ('font', 2),
#  ('actions', 2),
#  ('chooser', 2),
#  ('labeled', 2),
#  ('pixels', 2),
#  ('neural', 2),
#  ('conv', 2),
#  ('histogram', 2),
#  ('summary', 2),
#  ('servlet', 2),
#  ('web', 2),
#  ('epsilon', 2),
#  ('not', 2),
#  ('reg', 2),
#  ('logical', 2),
#  ('cornell', 2),
#  ('spf', 2),
#  ('lambda', 2),
#  ('joint', 2),
#  ('creator', 2),
#  ('syntax', 2),
#  ('rule', 2),
#  ('ccg', 2),
#  ('neuron', 2),
#  ('fea', 2),
#  ('project', 2),
#  ('connector', 2),
#  ('entities', 2),
#  ('fasterxml', 2),
#  ('jackson', 2),
#  ('pipeline', 2),
#  ('processors', 2),
#  ('similarity', 2),
#  ('neighbors', 2),
#  ('fast', 2),
#  ('copy', 2),
#  ('radius', 2),
#  ('bounds', 2),
#  ('heap', 2),
#  ('script', 2),
#  ('display', 2),
#  ('attr', 2),
#  ('std', 2),
#  ('err', 2),
#  ('metadata', 2),
#  ('ast', 2),
#  ('statement', 2),
#  ('dom', 2),
#  ('stop', 2),
#  ('states', 2),
#  ('middle', 2),
#  ('swap', 2),
#  ('standard', 2),
#  ('paths', 2),
#  ('substring', 2),
#  ('member', 2),
#  ('hidden', 2),
#  ('alert', 2),
#  ('background', 2),
#  ('delta', 2),
#  ('extractor', 2),
#  ('full', 2),
#  ('attrs', 2),
#  ('feed', 2),
#  ('confidence', 2),
#  ('title', 2),
#  ('box', 2),
#  ('directory', 2),
#  ('analysis', 2),
#  ('take', 2),
#  ('photo', 2),
#  ('picture', 2),
#  ('helper', 2),
#  ('translation', 2),
#  ('processing', 2),
#  ('paint', 2),
#  ('fragment', 2),
#  ('blocks', 2),
#  ('chunk', 2),
#  ('manifest', 2),
#  ('style', 2),
#  ('permission', 2),
#  ('location', 2),
#  ('construction', 2),
#  ('toast', 2),
#  ('detector', 2),
#  ('lines', 2),
#  ('gene', 1),
#  ('genome', 1),
#  ('fitness', 1),
#  ('mutation', 1),
#  ('genomes', 1),
#  ('neat', 1),
#  ('species', 1),
#  ('top', 1),
#  ('con', 1),
#  ('chance', 1),
#  ('innovation', 1),
#  ('rand', 1),
#  ('adjusted', 1),
#  ('rates', 1),
#  ('evo', 1),
#  ('staleness', 1),
#  ('survived', 1),
#  ('into', 1),
#  ('contains', 1),
#  ('incoming', 1),
#  ('collections', 1),
#  ('trait', 1),
#  ('topics', 1),
#  ('mallet', 1),
#  ('phi', 1),
#  ('sampler', 1),
#  ('alphabet', 1),
#  ('beta', 1),
#  ('pipe', 1),
#  ('tur', 1),
#  ('site', 1),
#  ('turing', 1),
#  ('converse', 1),
#  ('viglet', 1),
#  ('locale', 1),
#  ('bind', 1),
#  ('vendor', 1),
#  ('solr', 1),
#  ('spotlight', 1),
#  ('cells', 1),
#  ('agi', 1),
#  ('framework', 1),
#  ('series', 1),
#  ('sparsity', 1),
#  ('clause', 1),
#  ('clauses', 1),
#  ('literals', 1),
#  ('lit', 1),
#  ('ground', 1),
#  ('neg', 1),
#  ('arity', 1),
#  ('will', 1),
#  ('wisc', 1),
#  ('lits', 1),
#  ('groundings', 1),
#  ('use', 1),
#  ('gnd', 1),
#  ('shifu', 1),
#  ('bin', 1),
#  ('constraints', 1),
#  ('pca', 1),
#  ('vizbin', 1),
#  ('uni', 1),
#  ('lcsb', 1),
#  ('visible', 1),
#  ('kmer', 1),
#  ('polygon', 1),
#  ('converters', 1),
#  ('open', 1),
#  ('qupath', 1),
#  ('roi', 1),
#  ('javafx', 1),
#  ('hierarchy', 1),
#  ('viewer', 1),
#  ('measurement', 1),
#  ('gui', 1),
#  ('scene', 1),
#  ('jtang', 1),
#  ('pic', 1),
#  ('rsl', 1),
#  ('required', 1),
#  ('controller', 1),
#  ('warnings', 1),
#  ('suppress', 1),
#  ('polling', 1),
#  ('definition', 1),
#  ('camunda', 1),
#  ('historic', 1),
#  ('tenant', 1),
#  ('deployment', 1),
#  ('pollingclient', 1),
#  ('timeslice', 1),
#  ('poll', 1),
#  ('history', 1),
#  ('polled', 1),
#  ('timestamp', 1),
#  ('monkey', 1),
#  ('monkeylearn', 1),
#  ('endpoint', 1),
#  ('sleep', 1),
#  ('throttled', 1),
#  ('tuple', 1),
#  ('agent', 1),
#  ('requests', 1),
#  ('combined', 1),
#  ('pipelines', 1),
#  ('fbk', 1),
#  ('alignments', 1),
#  ('jooq', 1),
#  ('cube', 1),
#  ('provider', 1),
#  ('flink', 1),
#  ('sgd', 1),
#  ('wabbit', 1),
#  ('vowpal', 1),
#  ('namespace', 1),
#  ('indeed', 1),
#  ('regressor', 1),
#  ('and', 1),
#  ('flag', 1),
#  ('namespaces', 1),
#  ('actual', 1),
#  ('regularization', 1),
#  ('learners', 1),
#  ('light', 1),
#  ('booster', 1),
#  ('jpmml', 1),
#  ('converter', 1),
#  ('lightgbm', 1),
#  ('mining', 1),
#  ('dmg', 1),
#  ('pmml', 1),
#  ('gbdt', 1),
#  ('encode', 1),
#  ('sparkml', 1),
#  ('microsoft', 1),
#  ('lgbm', 1),
#  ('ioe', 1),
#  ('continuous', 1),
#  ('transformer', 1),
#  ('compact', 1),
#  ('shared', 1),
#  ('discrete', 1),
#  ('problem', 1),
#  ('measure', 1),
#  ('iterations', 1),
#  ('observations', 1),
#  ('rectangular', 1),
#  ('crossbow', 1),
#  ('imperial', 1),
#  ('lsds', 1),
#  ('shape', 1),
#  ('the', 1),
#  ('operator', 1),
#  ('requirements', 1),
#  ('buffers', 1),
#  ('gradient', 1),
#  ('phase', 1),
#  ('dataflow', 1),
#  ('ndx', 1),
#  ('padding', 1),
#  ('tony', 1),
#  ('container', 1),
#  ('yarn', 1),
#  ('linkedin', 1),
#  ('rpc', 1),
#  ('port', 1),
#  ('host', 1),
#  ('mmtf', 1),
#  ('chain', 1),
#  ('atom', 1),
#  ('sdsc', 1),
#  ('groups', 1),
#  ('chains', 1),
#  ('pdb', 1),
#  ('atoms', 1),
#  ('interactions', 1),
#  ('polymer', 1),
#  ('quickml', 1),
#  ('branch', 1),
#  ('ignoring', 1),
#  ('finder', 1),
#  ('predictive', 1),
#  ('counters', 1),
#  ('swig', 1),
#  ('crfsuite', 1),
#  ('jni', 1),
#  ('tagger', 1),
#  ('own', 1),
#  ('mem', 1),
#  ('crf', 1),
#  ('xseq', 1),
#  ('chokkan', 1),
#  ('third', 1),
#  ('party', 1),
#  ('suite', 1),
#  ('xseqs', 1),
#  ('jcrfsuite', 1),
#  ('yseq', 1),
#  ('clear', 1),
#  ('digest', 1),
#  ('saved', 1),
#  ('lizhangqu', 1),
#  ('dawg', 1),
#  ('liblevenshtein', 1),
#  ('transducer', 1),
#  ('positions', 1),
#  ('cli', 1),
#  ('levenshtein', 1),
#  ('terms', 1),
#  ('hashes', 1),
#  ('rounded', 1),
#  ('minset', 1),
#  ('concurrent', 1),
#  ('latch', 1),
#  ('done', 1),
#  ('down', 1),
#  ('buf', 1),
#  ('lzj', 1),
#  ('shift', 1),
#  ('illinois', 1),
#  ('cogcomp', 1),
#  ('lbjava', 1),
#  ('constraint', 1),
#  ('propositional', 1),
#  ('lce', 1),
#  ('pass', 1),
#  ('sym', 1),
#  ('yyline', 1),
#  ('yytext', 1),
#  ('yychar', 1),
#  ('tool', 1),
#  ('opennlp', 1),
#  ('cmdline', 1),
#  ('authorage', 1),
#  ('agepredictor', 1),
#  ('irds', 1),
#  ('usc', 1),
#  ('featureset', 1),
#  ('average', 1),
#  ('weighed', 1),
#  ('totals', 1),
#  ('hashtable', 1),
#  ('machinelearning', 1),
#  ('daslaboratorium', 1),
#  ('product', 1),
#  ('decrement', 1),
#  ('increment', 1),
#  ('forget', 1),
#  ('reset', 1),
#  ('bayes', 1),
#  ('assumed', 1),
#  ('elki', 1),
#  ('dbid', 1),
#  ('optionhandling', 1),
#  ('visualization', 1),
#  ('dbi', 1),
#  ('svg', 1),
#  ('logging', 1),
#  ('dim', 1),
#  ('store', 1),
#  ('knn', 1),
#  ('clustering', 1),
#  ('parameterization', 1),
#  ('outlier', 1),
#  ('spatial', 1),
#  ('slot', 1),
#  ('rabidgremlin', 1),
#  ('mutters', 1),
#  ('bot', 1),
#  ('story', 1),
#  ('slots', 1),
#  ('ink', 1),
#  ('matcher', 1),
#  ('intents', 1),
#  ('utterance', 1),
#  ('reprompt', 1),
#  ('quick', 1),
#  ('hint', 1),
#  ('attachments', 1),
#  ('confused', 1),
#  ('knot', 1),
#  ('replies', 1),
#  ('templated', 1),
#  ('writable', 1),
#  ('parts', 1),
#  ('lud', 1),
#  ('naive', 1),
#  ('mapreduce', 1),
#  ('interrupted', 1),
#  ('reducer', 1),
#  ('nth', 1),
#  ('gausssian', 1),
#  ('decomposition', 1),
#  ('comparable', 1),
#  ('missing', 1),
#  ('rapaio', 1),
#  ('svm', 1),
#  ('printer', 1),
#  ('palette', 1),
#  ('inception', 1),
#  ('streams', 1),
#  ('jpeg', 1),
#  ('encoded', 1),
#  ('accessor', 1),
#  ('initialized', 1),
#  ('protocol', 1),
#  ('empty', 1),
#  ('stub', 1),
#  ('sms', 1),
#  ('contract', 1),
#  ('selection', 1),
#  ('initialize', 1),
#  ('runnable', 1),
#  ('sim', 1),
#  ('trained', 1),
#  ('deep', 1),
#  ('fill', 1),
#  ('off', 1),
#  ('nums', 1),
#  ('normsub', 1),
#  ('normmul', 1),
#  ('hex', 1),
#  ('catoffsets', 1),
#  ('genmodel', 1),
#  ('udf', 1),
#  ('gen', 1),
#  ('auto', 1),
#  ('encoder', 1),
#  ('multiple', 1),
#  ('domains', 1),
#  ('ksql', 1),
#  ('confluent', 1),
#  ('exp', 1),
#  ('annotations', 1),
#  ('nfeatures', 1),
#  ('nclasses', 1),
#  ('mlflow', 1),
#  ('destination', 1),
#  ('environment', 1),
#  ('gocd', 1),
#  ('indix', 1),
#  ('handle', 1),
#  ('aws', 1),
#  ('thoughtworks', 1),
#  ('experiment', 1),
#  ('latest', 1),
#  ('promoted', 1),
#  ('kelp', 1),
#  ('representation', 1),
#  ('sag', 1),
#  ('relations', 1),
#  ('lemma', 1),
#  ('stanford', 1),
#  ('dependencies', 1),
#  ('synt', 1),
#  ('edge', 1),
#  ('generate', 1),
#  ('compositional', 1),
#  ('onyx', 1),
#  ('hanuor', 1),
#  ('toolbox', 1),
#  ('peeked', 1),
#  ('raw', 1),
#  ('adapters', 1),
#  ('peek', 1),
#  ('primitive', 1),
#  ('credential', 1),
#  ...]

# %%
kw_extractor = yake.KeywordExtractor(n=1, stopwords=java_stopwords, top=50)
all_text = " ".join([" ".join(keywords[project]) for project in keywords])

all_keywords =  kw_extractor.extract_keywords(all_text)

# %%
for x in all_keywords:
    print(x)
# Out:
# ('data', 2.5364163643828056e-08)
# ('name', 3.249414488485974e-08)
# ('type', 4.8664492873375205e-08)
# ('add', 5.944575887143773e-08)
# ('file', 6.063323783804538e-08)
# ('size', 6.553095029130837e-08)
# ('result', 7.124376940519278e-08)
# ('map', 8.854624674965106e-08)
# ('model', 9.227293667043316e-08)
# ('index', 9.760248942706905e-08)
# ('num', 1.003353467599736e-07)
# ('instance', 1.0478115211397847e-07)
# ('object', 1.1709826776616213e-07)
# ('node', 1.2902499287222149e-07)
# ('config', 1.4609188716585373e-07)
# ('input', 1.518467073108732e-07)
# ('instances', 1.6075679225146214e-07)
# ('array', 1.6452512673919166e-07)
# ('builder', 1.6622123735069255e-07)
# ('path', 1.780427693970337e-07)
# ('output', 1.975313558500376e-07)
# ('option', 2.0619667109775861e-07)
# ('max', 2.2310033336598874e-07)
# ('options', 2.5951338700805383e-07)
# ('vector', 2.625128668876674e-07)
# ('log', 2.849889020163885e-07)
# ('count', 2.856821810054825e-07)
# ('matrix', 3.0034718289317545e-07)
# ('names', 3.019885924266424e-07)
# ('attribute', 3.2237444323351874e-07)
# ('stream', 3.3007997213017764e-07)
# ('var', 3.304854946610449e-07)
# ('text', 3.4566930525897113e-07)
# ('key', 3.4775455579737604e-07)
# ('core', 3.5476470829812787e-07)
# ('label', 3.6266830673563234e-07)
# ('task', 3.8268087539438355e-07)
# ('append', 3.9370358399878e-07)
# ('gradle', 4.1038377977566597e-07)
# ('hash', 4.1361072144133903e-07)
# ('field', 4.16828830336797e-07)
# ('out', 4.3807830746370873e-07)
# ('obj', 4.6667059576472964e-07)
# ('image', 5.121133087271156e-07)
# ('min', 5.410695101006337e-07)
# ('weka', 5.429377651984582e-07)
# ('integer', 5.507614521755374e-07)
# ('clause', 5.565766021184881e-07)
# ('types', 5.566503036204642e-07)
# ('info', 5.579411933688861e-07)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import spacy

nlp = spacy.load("en_core_web_trf")
label_emb = list(nlp.pipe(['machine learning']))[0]._.trf_data.tensors[-1]
keywords = [x[0] for x in counter.most_common()]
print(len(keywords))
similarities = []
for i, doc in tqdm(enumerate(nlp.pipe(keywords))):
    tokvecs = doc._.trf_data.tensors[-1]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities.append((keywords[i], sim))
# Out:
# 1539
# 1539it [00:10, 152.52it/s]

# %%
similarities.sort(key=lambda x: -x[1])

# %%
len(similarities)
# Out:
# 1539

# %%
similarities[:50]
# Out:
# [('turing', 0.9809649),
#  ('instruction', 0.9800265),
#  ('streaming', 0.9777824),
#  ('construction', 0.97773445),
#  ('detection', 0.9767931),
#  ('utility', 0.976743),
#  ('modeler', 0.9764216),
#  ('scanner', 0.97631496),
#  ('detector', 0.9762422),
#  ('structure', 0.97588086),
#  ('training', 0.97576797),
#  ('mutation', 0.97568756),
#  ('machinelearning', 0.9753635),
#  ('specification', 0.97524905),
#  ('registry', 0.9751737),
#  ('planner', 0.9750017),
#  ('evaluation', 0.9748831),
#  ('activity', 0.9748595),
#  ('recognition', 0.97475684),
#  ('rotation', 0.9743566),
#  ('pattern', 0.97430557),
#  ('configuration', 0.9741598),
#  ('trainer', 0.97412884),
#  ('animation', 0.97403884),
#  ('polymer', 0.97387385),
#  ('sampling', 0.97385454),
#  ('mining', 0.973853),
#  ('trait', 0.9737062),
#  ('capacity', 0.9735535),
#  ('cluster', 0.9734316),
#  ('tracking', 0.97341496),
#  ('execution', 0.9733811),
#  ('taste', 0.97310764),
#  ('dependency', 0.9730565),
#  ('analysis', 0.9729489),
#  ('storage', 0.97260875),
#  ('regularization', 0.97256637),
#  ('validation', 0.9725188),
#  ('visitor', 0.97250986),
#  ('language', 0.97250456),
#  ('extension', 0.9724932),
#  ('vendor', 0.97245514),
#  ('convolution', 0.97235453),
#  ('expression', 0.97231877),
#  ('occurrence', 0.97227496),
#  ('segment', 0.9722193),
#  ('coverage', 0.972173),
#  ('device', 0.9721632),
#  ('branch', 0.9719856),
#  ('bucket', 0.97191334)]

# %%
from feature.embedding import FastTextEmbedding

ft = FastTextEmbedding(path='/home/sasce/PycharmProjects/CodeGraphClassification/data/models/wiki.en.bin', model='fastText')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
label_emb = [ft.get_embedding('machine learning')]
keywords = [x[0] for x in counter.most_common()]

similarities_ft = []
for i, key in tqdm(enumerate(keywords)):
    tokvecs = [ft.get_embedding(key)]
    sim = cosine_similarity(tokvecs, label_emb)[0][0]
    similarities_ft.append((keywords[i], sim))

similarities_ft.sort(key=lambda x: -x[1])
# Out:
# 1539it [00:00, 3457.35it/s]

# %%
similarities_ft[:50]
# Out:
# [('learning', 0.80086046),
#  ('machinelearning', 0.77182347),
#  ('learner', 0.59861034),
#  ('learners', 0.5608892),
#  ('learn', 0.5550004),
#  ('turing', 0.54515105),
#  ('weblearner', 0.51500314),
#  ('instruction', 0.500135),
#  ('dataflow', 0.48761946),
#  ('neural', 0.469069),
#  ('retrieval', 0.46826547),
#  ('learnlib', 0.46304932),
#  ('tool', 0.4624128),
#  ('processing', 0.46188936),
#  ('tasks', 0.4562919),
#  ('innovation', 0.44578502),
#  ('algorithm', 0.43994573),
#  ('visualization', 0.4318238),
#  ('tools', 0.4295457),
#  ('visualizer', 0.42692038),
#  ('inference', 0.42638168),
#  ('mapreduce', 0.42484185),
#  ('modeler', 0.4239036),
#  ('opencv', 0.42344636),
#  ('recognizer', 0.4231896),
#  ('iterator', 0.42285484),
#  ('predictive', 0.4199339),
#  ('extractor', 0.41926408),
#  ('tokenizer', 0.41307795),
#  ('processor', 0.4125301),
#  ('memory', 0.41247398),
#  ('javacpp', 0.41011852),
#  ('communication', 0.41005751),
#  ('training', 0.4083612),
#  ('ytklearn', 0.4064971),
#  ('encoder', 0.4046787),
#  ('propositional', 0.40421215),
#  ('validation', 0.40149376),
#  ('device', 0.40029234),
#  ('constraint', 0.3995658),
#  ('preprocessing', 0.3994797),
#  ('workflow', 0.3993489),
#  ('openscience', 0.39766753),
#  ('hadoop', 0.3957212),
#  ('opennlp', 0.3956968),
#  ('tensorflow', 0.39567605),
#  ('generator', 0.39478937),
#  ('optimize', 0.39476794),
#  ('clustering', 0.39436004),
#  ('writable', 0.3938091)]
