# %%
import sourcy

# %%
from sourcy.tokens.doc import Document
import tree_sitter
from tree_sitter.binding import Tree, Node
from typing import List


class Token(object):
    """
    Container for the token text and its annotations
    """

    def __init__(self, token: str, annotation=None, block_annotation=None, position=0):
        """
        :param token:
        :param annotation:
        :param block_annotation:
        """
        self._token = token
        self._annotation = annotation
        self._block = block_annotation
        self._position = position

    @property
    def token(self):
        return self._token

    @property
    def position(self):
        return self._position
    
    @property
    def annotation(self):
        return self._annotation

    @property
    def block(self):
        return self._block

    def __str__(self):
        return f"{self.token} - {self.annotation} - {self.block} - {self.position}"


def _extract_token_annotation(code: bytes, node: Node) -> (bytes, str):
    """
    Extract the token string from the code
    :param code: The code textual representation
    :param node: A node containing the start and end positions of the token
    :return:
    """
    token = code[node.start_byte:node.end_byte]
    annotations = node.type
    return token, annotations



def _traverse(code: bytes, tree: Tree) -> List[Token]:
        """
        Post-order tree traversal that returns a list of tokens with their annotations
        :param code: A byte string representation of the code
        :param tree: The tree representation of the code
        :return:
        """
        root = tree.root_node
        stack = deque()
        stack.append((root, None))

        tokens = []
        while len(stack):
            current, parent = stack.pop()

            if current.type != tree.root_node.type and len(current.children) == 0:
                token, annotation = _extract_token_annotation(code, current)
                _, block_annotation = _extract_token_annotation(code, parent)
                tokens.append(Token(token.decode("utf8"), annotation, block_annotation, current.start_byte))
            for child in current.children:
                stack.append((child, current))

        return tokens[::-1]

# %%
with open("/home/sasce/PycharmProjects/CodeGraphClassification/notebooks/test/resources/Lexer.java", 'rb') as f:
    file_content = f.read()

# %%
from tree_sitter import Language, Parser
from collections import deque

lang = tree_sitter.Language('/home/sasce/PycharmProjects/CodeGraphClassification/languages.so', 'java')
parser = Parser()
parser.set_language(lang)
tree = parser.parse(file_content)

# %%
tokens = _traverse(file_content, tree)

# %%
for t in tokens:
    print(str(t))
# Out:
# public - public - modifiers - 0
# abstract - abstract - modifiers - 7
# class - class - class_declaration - 16
# Lexer - identifier - class_declaration - 22
# extends - extends - superclass - 28
# Recognizer - type_identifier - generic_type - 36
# < - < - type_arguments - 46
# Integer - type_identifier - type_arguments - 47
# , - , - type_arguments - 54
# LexerATNSimulator - type_identifier - type_arguments - 56
# > - > - type_arguments - 73
# implements - implements - super_interfaces - 76
# TokenSource - type_identifier - type_list - 87
# { - { - class_body - 99
# public - public - modifiers - 102
# Lexer - identifier - constructor_declaration - 109
# ( - ( - formal_parameters - 114
# CharStream - type_identifier - formal_parameter - 115
# input - identifier - formal_parameter - 126
# ) - ) - formal_parameters - 131
# { - { - constructor_body - 133
# this - this - field_access - 137
# . - . - field_access - 141
# _input - identifier - field_access - 142
# = - = - assignment_expression - 149
# input - identifier - assignment_expression - 151
# ; - ; - expression_statement - 156
# this - this - field_access - 160
# . - . - field_access - 164
# _tokenFactorySourcePair - identifier - field_access - 165
# = - = - assignment_expression - 189
# new - new - object_creation_expression - 191
# Pair - type_identifier - generic_type - 195
# < - < - type_arguments - 199
# TokenSource - type_identifier - type_arguments - 200
# , - , - type_arguments - 211
# CharStream - type_identifier - type_arguments - 213
# > - > - type_arguments - 223
# ( - ( - argument_list - 224
# this - this - argument_list - 225
# , - , - argument_list - 229
# input - identifier - argument_list - 231
# ) - ) - argument_list - 236
# ; - ; - expression_statement - 237
# } - } - constructor_body - 240
# public - public - modifiers - 244
# void - void_type - method_declaration - 251
# reset - identifier - method_declaration - 256
# ( - ( - formal_parameters - 261
# ) - ) - formal_parameters - 262
# { - { - block - 264
# // wack Lexer state variables - line_comment - block - 268
# if - if - if_statement - 300
# ( - ( - parenthesized_expression - 303
# _input - identifier - binary_expression - 305
# != - != - binary_expression - 312
# null - null_literal - binary_expression - 314
# ) - ) - parenthesized_expression - 319
# { - { - block - 321
# _input - identifier - method_invocation - 326
# . - . - method_invocation - 332
# seek - identifier - method_invocation - 333
# ( - ( - argument_list - 337
# 0 - decimal_integer_literal - argument_list - 338
# ) - ) - argument_list - 339
# ; - ; - expression_statement - 340
# // rewind the input - line_comment - block - 342
# } - } - block - 364
# _token - identifier - assignment_expression - 368
# = - = - assignment_expression - 375
# null - null_literal - assignment_expression - 377
# ; - ; - expression_statement - 381
# _type - identifier - assignment_expression - 385
# = - = - assignment_expression - 391
# Token - identifier - field_access - 393
# . - . - field_access - 398
# INVALID_TYPE - identifier - field_access - 399
# ; - ; - expression_statement - 411
# _channel - identifier - assignment_expression - 415
# = - = - assignment_expression - 424
# Token - identifier - field_access - 426
# . - . - field_access - 431
# DEFAULT_CHANNEL - identifier - field_access - 432
# ; - ; - expression_statement - 447
# _tokenStartCharIndex - identifier - assignment_expression - 451
# = - = - assignment_expression - 472
# - - - - unary_expression - 474
# 1 - decimal_integer_literal - unary_expression - 475
# ; - ; - expression_statement - 476
# _tokenStartCharPositionInLine - identifier - assignment_expression - 480
# = - = - assignment_expression - 510
# - - - - unary_expression - 512
# 1 - decimal_integer_literal - unary_expression - 513
# ; - ; - expression_statement - 514
# _tokenStartLine - identifier - assignment_expression - 518
# = - = - assignment_expression - 534
# - - - - unary_expression - 536
# 1 - decimal_integer_literal - unary_expression - 537
# ; - ; - expression_statement - 538
# _text - identifier - assignment_expression - 542
# = - = - assignment_expression - 548
# null - null_literal - assignment_expression - 550
# ; - ; - expression_statement - 554
# _hitEOF - identifier - assignment_expression - 559
# = - = - assignment_expression - 567
# false - false - assignment_expression - 569
# ; - ; - expression_statement - 574
# _mode - identifier - assignment_expression - 578
# = - = - assignment_expression - 584
# Lexer - identifier - field_access - 586
# . - . - field_access - 591
# DEFAULT_MODE - identifier - field_access - 592
# ; - ; - expression_statement - 604
# _modeStack - identifier - method_invocation - 608
# . - . - method_invocation - 618
# clear - identifier - method_invocation - 619
# ( - ( - argument_list - 624
# ) - ) - argument_list - 625
# ; - ; - expression_statement - 626
# getInterpreter - identifier - method_invocation - 631
# ( - ( - argument_list - 645
# ) - ) - argument_list - 646
# . - . - method_invocation - 647
# reset - identifier - method_invocation - 648
# ( - ( - argument_list - 653
# ) - ) - argument_list - 654
# ; - ; - expression_statement - 655
# } - } - block - 658
# /** Return a token from this source; i.e., match a token on the char
# 	 *  stream.
# 	 */ - block_comment - class_body - 662
# @ - @ - marker_annotation - 750
# Override - identifier - marker_annotation - 751
# public - public - modifiers - 761
# Token - type_identifier - method_declaration - 768
# nextToken - identifier - method_declaration - 774
# ( - ( - formal_parameters - 783
# ) - ) - formal_parameters - 784
# { - { - block - 786
# if - if - if_statement - 790
# ( - ( - parenthesized_expression - 793
# _input - identifier - binary_expression - 794
# == - == - binary_expression - 801
# null - null_literal - binary_expression - 804
# ) - ) - parenthesized_expression - 808
# { - { - block - 810
# throw - throw - throw_statement - 815
# new - new - object_creation_expression - 821
# IllegalStateException - type_identifier - object_creation_expression - 825
# ( - ( - argument_list - 846
# "nextToken requires a non-null input stream." - string_literal - argument_list - 847
# ) - ) - argument_list - 892
# ; - ; - throw_statement - 893
# } - } - block - 897
# // Mark start location in char stream so unbuffered streams are - line_comment - block - 902
# // guaranteed at least have text of current token - line_comment - block - 968
# int - int - integral_type - 1020
# tokenStartMarker - identifier - variable_declarator - 1024
# = - = - variable_declarator - 1041
# _input - identifier - method_invocation - 1043
# . - . - method_invocation - 1049
# mark - identifier - method_invocation - 1050
# ( - ( - argument_list - 1054
# ) - ) - argument_list - 1055
# ; - ; - local_variable_declaration - 1056
# try - try - try_statement - 1060
# { - { - block - 1063
# outer - identifier - labeled_statement - 1068
# : - : - labeled_statement - 1073
# while - while - while_statement - 1078
# ( - ( - parenthesized_expression - 1084
# true - true - parenthesized_expression - 1085
# ) - ) - parenthesized_expression - 1089
# { - { - block - 1091
# if - if - if_statement - 1097
# ( - ( - parenthesized_expression - 1100
# _hitEOF - identifier - parenthesized_expression - 1101
# ) - ) - parenthesized_expression - 1108
# { - { - block - 1110
# emitEOF - identifier - method_invocation - 1117
# ( - ( - argument_list - 1124
# ) - ) - argument_list - 1125
# ; - ; - expression_statement - 1126
# return - return - return_statement - 1133
# _token - identifier - return_statement - 1140
# ; - ; - return_statement - 1146
# } - } - block - 1152
# _token - identifier - assignment_expression - 1159
# = - = - assignment_expression - 1166
# null - null_literal - assignment_expression - 1168
# ; - ; - expression_statement - 1172
# _channel - identifier - assignment_expression - 1178
# = - = - assignment_expression - 1187
# Token - identifier - field_access - 1189
# . - . - field_access - 1194
# DEFAULT_CHANNEL - identifier - field_access - 1195
# ; - ; - expression_statement - 1210
# _tokenStartCharIndex - identifier - assignment_expression - 1216
# = - = - assignment_expression - 1237
# _input - identifier - method_invocation - 1239
# . - . - method_invocation - 1245
# index - identifier - method_invocation - 1246
# ( - ( - argument_list - 1251
# ) - ) - argument_list - 1252
# ; - ; - expression_statement - 1253
# _tokenStartCharPositionInLine - identifier - assignment_expression - 1259
# = - = - assignment_expression - 1289
# getInterpreter - identifier - method_invocation - 1291
# ( - ( - argument_list - 1305
# ) - ) - argument_list - 1306
# . - . - method_invocation - 1307
# getCharPositionInLine - identifier - method_invocation - 1308
# ( - ( - argument_list - 1329
# ) - ) - argument_list - 1330
# ; - ; - expression_statement - 1331
# _tokenStartLine - identifier - assignment_expression - 1337
# = - = - assignment_expression - 1353
# getInterpreter - identifier - method_invocation - 1355
# ( - ( - argument_list - 1369
# ) - ) - argument_list - 1370
# . - . - method_invocation - 1371
# getLine - identifier - method_invocation - 1372
# ( - ( - argument_list - 1379
# ) - ) - argument_list - 1380
# ; - ; - expression_statement - 1381
# _text - identifier - assignment_expression - 1387
# = - = - assignment_expression - 1393
# null - null_literal - assignment_expression - 1395
# ; - ; - expression_statement - 1399
# do - do - do_statement - 1405
# { - { - block - 1408
# _type - identifier - assignment_expression - 1415
# = - = - assignment_expression - 1421
# Token - identifier - field_access - 1423
# . - . - field_access - 1428
# INVALID_TYPE - identifier - field_access - 1429
# ; - ; - expression_statement - 1441
# //				System.out.println("nextToken line "+tokenStartLine+" at "+((char)input.LA(1))+ - line_comment - block - 1443
# //								   " in mode "+mode+ - line_comment - block - 1529
# //								   " at index "+input.index()); - line_comment - block - 1560
# int - int - integral_type - 1607
# ttype - identifier - variable_declarator - 1611
# ; - ; - local_variable_declaration - 1616
# try - try - try_statement - 1623
# { - { - block - 1627
# ttype - identifier - assignment_expression - 1635
# = - = - assignment_expression - 1641
# getInterpreter - identifier - method_invocation - 1643
# ( - ( - argument_list - 1657
# ) - ) - argument_list - 1658
# . - . - method_invocation - 1659
# match - identifier - method_invocation - 1660
# ( - ( - argument_list - 1665
# _input - identifier - argument_list - 1666
# , - , - argument_list - 1672
# _mode - identifier - argument_list - 1674
# ) - ) - argument_list - 1679
# ; - ; - expression_statement - 1680
# } - } - block - 1687
# catch - catch - catch_clause - 1694
# ( - ( - catch_clause - 1700
# LexerNoViableAltException - type_identifier - catch_type - 1701
# e - identifier - catch_formal_parameter - 1727
# ) - ) - catch_clause - 1728
# { - { - block - 1730
# notifyListeners - identifier - method_invocation - 1738
# ( - ( - argument_list - 1753
# e - identifier - argument_list - 1754
# ) - ) - argument_list - 1755
# ; - ; - expression_statement - 1756
# // report error - line_comment - block - 1759
# recover - identifier - method_invocation - 1781
# ( - ( - argument_list - 1788
# e - identifier - argument_list - 1789
# ) - ) - argument_list - 1790
# ; - ; - expression_statement - 1791
# ttype - identifier - assignment_expression - 1799
# = - = - assignment_expression - 1805
# SKIP - identifier - assignment_expression - 1807
# ; - ; - expression_statement - 1811
# } - } - block - 1818
# if - if - if_statement - 1825
# ( - ( - parenthesized_expression - 1828
# _input - identifier - method_invocation - 1830
# . - . - method_invocation - 1836
# LA - identifier - method_invocation - 1837
# ( - ( - argument_list - 1839
# 1 - decimal_integer_literal - argument_list - 1840
# ) - ) - argument_list - 1841
# == - == - binary_expression - 1842
# IntStream - identifier - field_access - 1844
# . - . - field_access - 1853
# EOF - identifier - field_access - 1854
# ) - ) - parenthesized_expression - 1858
# { - { - block - 1860
# _hitEOF - identifier - assignment_expression - 1868
# = - = - assignment_expression - 1876
# true - true - assignment_expression - 1878
# ; - ; - expression_statement - 1882
# } - } - block - 1889
# if - if - if_statement - 1896
# ( - ( - parenthesized_expression - 1899
# _type - identifier - binary_expression - 1901
# == - == - binary_expression - 1907
# Token - identifier - field_access - 1910
# . - . - field_access - 1915
# INVALID_TYPE - identifier - field_access - 1916
# ) - ) - parenthesized_expression - 1929
# _type - identifier - assignment_expression - 1931
# = - = - assignment_expression - 1937
# ttype - identifier - assignment_expression - 1939
# ; - ; - expression_statement - 1944
# if - if - if_statement - 1951
# ( - ( - parenthesized_expression - 1954
# _type - identifier - binary_expression - 1956
# == - == - binary_expression - 1962
# SKIP - identifier - binary_expression - 1964
# ) - ) - parenthesized_expression - 1969
# { - { - block - 1971
# continue - continue - continue_statement - 1979
# outer - identifier - continue_statement - 1988
# ; - ; - continue_statement - 1993
# } - } - block - 2000
# } - } - block - 2006
# while - while - do_statement - 2008
# ( - ( - parenthesized_expression - 2014
# _type - identifier - binary_expression - 2016
# == - == - binary_expression - 2022
# MORE - identifier - binary_expression - 2024
# ) - ) - parenthesized_expression - 2029
# ; - ; - do_statement - 2030
# if - if - if_statement - 2036
# ( - ( - parenthesized_expression - 2039
# _token - identifier - binary_expression - 2041
# == - == - binary_expression - 2048
# null - null_literal - binary_expression - 2051
# ) - ) - parenthesized_expression - 2056
# emit - identifier - method_invocation - 2058
# ( - ( - argument_list - 2062
# ) - ) - argument_list - 2063
# ; - ; - expression_statement - 2064
# return - return - return_statement - 2070
# _token - identifier - return_statement - 2077
# ; - ; - return_statement - 2083
# } - } - block - 2088
# } - } - block - 2092
# finally - finally - finally_clause - 2096
# { - { - block - 2104
# // make sure we release marker after match or - line_comment - block - 2109
# // unbuffered char stream will keep buffering - line_comment - block - 2158
# _input - identifier - method_invocation - 2207
# . - . - method_invocation - 2213
# release - identifier - method_invocation - 2214
# ( - ( - argument_list - 2221
# tokenStartMarker - identifier - argument_list - 2222
# ) - ) - argument_list - 2238
# ; - ; - expression_statement - 2239
# } - } - block - 2243
# } - } - block - 2246
# /** Instruct the lexer to skip creating a token for current lexer rule
# 	 *  and look for another token.  nextToken() knows to keep looking when
# 	 *  a lexer rule finishes with token set to SKIP_TOKEN.  Recall that
# 	 *  if token==null at end of any token rule, it creates one for you
# 	 *  and emits it.
# 	 */ - block_comment - class_body - 2250
# public - public - modifiers - 2558
# void - void_type - method_declaration - 2565
# skip - identifier - method_declaration - 2570
# ( - ( - formal_parameters - 2574
# ) - ) - formal_parameters - 2575
# { - { - block - 2577
# _type - identifier - assignment_expression - 2581
# = - = - assignment_expression - 2587
# SKIP - identifier - assignment_expression - 2589
# ; - ; - expression_statement - 2593
# } - } - block - 2596
# public - public - modifiers - 2600
# void - void_type - method_declaration - 2607
# more - identifier - method_declaration - 2612
# ( - ( - formal_parameters - 2616
# ) - ) - formal_parameters - 2617
# { - { - block - 2619
# _type - identifier - assignment_expression - 2623
# = - = - assignment_expression - 2629
# MORE - identifier - assignment_expression - 2631
# ; - ; - expression_statement - 2635
# } - } - block - 2638
# public - public - modifiers - 2642
# void - void_type - method_declaration - 2649
# mode - identifier - method_declaration - 2654
# ( - ( - formal_parameters - 2658
# int - int - integral_type - 2659
# m - identifier - formal_parameter - 2663
# ) - ) - formal_parameters - 2664
# { - { - block - 2666
# _mode - identifier - assignment_expression - 2670
# = - = - assignment_expression - 2676
# m - identifier - assignment_expression - 2678
# ; - ; - expression_statement - 2679
# } - } - block - 2682
# public - public - modifiers - 2686
# void - void_type - method_declaration - 2693
# pushMode - identifier - method_declaration - 2698
# ( - ( - formal_parameters - 2706
# int - int - integral_type - 2707
# m - identifier - formal_parameter - 2711
# ) - ) - formal_parameters - 2712
# { - { - block - 2714
# if - if - if_statement - 2718
# ( - ( - parenthesized_expression - 2721
# LexerATNSimulator - identifier - field_access - 2723
# . - . - field_access - 2740
# debug - identifier - field_access - 2741
# ) - ) - parenthesized_expression - 2747
# System - identifier - field_access - 2749
# . - . - field_access - 2755
# out - identifier - field_access - 2756
# . - . - method_invocation - 2759
# println - identifier - method_invocation - 2760
# ( - ( - argument_list - 2767
# "pushMode " - string_literal - binary_expression - 2768
# + - + - binary_expression - 2779
# m - identifier - binary_expression - 2780
# ) - ) - argument_list - 2781
# ; - ; - expression_statement - 2782
# _modeStack - identifier - method_invocation - 2786
# . - . - method_invocation - 2796
# push - identifier - method_invocation - 2797
# ( - ( - argument_list - 2801
# _mode - identifier - argument_list - 2802
# ) - ) - argument_list - 2807
# ; - ; - expression_statement - 2808
# mode - identifier - method_invocation - 2812
# ( - ( - argument_list - 2816
# m - identifier - argument_list - 2817
# ) - ) - argument_list - 2818
# ; - ; - expression_statement - 2819
# } - } - block - 2822
# public - public - modifiers - 2826
# int - int - integral_type - 2833
# popMode - identifier - method_declaration - 2837
# ( - ( - formal_parameters - 2844
# ) - ) - formal_parameters - 2845
# { - { - block - 2847
# if - if - if_statement - 2851
# ( - ( - parenthesized_expression - 2854
# _modeStack - identifier - method_invocation - 2856
# . - . - method_invocation - 2866
# isEmpty - identifier - method_invocation - 2867
# ( - ( - argument_list - 2874
# ) - ) - argument_list - 2875
# ) - ) - parenthesized_expression - 2877
# throw - throw - throw_statement - 2879
# new - new - object_creation_expression - 2885
# EmptyStackException - type_identifier - object_creation_expression - 2889
# ( - ( - argument_list - 2908
# ) - ) - argument_list - 2909
# ; - ; - throw_statement - 2910
# if - if - if_statement - 2914
# ( - ( - parenthesized_expression - 2917
# LexerATNSimulator - identifier - field_access - 2919
# . - . - field_access - 2936
# debug - identifier - field_access - 2937
# ) - ) - parenthesized_expression - 2943
# System - identifier - field_access - 2945
# . - . - field_access - 2951
# out - identifier - field_access - 2952
# . - . - method_invocation - 2955
# println - identifier - method_invocation - 2956
# ( - ( - argument_list - 2963
# "popMode back to " - string_literal - binary_expression - 2964
# + - + - binary_expression - 2982
# _modeStack - identifier - method_invocation - 2984
# . - . - method_invocation - 2994
# peek - identifier - method_invocation - 2995
# ( - ( - argument_list - 2999
# ) - ) - argument_list - 3000
# ) - ) - argument_list - 3001
# ; - ; - expression_statement - 3002
# mode - identifier - method_invocation - 3006
# ( - ( - argument_list - 3010
# _modeStack - identifier - method_invocation - 3012
# . - . - method_invocation - 3022
# pop - identifier - method_invocation - 3023
# ( - ( - argument_list - 3026
# ) - ) - argument_list - 3027
# ) - ) - argument_list - 3029
# ; - ; - expression_statement - 3030
# return - return - return_statement - 3034
# _mode - identifier - return_statement - 3041
# ; - ; - return_statement - 3046
# } - } - block - 3049
# @ - @ - marker_annotation - 3053
# Override - identifier - marker_annotation - 3054
# public - public - modifiers - 3064
# void - void_type - method_declaration - 3071
# setTokenFactory - identifier - method_declaration - 3076
# ( - ( - formal_parameters - 3091
# TokenFactory - type_identifier - generic_type - 3092
# < - < - type_arguments - 3104
# ? - ? - wildcard - 3105
# > - > - type_arguments - 3106
# factory - identifier - formal_parameter - 3108
# ) - ) - formal_parameters - 3115
# { - { - block - 3117
# this - this - field_access - 3121
# . - . - field_access - 3125
# _factory - identifier - field_access - 3126
# = - = - assignment_expression - 3135
# factory - identifier - assignment_expression - 3137
# ; - ; - expression_statement - 3144
# } - } - block - 3147
# @ - @ - marker_annotation - 3151
# Override - identifier - marker_annotation - 3152
# public - public - modifiers - 3162
# TokenFactory - type_identifier - generic_type - 3169
# < - < - type_arguments - 3181
# ? - ? - wildcard - 3182
# extends - extends - wildcard - 3184
# Token - type_identifier - wildcard - 3192
# > - > - type_arguments - 3197
# getTokenFactory - identifier - method_declaration - 3199
# ( - ( - formal_parameters - 3214
# ) - ) - formal_parameters - 3215
# { - { - block - 3217
# return - return - return_statement - 3221
# _factory - identifier - return_statement - 3228
# ; - ; - return_statement - 3236
# } - } - block - 3239
# /** Set the char stream and reset the lexer */ - block_comment - class_body - 3243
# @ - @ - marker_annotation - 3291
# Override - identifier - marker_annotation - 3292
# public - public - modifiers - 3302
# void - void_type - method_declaration - 3309
# setInputStream - identifier - method_declaration - 3314
# ( - ( - formal_parameters - 3328
# IntStream - type_identifier - formal_parameter - 3329
# input - identifier - formal_parameter - 3339
# ) - ) - formal_parameters - 3344
# { - { - block - 3346
# this - this - field_access - 3350
# . - . - field_access - 3354
# _input - identifier - field_access - 3355
# = - = - assignment_expression - 3362
# null - null_literal - assignment_expression - 3364
# ; - ; - expression_statement - 3368
# this - this - field_access - 3372
# . - . - field_access - 3376
# _tokenFactorySourcePair - identifier - field_access - 3377
# = - = - assignment_expression - 3401
# new - new - object_creation_expression - 3403
# Pair - type_identifier - generic_type - 3407
# < - < - type_arguments - 3411
# TokenSource - type_identifier - type_arguments - 3412
# , - , - type_arguments - 3423
# CharStream - type_identifier - type_arguments - 3425
# > - > - type_arguments - 3435
# ( - ( - argument_list - 3436
# this - this - argument_list - 3437
# , - , - argument_list - 3441
# _input - identifier - argument_list - 3443
# ) - ) - argument_list - 3449
# ; - ; - expression_statement - 3450
# reset - identifier - method_invocation - 3454
# ( - ( - argument_list - 3459
# ) - ) - argument_list - 3460
# ; - ; - expression_statement - 3461
# this - this - field_access - 3465
# . - . - field_access - 3469
# _input - identifier - field_access - 3470
# = - = - assignment_expression - 3477
# ( - ( - cast_expression - 3479
# CharStream - type_identifier - cast_expression - 3480
# ) - ) - cast_expression - 3490
# input - identifier - cast_expression - 3491
# ; - ; - expression_statement - 3496
# this - this - field_access - 3500
# . - . - field_access - 3504
# _tokenFactorySourcePair - identifier - field_access - 3505
# = - = - assignment_expression - 3529
# new - new - object_creation_expression - 3531
# Pair - type_identifier - generic_type - 3535
# < - < - type_arguments - 3539
# TokenSource - type_identifier - type_arguments - 3540
# , - , - type_arguments - 3551
# CharStream - type_identifier - type_arguments - 3553
# > - > - type_arguments - 3563
# ( - ( - argument_list - 3564
# this - this - argument_list - 3565
# , - , - argument_list - 3569
# _input - identifier - argument_list - 3571
# ) - ) - argument_list - 3577
# ; - ; - expression_statement - 3578
# } - } - block - 3581
# @ - @ - marker_annotation - 3585
# Override - identifier - marker_annotation - 3586
# public - public - modifiers - 3596
# String - type_identifier - method_declaration - 3603
# getSourceName - identifier - method_declaration - 3610
# ( - ( - formal_parameters - 3623
# ) - ) - formal_parameters - 3624
# { - { - block - 3626
# return - return - return_statement - 3630
# _input - identifier - method_invocation - 3637
# . - . - method_invocation - 3643
# getSourceName - identifier - method_invocation - 3644
# ( - ( - argument_list - 3657
# ) - ) - argument_list - 3658
# ; - ; - return_statement - 3659
# } - } - block - 3662
# @ - @ - marker_annotation - 3666
# Override - identifier - marker_annotation - 3667
# public - public - modifiers - 3677
# CharStream - type_identifier - method_declaration - 3684
# getInputStream - identifier - method_declaration - 3695
# ( - ( - formal_parameters - 3709
# ) - ) - formal_parameters - 3710
# { - { - block - 3712
# return - return - return_statement - 3716
# _input - identifier - return_statement - 3723
# ; - ; - return_statement - 3729
# } - } - block - 3732
# /** By default does not support multiple emits per nextToken invocation
# 	 *  for efficiency reasons.  Subclass and override this method, nextToken,
# 	 *  and getToken (to push tokens into a list and pull from that list
# 	 *  rather than a single variable as this implementation does).
# 	 */ - block_comment - class_body - 3736
# public - public - modifiers - 4025
# void - void_type - method_declaration - 4032
# emit - identifier - method_declaration - 4037
# ( - ( - formal_parameters - 4041
# Token - type_identifier - formal_parameter - 4042
# token - identifier - formal_parameter - 4048
# ) - ) - formal_parameters - 4053
# { - { - block - 4055
# //System.err.println("emit "+token); - line_comment - block - 4059
# this - this - field_access - 4098
# . - . - field_access - 4102
# _token - identifier - field_access - 4103
# = - = - assignment_expression - 4110
# token - identifier - assignment_expression - 4112
# ; - ; - expression_statement - 4117
# } - } - block - 4120
# /** The standard method called to automatically emit a token at the
# 	 *  outermost lexical rule.  The token object should point into the
# 	 *  char buffer start..stop.  If there is a text override in 'text',
# 	 *  use that to set the token's text.  Override this method to emit
# 	 *  custom Token objects or provide a new factory.
# 	 */ - block_comment - class_body - 4124
# public - public - modifiers - 4458
# Token - type_identifier - method_declaration - 4465
# emit - identifier - method_declaration - 4471
# ( - ( - formal_parameters - 4475
# ) - ) - formal_parameters - 4476
# { - { - block - 4478
# Token - type_identifier - local_variable_declaration - 4482
# t - identifier - variable_declarator - 4488
# = - = - variable_declarator - 4490
# _factory - identifier - method_invocation - 4492
# . - . - method_invocation - 4500
# create - identifier - method_invocation - 4501
# ( - ( - argument_list - 4507
# _tokenFactorySourcePair - identifier - argument_list - 4508
# , - , - argument_list - 4531
# _type - identifier - argument_list - 4533
# , - , - argument_list - 4538
# _text - identifier - argument_list - 4540
# , - , - argument_list - 4545
# _channel - identifier - argument_list - 4547
# , - , - argument_list - 4555
# _tokenStartCharIndex - identifier - argument_list - 4557
# , - , - argument_list - 4577
# getCharIndex - identifier - method_invocation - 4579
# ( - ( - argument_list - 4591
# ) - ) - argument_list - 4592
# - - - - binary_expression - 4593
# 1 - decimal_integer_literal - binary_expression - 4594
# , - , - argument_list - 4595
# _tokenStartLine - identifier - argument_list - 4607
# , - , - argument_list - 4622
# _tokenStartCharPositionInLine - identifier - argument_list - 4624
# ) - ) - argument_list - 4653
# ; - ; - local_variable_declaration - 4654
# emit - identifier - method_invocation - 4658
# ( - ( - argument_list - 4662
# t - identifier - argument_list - 4663
# ) - ) - argument_list - 4664
# ; - ; - expression_statement - 4665
# return - return - return_statement - 4669
# t - identifier - return_statement - 4676
# ; - ; - return_statement - 4677
# } - } - block - 4680
# public - public - modifiers - 4684
# Token - type_identifier - method_declaration - 4691
# emitEOF - identifier - method_declaration - 4697
# ( - ( - formal_parameters - 4704
# ) - ) - formal_parameters - 4705
# { - { - block - 4707
# int - int - integral_type - 4711
# cpos - identifier - variable_declarator - 4715
# = - = - variable_declarator - 4720
# getCharPositionInLine - identifier - method_invocation - 4722
# ( - ( - argument_list - 4743
# ) - ) - argument_list - 4744
# ; - ; - local_variable_declaration - 4745
# int - int - integral_type - 4749
# line - identifier - variable_declarator - 4753
# = - = - variable_declarator - 4758
# getLine - identifier - method_invocation - 4760
# ( - ( - argument_list - 4767
# ) - ) - argument_list - 4768
# ; - ; - local_variable_declaration - 4769
# Token - type_identifier - local_variable_declaration - 4773
# eof - identifier - variable_declarator - 4779
# = - = - variable_declarator - 4783
# _factory - identifier - method_invocation - 4785
# . - . - method_invocation - 4793
# create - identifier - method_invocation - 4794
# ( - ( - argument_list - 4800
# _tokenFactorySourcePair - identifier - argument_list - 4801
# , - , - argument_list - 4824
# Token - identifier - field_access - 4826
# . - . - field_access - 4831
# EOF - identifier - field_access - 4832
# , - , - argument_list - 4835
# null - null_literal - argument_list - 4837
# , - , - argument_list - 4841
# Token - identifier - field_access - 4843
# . - . - field_access - 4848
# DEFAULT_CHANNEL - identifier - field_access - 4849
# , - , - argument_list - 4864
# _input - identifier - method_invocation - 4866
# . - . - method_invocation - 4872
# index - identifier - method_invocation - 4873
# ( - ( - argument_list - 4878
# ) - ) - argument_list - 4879
# , - , - argument_list - 4880
# _input - identifier - method_invocation - 4882
# . - . - method_invocation - 4888
# index - identifier - method_invocation - 4889
# ( - ( - argument_list - 4894
# ) - ) - argument_list - 4895
# - - - - binary_expression - 4896
# 1 - decimal_integer_literal - binary_expression - 4897
# , - , - argument_list - 4898
# line - identifier - argument_list - 4909
# , - , - argument_list - 4913
# cpos - identifier - argument_list - 4915
# ) - ) - argument_list - 4919
# ; - ; - local_variable_declaration - 4920
# emit - identifier - method_invocation - 4924
# ( - ( - argument_list - 4928
# eof - identifier - argument_list - 4929
# ) - ) - argument_list - 4932
# ; - ; - expression_statement - 4933
# return - return - return_statement - 4937
# eof - identifier - return_statement - 4944
# ; - ; - return_statement - 4947
# } - } - block - 4950
# @ - @ - marker_annotation - 4954
# Override - identifier - marker_annotation - 4955
# public - public - modifiers - 4965
# int - int - integral_type - 4972
# getLine - identifier - method_declaration - 4976
# ( - ( - formal_parameters - 4983
# ) - ) - formal_parameters - 4984
# { - { - block - 4986
# return - return - return_statement - 4990
# getInterpreter - identifier - method_invocation - 4997
# ( - ( - argument_list - 5011
# ) - ) - argument_list - 5012
# . - . - method_invocation - 5013
# getLine - identifier - method_invocation - 5014
# ( - ( - argument_list - 5021
# ) - ) - argument_list - 5022
# ; - ; - return_statement - 5023
# } - } - block - 5026
# @ - @ - marker_annotation - 5030
# Override - identifier - marker_annotation - 5031
# public - public - modifiers - 5041
# int - int - integral_type - 5048
# getCharPositionInLine - identifier - method_declaration - 5052
# ( - ( - formal_parameters - 5073
# ) - ) - formal_parameters - 5074
# { - { - block - 5076
# return - return - return_statement - 5080
# getInterpreter - identifier - method_invocation - 5087
# ( - ( - argument_list - 5101
# ) - ) - argument_list - 5102
# . - . - method_invocation - 5103
# getCharPositionInLine - identifier - method_invocation - 5104
# ( - ( - argument_list - 5125
# ) - ) - argument_list - 5126
# ; - ; - return_statement - 5127
# } - } - block - 5130
# public - public - modifiers - 5134
# void - void_type - method_declaration - 5141
# setLine - identifier - method_declaration - 5146
# ( - ( - formal_parameters - 5153
# int - int - integral_type - 5154
# line - identifier - formal_parameter - 5158
# ) - ) - formal_parameters - 5162
# { - { - block - 5164
# getInterpreter - identifier - method_invocation - 5168
# ( - ( - argument_list - 5182
# ) - ) - argument_list - 5183
# . - . - method_invocation - 5184
# setLine - identifier - method_invocation - 5185
# ( - ( - argument_list - 5192
# line - identifier - argument_list - 5193
# ) - ) - argument_list - 5197
# ; - ; - expression_statement - 5198
# } - } - block - 5201
# public - public - modifiers - 5205
# void - void_type - method_declaration - 5212
# setCharPositionInLine - identifier - method_declaration - 5217
# ( - ( - formal_parameters - 5238
# int - int - integral_type - 5239
# charPositionInLine - identifier - formal_parameter - 5243
# ) - ) - formal_parameters - 5261
# { - { - block - 5263
# getInterpreter - identifier - method_invocation - 5267
# ( - ( - argument_list - 5281
# ) - ) - argument_list - 5282
# . - . - method_invocation - 5283
# setCharPositionInLine - identifier - method_invocation - 5284
# ( - ( - argument_list - 5305
# charPositionInLine - identifier - argument_list - 5306
# ) - ) - argument_list - 5324
# ; - ; - expression_statement - 5325
# } - } - block - 5328
# /** What is the index of the current character of lookahead? */ - block_comment - class_body - 5332
# public - public - modifiers - 5397
# int - int - integral_type - 5404
# getCharIndex - identifier - method_declaration - 5408
# ( - ( - formal_parameters - 5420
# ) - ) - formal_parameters - 5421
# { - { - block - 5423
# return - return - return_statement - 5427
# _input - identifier - method_invocation - 5434
# . - . - method_invocation - 5440
# index - identifier - method_invocation - 5441
# ( - ( - argument_list - 5446
# ) - ) - argument_list - 5447
# ; - ; - return_statement - 5448
# } - } - block - 5451
# /** Return the text matched so far for the current token or any
# 	 *  text override.
# 	 */ - block_comment - class_body - 5455
# public - public - modifiers - 5545
# String - type_identifier - method_declaration - 5552
# getText - identifier - method_declaration - 5559
# ( - ( - formal_parameters - 5566
# ) - ) - formal_parameters - 5567
# { - { - block - 5569
# if - if - if_statement - 5573
# ( - ( - parenthesized_expression - 5576
# _text - identifier - binary_expression - 5578
# != - != - binary_expression - 5584
# null - null_literal - binary_expression - 5586
# ) - ) - parenthesized_expression - 5591
# { - { - block - 5593
# return - return - return_statement - 5598
# _text - identifier - return_statement - 5605
# ; - ; - return_statement - 5610
# } - } - block - 5614
# return - return - return_statement - 5618
# getInterpreter - identifier - method_invocation - 5625
# ( - ( - argument_list - 5639
# ) - ) - argument_list - 5640
# . - . - method_invocation - 5641
# getText - identifier - method_invocation - 5642
# ( - ( - argument_list - 5649
# _input - identifier - argument_list - 5650
# ) - ) - argument_list - 5656
# ; - ; - return_statement - 5657
# } - } - block - 5660
# /** Set the complete text of this token; it wipes any previous
# 	 *  changes to the text.
# 	 */ - block_comment - class_body - 5664
# public - public - modifiers - 5759
# void - void_type - method_declaration - 5766
# setText - identifier - method_declaration - 5771
# ( - ( - formal_parameters - 5778
# String - type_identifier - formal_parameter - 5779
# text - identifier - formal_parameter - 5786
# ) - ) - formal_parameters - 5790
# { - { - block - 5792
# this - this - field_access - 5796
# . - . - field_access - 5800
# _text - identifier - field_access - 5801
# = - = - assignment_expression - 5807
# text - identifier - assignment_expression - 5809
# ; - ; - expression_statement - 5813
# } - } - block - 5816
# /** Override if emitting multiple tokens. */ - block_comment - class_body - 5820
# public - public - modifiers - 5866
# Token - type_identifier - method_declaration - 5873
# getToken - identifier - method_declaration - 5879
# ( - ( - formal_parameters - 5887
# ) - ) - formal_parameters - 5888
# { - { - block - 5890
# return - return - return_statement - 5892
# _token - identifier - return_statement - 5899
# ; - ; - return_statement - 5905
# } - } - block - 5907
# public - public - modifiers - 5911
# void - void_type - method_declaration - 5918
# setToken - identifier - method_declaration - 5923
# ( - ( - formal_parameters - 5931
# Token - type_identifier - formal_parameter - 5932
# _token - identifier - formal_parameter - 5938
# ) - ) - formal_parameters - 5944
# { - { - block - 5946
# this - this - field_access - 5950
# . - . - field_access - 5954
# _token - identifier - field_access - 5955
# = - = - assignment_expression - 5962
# _token - identifier - assignment_expression - 5964
# ; - ; - expression_statement - 5970
# } - } - block - 5973
# public - public - modifiers - 5977
# void - void_type - method_declaration - 5984
# setType - identifier - method_declaration - 5989
# ( - ( - formal_parameters - 5996
# int - int - integral_type - 5997
# ttype - identifier - formal_parameter - 6001
# ) - ) - formal_parameters - 6006
# { - { - block - 6008
# _type - identifier - assignment_expression - 6012
# = - = - assignment_expression - 6018
# ttype - identifier - assignment_expression - 6020
# ; - ; - expression_statement - 6025
# } - } - block - 6028
# public - public - modifiers - 6032
# int - int - integral_type - 6039
# getType - identifier - method_declaration - 6043
# ( - ( - formal_parameters - 6050
# ) - ) - formal_parameters - 6051
# { - { - block - 6053
# return - return - return_statement - 6057
# _type - identifier - return_statement - 6064
# ; - ; - return_statement - 6069
# } - } - block - 6072
# public - public - modifiers - 6076
# void - void_type - method_declaration - 6083
# setChannel - identifier - method_declaration - 6088
# ( - ( - formal_parameters - 6098
# int - int - integral_type - 6099
# channel - identifier - formal_parameter - 6103
# ) - ) - formal_parameters - 6110
# { - { - block - 6112
# _channel - identifier - assignment_expression - 6116
# = - = - assignment_expression - 6125
# channel - identifier - assignment_expression - 6127
# ; - ; - expression_statement - 6134
# } - } - block - 6137
# public - public - modifiers - 6141
# int - int - integral_type - 6148
# getChannel - identifier - method_declaration - 6152
# ( - ( - formal_parameters - 6162
# ) - ) - formal_parameters - 6163
# { - { - block - 6165
# return - return - return_statement - 6169
# _channel - identifier - return_statement - 6176
# ; - ; - return_statement - 6184
# } - } - block - 6187
# public - public - modifiers - 6191
# String - type_identifier - array_type - 6198
# [ - [ - dimensions - 6204
# ] - ] - dimensions - 6205
# getChannelNames - identifier - method_declaration - 6207
# ( - ( - formal_parameters - 6222
# ) - ) - formal_parameters - 6223
# { - { - block - 6225
# return - return - return_statement - 6227
# null - null_literal - return_statement - 6234
# ; - ; - return_statement - 6238
# } - } - block - 6240
# public - public - modifiers - 6244
# String - type_identifier - array_type - 6251
# [ - [ - dimensions - 6257
# ] - ] - dimensions - 6258
# getModeNames - identifier - method_declaration - 6260
# ( - ( - formal_parameters - 6272
# ) - ) - formal_parameters - 6273
# { - { - block - 6275
# return - return - return_statement - 6279
# null - null_literal - return_statement - 6286
# ; - ; - return_statement - 6290
# } - } - block - 6293
# /** Used to print out token names like ID during debugging and
# 	 *  error reporting.  The generated parsers implement a method
# 	 *  that overrides this to point to their String[] tokenNames.
# 	 */ - block_comment - class_body - 6297
# @ - @ - marker_annotation - 6494
# Override - identifier - marker_annotation - 6495
# @ - @ - marker_annotation - 6505
# Deprecated - identifier - marker_annotation - 6506
# public - public - modifiers - 6518
# String - type_identifier - array_type - 6525
# [ - [ - dimensions - 6531
# ] - ] - dimensions - 6532
# getTokenNames - identifier - method_declaration - 6534
# ( - ( - formal_parameters - 6547
# ) - ) - formal_parameters - 6548
# { - { - block - 6550
# return - return - return_statement - 6554
# null - null_literal - return_statement - 6561
# ; - ; - return_statement - 6565
# } - } - block - 6568
# /** Return a list of all Token objects in input char stream.
# 	 *  Forces load of all tokens. Does not include EOF token.
# 	 */ - block_comment - class_body - 6572
# public - public - modifiers - 6699
# List - type_identifier - generic_type - 6706
# < - < - type_arguments - 6710
# ? - ? - wildcard - 6711
# extends - extends - wildcard - 6713
# Token - type_identifier - wildcard - 6721
# > - > - type_arguments - 6726
# getAllTokens - identifier - method_declaration - 6728
# ( - ( - formal_parameters - 6740
# ) - ) - formal_parameters - 6741
# { - { - block - 6743
# List - type_identifier - generic_type - 6747
# < - < - type_arguments - 6751
# Token - type_identifier - type_arguments - 6752
# > - > - type_arguments - 6757
# tokens - identifier - variable_declarator - 6759
# = - = - variable_declarator - 6766
# new - new - object_creation_expression - 6768
# ArrayList - type_identifier - generic_type - 6772
# < - < - type_arguments - 6781
# Token - type_identifier - type_arguments - 6782
# > - > - type_arguments - 6787
# ( - ( - argument_list - 6788
# ) - ) - argument_list - 6789
# ; - ; - local_variable_declaration - 6790
# Token - type_identifier - local_variable_declaration - 6794
# t - identifier - variable_declarator - 6800
# = - = - variable_declarator - 6802
# nextToken - identifier - method_invocation - 6804
# ( - ( - argument_list - 6813
# ) - ) - argument_list - 6814
# ; - ; - local_variable_declaration - 6815
# while - while - while_statement - 6819
# ( - ( - parenthesized_expression - 6825
# t - identifier - method_invocation - 6827
# . - . - method_invocation - 6828
# getType - identifier - method_invocation - 6829
# ( - ( - argument_list - 6836
# ) - ) - argument_list - 6837
# != - != - binary_expression - 6838
# Token - identifier - field_access - 6840
# . - . - field_access - 6845
# EOF - identifier - field_access - 6846
# ) - ) - parenthesized_expression - 6850
# { - { - block - 6852
# tokens - identifier - method_invocation - 6857
# . - . - method_invocation - 6863
# add - identifier - method_invocation - 6864
# ( - ( - argument_list - 6867
# t - identifier - argument_list - 6868
# ) - ) - argument_list - 6869
# ; - ; - expression_statement - 6870
# t - identifier - assignment_expression - 6875
# = - = - assignment_expression - 6877
# nextToken - identifier - method_invocation - 6879
# ( - ( - argument_list - 6888
# ) - ) - argument_list - 6889
# ; - ; - expression_statement - 6890
# } - } - block - 6894
# return - return - return_statement - 6898
# tokens - identifier - return_statement - 6905
# ; - ; - return_statement - 6911
# } - } - block - 6914
# public - public - modifiers - 6918
# void - void_type - method_declaration - 6925
# recover - identifier - method_declaration - 6930
# ( - ( - formal_parameters - 6937
# LexerNoViableAltException - type_identifier - formal_parameter - 6938
# e - identifier - formal_parameter - 6964
# ) - ) - formal_parameters - 6965
# { - { - block - 6967
# if - if - if_statement - 6971
# ( - ( - parenthesized_expression - 6974
# _input - identifier - method_invocation - 6975
# . - . - method_invocation - 6981
# LA - identifier - method_invocation - 6982
# ( - ( - argument_list - 6984
# 1 - decimal_integer_literal - argument_list - 6985
# ) - ) - argument_list - 6986
# != - != - binary_expression - 6988
# IntStream - identifier - field_access - 6991
# . - . - field_access - 7000
# EOF - identifier - field_access - 7001
# ) - ) - parenthesized_expression - 7004
# { - { - block - 7006
# // skip a char and try again - line_comment - block - 7011
# getInterpreter - identifier - method_invocation - 7043
# ( - ( - argument_list - 7057
# ) - ) - argument_list - 7058
# . - . - method_invocation - 7059
# consume - identifier - method_invocation - 7060
# ( - ( - argument_list - 7067
# _input - identifier - argument_list - 7068
# ) - ) - argument_list - 7074
# ; - ; - expression_statement - 7075
# } - } - block - 7079
# } - } - block - 7082
# public - public - modifiers - 7086
# void - void_type - method_declaration - 7093
# notifyListeners - identifier - method_declaration - 7098
# ( - ( - formal_parameters - 7113
# LexerNoViableAltException - type_identifier - formal_parameter - 7114
# e - identifier - formal_parameter - 7140
# ) - ) - formal_parameters - 7141
# { - { - block - 7143
# String - type_identifier - local_variable_declaration - 7147
# text - identifier - variable_declarator - 7154
# = - = - variable_declarator - 7159
# _input - identifier - method_invocation - 7161
# . - . - method_invocation - 7167
# getText - identifier - method_invocation - 7168
# ( - ( - argument_list - 7175
# Interval - identifier - method_invocation - 7176
# . - . - method_invocation - 7184
# of - identifier - method_invocation - 7185
# ( - ( - argument_list - 7187
# _tokenStartCharIndex - identifier - argument_list - 7188
# , - , - argument_list - 7208
# _input - identifier - method_invocation - 7210
# . - . - method_invocation - 7216
# index - identifier - method_invocation - 7217
# ( - ( - argument_list - 7222
# ) - ) - argument_list - 7223
# ) - ) - argument_list - 7224
# ) - ) - argument_list - 7225
# ; - ; - local_variable_declaration - 7226
# String - type_identifier - local_variable_declaration - 7230
# msg - identifier - variable_declarator - 7237
# = - = - variable_declarator - 7241
# "token recognition error at: '" - string_literal - binary_expression - 7243
# + - + - binary_expression - 7274
# getErrorDisplay - identifier - method_invocation - 7276
# ( - ( - argument_list - 7291
# text - identifier - argument_list - 7292
# ) - ) - argument_list - 7296
# + - + - binary_expression - 7298
# "'" - string_literal - binary_expression - 7300
# ; - ; - local_variable_declaration - 7303
# ANTLRErrorListener - type_identifier - local_variable_declaration - 7308
# listener - identifier - variable_declarator - 7327
# = - = - variable_declarator - 7336
# getErrorListenerDispatch - identifier - method_invocation - 7338
# ( - ( - argument_list - 7362
# ) - ) - argument_list - 7363
# ; - ; - local_variable_declaration - 7364
# listener - identifier - method_invocation - 7368
# . - . - method_invocation - 7376
# syntaxError - identifier - method_invocation - 7377
# ( - ( - argument_list - 7388
# this - this - argument_list - 7389
# , - , - argument_list - 7393
# null - null_literal - argument_list - 7395
# , - , - argument_list - 7399
# _tokenStartLine - identifier - argument_list - 7401
# , - , - argument_list - 7416
# _tokenStartCharPositionInLine - identifier - argument_list - 7418
# , - , - argument_list - 7447
# msg - identifier - argument_list - 7449
# , - , - argument_list - 7452
# e - identifier - argument_list - 7454
# ) - ) - argument_list - 7455
# ; - ; - expression_statement - 7456
# } - } - block - 7459
# public - public - modifiers - 7463
# String - type_identifier - method_declaration - 7470
# getErrorDisplay - identifier - method_declaration - 7477
# ( - ( - formal_parameters - 7492
# String - type_identifier - formal_parameter - 7493
# s - identifier - formal_parameter - 7500
# ) - ) - formal_parameters - 7501
# { - { - block - 7503
# StringBuilder - type_identifier - local_variable_declaration - 7507
# buf - identifier - variable_declarator - 7521
# = - = - variable_declarator - 7525
# new - new - object_creation_expression - 7527
# StringBuilder - type_identifier - object_creation_expression - 7531
# ( - ( - argument_list - 7544
# ) - ) - argument_list - 7545
# ; - ; - local_variable_declaration - 7546
# for - for - enhanced_for_statement - 7550
# ( - ( - enhanced_for_statement - 7554
# char - char - integral_type - 7555
# c - identifier - enhanced_for_statement - 7560
# : - : - enhanced_for_statement - 7562
# s - identifier - method_invocation - 7564
# . - . - method_invocation - 7565
# toCharArray - identifier - method_invocation - 7566
# ( - ( - argument_list - 7577
# ) - ) - argument_list - 7578
# ) - ) - enhanced_for_statement - 7579
# { - { - block - 7581
# buf - identifier - method_invocation - 7586
# . - . - method_invocation - 7589
# append - identifier - method_invocation - 7590
# ( - ( - argument_list - 7596
# getErrorDisplay - identifier - method_invocation - 7597
# ( - ( - argument_list - 7612
# c - identifier - argument_list - 7613
# ) - ) - argument_list - 7614
# ) - ) - argument_list - 7615
# ; - ; - expression_statement - 7616
# } - } - block - 7620
# return - return - return_statement - 7624
# buf - identifier - method_invocation - 7631
# . - . - method_invocation - 7634
# toString - identifier - method_invocation - 7635
# ( - ( - argument_list - 7643
# ) - ) - argument_list - 7644
# ; - ; - return_statement - 7645
# } - } - block - 7648
# public - public - modifiers - 7652
# String - type_identifier - method_declaration - 7659
# getErrorDisplay - identifier - method_declaration - 7666
# ( - ( - formal_parameters - 7681
# int - int - integral_type - 7682
# c - identifier - formal_parameter - 7686
# ) - ) - formal_parameters - 7687
# { - { - block - 7689
# String - type_identifier - local_variable_declaration - 7693
# s - identifier - variable_declarator - 7700
# = - = - variable_declarator - 7702
# String - identifier - method_invocation - 7704
# . - . - method_invocation - 7710
# valueOf - identifier - method_invocation - 7711
# ( - ( - argument_list - 7718
# ( - ( - cast_expression - 7719
# char - char - integral_type - 7720
# ) - ) - cast_expression - 7724
# c - identifier - cast_expression - 7725
# ) - ) - argument_list - 7726
# ; - ; - local_variable_declaration - 7727
# switch - switch - switch_expression - 7731
# ( - ( - parenthesized_expression - 7738
# c - identifier - parenthesized_expression - 7740
# ) - ) - parenthesized_expression - 7742
# { - { - switch_block - 7744
# case - case - switch_label - 7749
# Token - identifier - field_access - 7754
# . - . - field_access - 7759
# EOF - identifier - field_access - 7760
# : - : - switch_block_statement_group - 7764
# s - identifier - assignment_expression - 7770
# = - = - assignment_expression - 7772
# "<EOF>" - string_literal - assignment_expression - 7774
# ; - ; - expression_statement - 7781
# break - break - break_statement - 7787
# ; - ; - break_statement - 7792
# case - case - switch_label - 7797
# '\n' - character_literal - switch_label - 7802
# : - : - switch_block_statement_group - 7807
# s - identifier - assignment_expression - 7813
# = - = - assignment_expression - 7815
# "\\n" - string_literal - assignment_expression - 7817
# ; - ; - expression_statement - 7822
# break - break - break_statement - 7828
# ; - ; - break_statement - 7833
# case - case - switch_label - 7838
# '\t' - character_literal - switch_label - 7843
# : - : - switch_block_statement_group - 7848
# s - identifier - assignment_expression - 7854
# = - = - assignment_expression - 7856
# "\\t" - string_literal - assignment_expression - 7858
# ; - ; - expression_statement - 7863
# break - break - break_statement - 7869
# ; - ; - break_statement - 7874
# case - case - switch_label - 7879
# '\r' - character_literal - switch_label - 7884
# : - : - switch_block_statement_group - 7889
# s - identifier - assignment_expression - 7895
# = - = - assignment_expression - 7897
# "\\r" - string_literal - assignment_expression - 7899
# ; - ; - expression_statement - 7904
# break - break - break_statement - 7910
# ; - ; - break_statement - 7915
# } - } - switch_block - 7919
# return - return - return_statement - 7923
# s - identifier - return_statement - 7930
# ; - ; - return_statement - 7931
# } - } - block - 7934
# public - public - modifiers - 7938
# String - type_identifier - method_declaration - 7945
# getCharErrorDisplay - identifier - method_declaration - 7952
# ( - ( - formal_parameters - 7971
# int - int - integral_type - 7972
# c - identifier - formal_parameter - 7976
# ) - ) - formal_parameters - 7977
# { - { - block - 7979
# String - type_identifier - local_variable_declaration - 7983
# s - identifier - variable_declarator - 7990
# = - = - variable_declarator - 7992
# getErrorDisplay - identifier - method_invocation - 7994
# ( - ( - argument_list - 8009
# c - identifier - argument_list - 8010
# ) - ) - argument_list - 8011
# ; - ; - local_variable_declaration - 8012
# return - return - return_statement - 8016
# "'" - string_literal - binary_expression - 8023
# + - + - binary_expression - 8026
# s - identifier - binary_expression - 8027
# + - + - binary_expression - 8028
# "'" - string_literal - binary_expression - 8029
# ; - ; - return_statement - 8032
# } - } - block - 8035
# /** Lexers can normally match any char in it's vocabulary after matching
# 	 *  a token, so do the easy thing and just kill a character and hope
# 	 *  it all works out.  You can instead use the rule invocation stack
# 	 *  to do sophisticated error recovery if you are in a fragment rule.
# 	 */ - block_comment - class_body - 8039
# public - public - modifiers - 8329
# void - void_type - method_declaration - 8336
# recover - identifier - method_declaration - 8341
# ( - ( - formal_parameters - 8348
# RecognitionException - type_identifier - formal_parameter - 8349
# re - identifier - formal_parameter - 8370
# ) - ) - formal_parameters - 8372
# { - { - block - 8374
# //System.out.println("consuming char "+(char)input.LA(1)+" during recovery"); - line_comment - block - 8378
# //re.printStackTrace(); - line_comment - block - 8458
# // TODO: Do we lose character or line position information? - line_comment - block - 8484
# _input - identifier - method_invocation - 8546
# . - . - method_invocation - 8552
# consume - identifier - method_invocation - 8553
# ( - ( - argument_list - 8560
# ) - ) - argument_list - 8561
# ; - ; - expression_statement - 8562
# } - } - block - 8565
# } - } - class_body - 8567

# %%
methods = []
in_method = 0
method = {}
i = 0
while True and len(tokens) != i:
    t = tokens[i]

    if (t.annotation == 'identifier' and t.block == 'method_declaration'):
        start = tokens[i].position
        in_method = True
        open_bloks = 0
        closed_bloks = 0
        comments = [start]
        while in_method:
            i += 1
            if 'comment' in tokens[i].annotation:
                comments.extend([tokens[i].position, tokens[i + 1].position])
            if tokens[i].block == 'block' and tokens[i].annotation == '{':
                open_bloks += 1
            if tokens[i].block == 'block' and tokens[i].annotation == '}':
                closed_bloks += 1
            
            if open_bloks != 0 and open_bloks == closed_bloks:
                in_method = False
                i += 1
        
        end = tokens[i].position
        comments.append(end)
        pairs = list(zip(comments[::2], comments[1::2]))
        body = [file_content[s:e] for s, e in pairs]
        body = ' '.join([t.decode("utf8") for t in body])
        method['body'] = ' '.join(body.split())
        methods.append(method)
    method = {}
    i += 1

# %%
methods
# Out:
# [{'body': 'reset() { if ( _input !=null ) { _input.seek(0); } _token = null; _type = Token.INVALID_TYPE; _channel = Token.DEFAULT_CHANNEL; _tokenStartCharIndex = -1; _tokenStartCharPositionInLine = -1; _tokenStartLine = -1; _text = null; _hitEOF = false; _mode = Lexer.DEFAULT_MODE; _modeStack.clear(); getInterpreter().reset(); }'},
#  {'body': 'nextToken() { if (_input == null) { throw new IllegalStateException("nextToken requires a non-null input stream."); } int tokenStartMarker = _input.mark(); try{ outer: while (true) { if (_hitEOF) { emitEOF(); return _token; } _token = null; _channel = Token.DEFAULT_CHANNEL; _tokenStartCharIndex = _input.index(); _tokenStartCharPositionInLine = getInterpreter().getCharPositionInLine(); _tokenStartLine = getInterpreter().getLine(); _text = null; do { _type = Token.INVALID_TYPE; int ttype; try { ttype = getInterpreter().match(_input, _mode); } catch (LexerNoViableAltException e) { notifyListeners(e); recover(e); ttype = SKIP; } if ( _input.LA(1)==IntStream.EOF ) { _hitEOF = true; } if ( _type == Token.INVALID_TYPE ) _type = ttype; if ( _type ==SKIP ) { continue outer; } } while ( _type ==MORE ); if ( _token == null ) emit(); return _token; } } finally { _input.release(tokenStartMarker); } }'},
#  {'body': 'skip() { _type = SKIP; }'},
#  {'body': 'more() { _type = MORE; }'},
#  {'body': 'mode(int m) { _mode = m; }'},
#  {'body': 'pushMode(int m) { if ( LexerATNSimulator.debug ) System.out.println("pushMode "+m); _modeStack.push(_mode); mode(m); }'},
#  {'body': 'popMode() { if ( _modeStack.isEmpty() ) throw new EmptyStackException(); if ( LexerATNSimulator.debug ) System.out.println("popMode back to "+ _modeStack.peek()); mode( _modeStack.pop() ); return _mode; }'},
#  {'body': 'setTokenFactory(TokenFactory<?> factory) { this._factory = factory; }'},
#  {'body': 'getTokenFactory() { return _factory; }'},
#  {'body': 'setInputStream(IntStream input) { this._input = null; this._tokenFactorySourcePair = new Pair<TokenSource, CharStream>(this, _input); reset(); this._input = (CharStream)input; this._tokenFactorySourcePair = new Pair<TokenSource, CharStream>(this, _input); }'},
#  {'body': 'getSourceName() { return _input.getSourceName(); }'},
#  {'body': 'getInputStream() { return _input; }'},
#  {'body': 'emit(Token token) { this._token = token; }'},
#  {'body': 'emit() { Token t = _factory.create(_tokenFactorySourcePair, _type, _text, _channel, _tokenStartCharIndex, getCharIndex()-1, _tokenStartLine, _tokenStartCharPositionInLine); emit(t); return t; }'},
#  {'body': 'emitEOF() { int cpos = getCharPositionInLine(); int line = getLine(); Token eof = _factory.create(_tokenFactorySourcePair, Token.EOF, null, Token.DEFAULT_CHANNEL, _input.index(), _input.index()-1, line, cpos); emit(eof); return eof; }'},
#  {'body': 'getLine() { return getInterpreter().getLine(); }'},
#  {'body': 'getCharPositionInLine() { return getInterpreter().getCharPositionInLine(); }'},
#  {'body': 'setLine(int line) { getInterpreter().setLine(line); }'},
#  {'body': 'setCharPositionInLine(int charPositionInLine) { getInterpreter().setCharPositionInLine(charPositionInLine); }'},
#  {'body': 'getCharIndex() { return _input.index(); }'},
#  {'body': 'getText() { if ( _text !=null ) { return _text; } return getInterpreter().getText(_input); }'},
#  {'body': 'setText(String text) { this._text = text; }'},
#  {'body': 'getToken() { return _token; }'},
#  {'body': 'setToken(Token _token) { this._token = _token; }'},
#  {'body': 'setType(int ttype) { _type = ttype; }'},
#  {'body': 'getType() { return _type; }'},
#  {'body': 'setChannel(int channel) { _channel = channel; }'},
#  {'body': 'getChannel() { return _channel; }'},
#  {'body': 'getChannelNames() { return null; }'},
#  {'body': 'getModeNames() { return null; }'},
#  {'body': 'getTokenNames() { return null; }'},
#  {'body': 'getAllTokens() { List<Token> tokens = new ArrayList<Token>(); Token t = nextToken(); while ( t.getType()!=Token.EOF ) { tokens.add(t); t = nextToken(); } return tokens; }'},
#  {'body': 'recover(LexerNoViableAltException e) { if (_input.LA(1) != IntStream.EOF) { getInterpreter().consume(_input); } }'},
#  {'body': 'notifyListeners(LexerNoViableAltException e) { String text = _input.getText(Interval.of(_tokenStartCharIndex, _input.index())); String msg = "token recognition error at: \'"+ getErrorDisplay(text) + "\'"; ANTLRErrorListener listener = getErrorListenerDispatch(); listener.syntaxError(this, null, _tokenStartLine, _tokenStartCharPositionInLine, msg, e); }'},
#  {'body': 'getErrorDisplay(String s) { StringBuilder buf = new StringBuilder(); for (char c : s.toCharArray()) { buf.append(getErrorDisplay(c)); } return buf.toString(); }'},
#  {'body': 'getErrorDisplay(int c) { String s = String.valueOf((char)c); switch ( c ) { case Token.EOF : s = "<EOF>"; break; case \'\\n\' : s = "\\\\n"; break; case \'\\t\' : s = "\\\\t"; break; case \'\\r\' : s = "\\\\r"; break; } return s; }'},
#  {'body': 'getCharErrorDisplay(int c) { String s = getErrorDisplay(c); return "\'"+s+"\'"; }'},
#  {'body': 'recover(RecognitionException re) { _input.consume(); }'}]

# %%
len(methods)
# Out:
# 38
